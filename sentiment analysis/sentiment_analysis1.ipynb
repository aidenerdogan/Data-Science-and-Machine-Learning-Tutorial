# %%
from nltk import ngrams
from nltk.corpus import stopwords 
import string
import pandas
import numpy as np

# %%
stopwords_english = stopwords.words('english')

# %%
# clean words, i.e. remove stopwords and punctuation
def clean_words(words, stopwords_english):
    words_clean = []
#     print(type(words))
    for word in words:
        word = word.lower()
        if word not in stopwords_english and word not in string.punctuation:
            words_clean.append(word)    
    return words_clean

# %%
# feature extractor function for unigram
def bag_of_words(words):    
    words_dictionary = dict([word, True] for word in words)    
    return words_dictionary

# %%
# feature extractor function for ngrams (bigram)
def bag_of_ngrams(words, n=2):
    words_ng = []
    for item in iter(ngrams(words, n)):
        words_ng.append(item)
    words_dictionary = dict([word, True] for word in words_ng)    
    return words_dictionary

# %%
from nltk.tokenize import word_tokenize
text = "It was a very good movie."
words = word_tokenize(text.lower())

# %%
words
# Out:
# ['it', 'was', 'a', 'very', 'good', 'movie', '.']

# %%
bag_of_ngrams(words)
# Out:
# {('it', 'was'): True,
#  ('was', 'a'): True,
#  ('a', 'very'): True,
#  ('very', 'good'): True,
#  ('good', 'movie'): True,
#  ('movie', '.'): True}

# %%
words_clean = clean_words(words, stopwords_english)
print (words_clean)
# Out:
# ['good', 'movie']

# %%
important_words = ['above', 'below', 'off', 'over', 'under', 'more', 'most', 'such', 'no', 'nor', 'not', 'only', 'so', 'than', 'too', 'very', 'just', 'but']

# %%
stopwords_english_for_bigrams = set(stopwords_english) - set(important_words)

# %%
words_clean_for_bigrams = clean_words(words, stopwords_english_for_bigrams)
print (words_clean_for_bigrams)
# Out:
# ['very', 'good', 'movie']

# %%
unigram_features = bag_of_words(words_clean)
unigram_features
# Out:
# {'good': True, 'movie': True}

# %%
bigram_features = bag_of_ngrams(words_clean_for_bigrams)
bigram_features
# Out:
# {('very', 'good'): True, ('good', 'movie'): True}

# %%
# combine both unigram and bigram features
all_features = unigram_features.copy()
all_features.update(bigram_features)
all_features
# Out:
# {'good': True, 'movie': True, ('very', 'good'): True, ('good', 'movie'): True}

# %%
# let's define a new function that extracts all features
# i.e. that extracts both unigram and bigrams features
def bag_of_all_words(words, n=2):
    words_clean = clean_words(words, stopwords_english)
    words_clean_for_bigrams = clean_words(words, stopwords_english_for_bigrams)
 
    unigram_features = bag_of_words(words_clean)
    bigram_features = bag_of_ngrams(words_clean_for_bigrams)
 
    all_features = unigram_features.copy()
    all_features.update(bigram_features)
 
    return all_features

# %%
bag_of_all_words(words)
# Out:
# {'good': True, 'movie': True, ('very', 'good'): True, ('good', 'movie'): True}

# %%
# from nltk.corpus import movie_reviews 
 
# pos_reviews = []
# for fileid in movie_reviews.fileids('pos'):
# #     print(movie_reviews.words(fileid))
#     words = movie_reviews.words(fileid)
#     pos_reviews.append(words)
 
# neg_reviews = []
# for fileid in movie_reviews.fileids('neg'):
#     words = movie_reviews.words(fileid)
#     neg_reviews.append(words)

# %%
# pos_reviews[:5]

# %%
# # positive reviews feature set
# pos_reviews_set = []
# for words in pos_reviews:
# #     print(words)
#     pos_reviews_set.append((bag_of_all_words(words), 'pos'))
 
# # negative reviews feature set
# neg_reviews_set = []
# for words in neg_reviews:
#     neg_reviews_set.append((bag_of_all_words(words), 'neg'))

# %%
tweet_data = pandas.read_csv('clean_tweet2.csv',index_col=0)
tweet_data.head()
# Out:
#                                                 text  sentiment
# 0                        is so sad for my apl friend          0
# 1                        missed the new moon trailer          0
# 2                                    omg its already          1
# 3  omgaga im sooo im gunna cry ve been at this de...          0
# 4                      think mi bf is cheating on me          0

# %%
tweet_data.shape
# Out:
# (99988, 2)

# %%
tweet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99988 entries, 0 to 99987
# Data columns (total 2 columns):
# text         99523 non-null object
# sentiment    99988 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.3+ MB

# %%
tweet_data[tweet_data.isnull().any(axis=1)].head()
# Out:
#     text  sentiment
# 225  NaN          1
# 228  NaN          1
# 233  NaN          0
# 252  NaN          0
# 694  NaN          1

# %%
np.sum(tweet_data.isnull().any(axis=1))
# Out:
# 465

# %%
tweet_data.isnull().any(axis=0)
# Out:
# text          True
# sentiment    False
# dtype: bool

# %%
tweet_data.dropna(inplace=True)
tweet_data.reset_index(drop=True,inplace=True)
tweet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99523 entries, 0 to 99522
# Data columns (total 2 columns):
# text         99523 non-null object
# sentiment    99523 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 1.5+ MB

# %%
tweet_data.shape
# Out:
# (99523, 2)

# %%
# import numpy as np
# pos_reviews = np.array([row for row in tweet_data[tweet_data.sentiment == 1].text.str.split()])
pos_reviews = [row for row in tweet_data[tweet_data.sentiment == 1].text.str.split()]
# [value for (index, value) in pos_reviews.items()]
pos_reviews
# Out:
# [['omg', 'its', 'already'],
#  ['handed', 'in', 'my', 'uniform', 'today', 'miss', 'you', 'already'],
#  ['hmmmm', 'wonder', 'how', 'she', 'my', 'number'],
#  ['thanks',
#   'to',
#   'all',
#   'the',
#   'haters',
#   'up',
#   'in',
#   'my',
#   'face',
#   'all',
#   'day'],
#  ['feeling',
#   'strangely',
#   'fine',
#   'now',
#   'gonna',
#   'go',
#   'listen',
#   'to',
#   'some',
#   'semisonic',
#   'to',
#   'celebrate'],
#  ['you',
#   're',
#   'the',
#   'only',
#   'one',
#   'who',
#   'can',
#   'see',
#   'this',
#   'cause',
#   'no',
#   'one',
#   'else',
#   'is',
#   'following',
#   'me',
#   'this',
#   'is',
#   'for',
#   'you',
#   'because',
#   'you',
#   're',
#   'pretty',
#   'awesome'],
#  ['goodbye', 'exams', 'hello', 'alcohol', 'tonight'],
#  ['uploading', 'pictures', 'on', 'friendster'],
#  ['so',
#   'wrote',
#   'something',
#   'last',
#   'week',
#   'and',
#   'got',
#   'call',
#   'from',
#   'someone',
#   'in',
#   'the',
#   'new',
#   'york',
#   'office'],
#  ['do',
#   'need',
#   'to',
#   'even',
#   'say',
#   'it',
#   'do',
#   'well',
#   'here',
#   'go',
#   'anyways',
#   'chris',
#   'cornell',
#   'in',
#   'chicago',
#   'tonight'],
#  ['health', 'class', 'what', 'joke'],
#  ['go', 'to', 'the', 'show', 'tonight'],
#  ['bathroom', 'is', 'clean', 'now', 'on', 'to', 'more', 'enjoyable', 'tasks'],
#  ['boom', 'boom', 'pow'],
#  ['go', 'give', 'ur', 'mom', 'hug', 'right', 'now'],
#  ['going', 'to', 'see', 'harry', 'sunday', 'happiness'],
#  ['always', 'get', 'what', 'want'],
#  ['bend', 'backwards'],
#  ['get',
#   'off',
#   'work',
#   'sooooon',
#   'miss',
#   'cody',
#   'booo',
#   'have',
#   'not',
#   'seen',
#   'him',
#   'in',
#   'foreverr'],
#  ['hate',
#   'allergies',
#   'should',
#   'get',
#   'my',
#   'hair',
#   'cut',
#   'tomorrow',
#   'taking',
#   'public',
#   'poll'],
#  ['really', 'going', 'to', 'bed', 'now'],
#  ['jin', 'has', 'twitter'],
#  ['just',
#   'gonna',
#   'smile',
#   'cuz',
#   'it',
#   'is',
#   'what',
#   'it',
#   'is',
#   'and',
#   'im',
#   'not',
#   'sure',
#   'what',
#   'more',
#   'they',
#   'could',
#   'want'],
#  ['just',
#   'got',
#   'home',
#   'and',
#   'got',
#   'to',
#   'see',
#   'my',
#   'friend',
#   'zahra',
#   'whom',
#   'have',
#   'not',
#   'seen',
#   'since',
#   'we',
#   'graduated',
#   'that',
#   'makes',
#   'me',
#   'so',
#   'happy'],
#  ['oh', 'thank', 'you'],
#  ['pleased'],
#  ['rose',
#   'and',
#   'ood',
#   'will',
#   'be',
#   'back',
#   'in',
#   'the',
#   'xmas',
#   'who',
#   'special',
#   'yay',
#   'damn',
#   'that',
#   'half',
#   'year',
#   'away'],
#  ['thanks', 'need', 'all', 'the', 'help', 'can', 'get'],
#  ['that', 'explains', 'alot'],
#  ['there',
#   'going',
#   'to',
#   'be',
#   'heathers',
#   'sequel',
#   'winona',
#   'ever',
#   'they',
#   'better',
#   'not',
#   'fuck',
#   'it',
#   'up'],
#  ['trae',
#   'is',
#   'so',
#   'sweet',
#   'he',
#   'just',
#   'bought',
#   'me',
#   'new',
#   'baithing',
#   'suit',
#   'wove',
#   'him'],
#  ['true',
#   'highly',
#   'subjective',
#   'of',
#   'me',
#   'there',
#   'tombre',
#   'was',
#   'actually',
#   'my',
#   'favorite',
#   'character',
#   'in',
#   'the',
#   'book',
#   'you',
#   'got',
#   'me',
#   'rishabh'],
#  ['wide', 'awake', 'not'],
#  ['yeah',
#   'me',
#   'too',
#   'its',
#   'been',
#   'awful',
#   'weather',
#   'here',
#   'for',
#   'the',
#   'last',
#   'week',
#   'so',
#   'that',
#   'stinks',
#   'kristis',
#   'comin',
#   'down',
#   'and',
#   'moe',
#   'said',
#   'mmmaybe',
#   'he',
#   'take',
#   'us',
#   'for'],
#  ['poemsunder', 'started', 'by'],
#  ['that', 'is', 'all', 'and', 'believe', 'me', 'it', 'enough'],
#  ['goooood', 'timessss'],
#  ['know',
#   'you',
#   'hungry',
#   'so',
#   'lets',
#   'go',
#   'outside',
#   'on',
#   'the',
#   'balcony',
#   'so',
#   'you',
#   'can',
#   'eat'],
#  ['the',
#   'men',
#   'uk',
#   'female',
#   'internet',
#   'entrepreneur',
#   'should',
#   'know',
#   'when',
#   'starting',
#   'and',
#   'growing',
#   'business',
#   'the',
#   'next',
#   'women'],
#  ['the', 'truth', 'is', 'hiding', 'in', 'your', 'eyes', 'paramore', 'decode'],
#  ['hummin',
#   'say',
#   'shut',
#   'up',
#   'put',
#   'your',
#   'money',
#   'where',
#   'your',
#   'mouth',
#   'is',
#   'headin',
#   'out',
#   'to',
#   'reality',
#   'cheers',
#   'twitter',
#   'world'],
#  ['sigh',
#   'you',
#   'cant',
#   'love',
#   'someone',
#   'that',
#   'does',
#   'not',
#   'love',
#   'you',
#   'back',
#   'that',
#   'like',
#   'stalker',
#   'status',
#   'get',
#   'divorce',
#   'move',
#   'on',
#   'trinity'],
#  ['aiqht',
#   'goodniqht',
#   'tri',
#   'neena',
#   'malcolm',
#   'chaise',
#   'jlew',
#   'atl',
#   'love',
#   'much'],
#  ['triiiiiii',
#   'ily',
#   'even',
#   'if',
#   'chaise',
#   'does',
#   'not',
#   'dies',
#   'of',
#   'laughter'],
#  ['hot', 'choco', 'is', 'the', 'best'],
#  ['beach', 'day', 'with', 'scoobs', 'still', 'no', 'phone'],
#  ['what',
#   'an',
#   'amazing',
#   'night',
#   'day',
#   'night',
#   'again',
#   'hi',
#   'twits',
#   'miss',
#   'guys'],
#  ['canaveral', 'national', 'seashore'],
#  ['progressing',
#   'in',
#   'the',
#   'production',
#   'department',
#   'with',
#   'the',
#   'uprizing',
#   'thats',
#   'the',
#   'priority',
#   'getting',
#   'the',
#   'head',
#   'nodding',
#   'beats',
#   'and',
#   'then',
#   'we',
#   'reach',
#   'out'],
#  ['taylorrhicks',
#   'enjoy',
#   'chicago',
#   'new',
#   'venue',
#   'is',
#   'always',
#   'cool',
#   'you',
#   'shine',
#   'everywhere',
#   'you',
#   'go',
#   'know',
#   'who',
#   'you',
#   'are',
#   'in',
#   'time',
#   'so',
#   'will',
#   'everyone'],
#  ['thestreetforce'],
#  ['makes', 'me', 'smile'],
#  ['my',
#   'first',
#   'day',
#   'off',
#   'in',
#   'weeks',
#   'and',
#   'my',
#   'child',
#   'got',
#   'up',
#   'before',
#   'so',
#   'watch',
#   'for',
#   'me',
#   'on',
#   'nancy',
#   'grac'],
#  ['video',
#   'woody',
#   'woodpecker',
#   'the',
#   'barber',
#   'of',
#   'seville',
#   'am',
#   'great',
#   'just',
#   'wishing',
#   'to',
#   'be',
#   'ch'],
#  ['am',
#   'happy',
#   'you',
#   'are',
#   'staying',
#   'around',
#   'here',
#   'drexel',
#   'is',
#   'fabulous',
#   'university',
#   'you',
#   'should',
#   'be',
#   'proud',
#   'yeah'],
#  ['call',
#   'dibs',
#   'on',
#   'the',
#   'voltron',
#   'arm',
#   'no',
#   'the',
#   'leg',
#   'wait',
#   'where',
#   'are',
#   'my',
#   'manners'],
#  ['just', 'saw', 'ur', 'mum'],
#  ['and', 'get', 'your', 'fat', 'asses', 'on', 'here', 'nai'],
#  ['see', 'three', 'external', 'monitors', 'on', 'one', 'laptop', 'win', 'rc'],
#  ['facebook',
#   'com',
#   'copic',
#   'marker',
#   'if',
#   'you',
#   're',
#   'cool',
#   'or',
#   'if',
#   'you',
#   're',
#   'not',
#   'cool',
#   'maybe',
#   'll',
#   'send',
#   'some',
#   'cool'],
#  ['you',
#   'want',
#   'to',
#   'start',
#   'the',
#   'morning',
#   'later',
#   'in',
#   'new',
#   'york',
#   'we',
#   'can',
#   'do',
#   'that',
#   'californians',
#   'have',
#   'it',
#   'even',
#   'better'],
#  ['lol', 'luv', 'it', 'did', 'any', 'find', 'or'],
#  ['is', 'making', 'fettucini', 'and', 'garlic', 'bread'],
#  ['tell', 'said', 'happy', 'bday'],
#  ['told', 'you', 'you', 'would', 'sweep', 'haha'],
#  ['the',
#   'servers',
#   'are',
#   'now',
#   'backup',
#   'if',
#   'you',
#   'experience',
#   'any',
#   'more',
#   'problems',
#   'then',
#   'please',
#   'let',
#   'me',
#   'know',
#   'sorry',
#   'about',
#   'the',
#   'delay'],
#  ['yes',
#   'am',
#   'lol',
#   'luv',
#   'this',
#   'you',
#   'are',
#   'like',
#   'gentle',
#   'breeze',
#   'that',
#   'has',
#   'blown',
#   'throug'],
#  ['are', 'my', 'future', 'rooooooooomies', 'nyc', 'holler'],
#  ['hope', 'have', 'cheese', 'burgers', 'lmbo'],
#  ['awesome'],
#  ['am',
#   'nothing',
#   'of',
#   'the',
#   'kind',
#   'and',
#   'everything',
#   'of',
#   'the',
#   'sort'],
#  ['pick',
#   'up',
#   'some',
#   'flowers',
#   'for',
#   'the',
#   'teacher',
#   'jealous',
#   'want',
#   'flowers',
#   'without',
#   'having',
#   'to',
#   'be',
#   'in',
#   'the',
#   'hospital',
#   'to',
#   'get',
#   'them'],
#  ['think',
#   'again',
#   'talvez',
#   'seja',
#   'do',
#   'nfase',
#   'na',
#   'cifra',
#   'mas',
#   'aten',
#   'security',
#   'is',
#   'chain',
#   'it',
#   'as',
#   'strong',
#   'as',
#   'the',
#   'weakest',
#   'link'],
#  ['watch', 'will', 'do'],
#  ['thanks', 'here', 'hoping', 'pretty', 'nervous', 'though'],
#  ['followers'],
#  ['ll',
#   'tell',
#   'ya',
#   'grocery',
#   'store',
#   'it',
#   'was',
#   'better',
#   'when',
#   'you',
#   'blasted',
#   'the',
#   'oldies',
#   'sugar',
#   'ray',
#   'does',
#   'not',
#   'make',
#   'me'],
#  ['yall',
#   'bitches',
#   'better',
#   'wake',
#   'up',
#   'early',
#   'to',
#   'go',
#   'to',
#   'the',
#   'la',
#   'opera',
#   'kay'],
#  ['congrats',
#   'bhai',
#   'but',
#   'like',
#   'the',
#   'oldies',
#   'in',
#   'used',
#   'to',
#   'say',
#   'arre',
#   'bhai',
#   'kuch',
#   'kam',
#   'ka'],
#  ['chilling',
#   'on',
#   'twitter',
#   'via',
#   'my',
#   'spanking',
#   'new',
#   'blackberry',
#   'unlimited',
#   'internet'],
#  ['so',
#   'do',
#   'you',
#   'give',
#   'him',
#   'every',
#   'inch',
#   'of',
#   'your',
#   'love',
#   'every',
#   'night'],
#  ['maybe',
#   'you',
#   'can',
#   'pop',
#   'tweet',
#   'they',
#   'are',
#   'quite',
#   'active',
#   'on',
#   'twitter'],
#  ['it',
#   'shame',
#   'all',
#   'the',
#   'women',
#   'in',
#   'mamma',
#   'mia',
#   'are',
#   'so',
#   'horny',
#   'since',
#   'all',
#   'the',
#   'men',
#   'on',
#   'this',
#   'island',
#   'are',
#   'so'],
#  ['thanks',
#   'for',
#   'letting',
#   'me',
#   'know',
#   'going',
#   'to',
#   'check',
#   'out',
#   'eureka',
#   'later',
#   'with',
#   'this',
#   'knowledge'],
#  ['what',
#   'up',
#   'hey',
#   'you',
#   'doing',
#   'ok',
#   'thx',
#   'you',
#   'you',
#   'too',
#   'ttyl',
#   'oh',
#   'sowwy',
#   'lol'],
#  ['happy', 'mothers', 'day'],
#  ['knew',
#   'sharepoint',
#   'was',
#   'written',
#   'by',
#   'interns',
#   'just',
#   'knew',
#   'it'],
#  ['am', 'happy'],
#  ['faltam', 'dias', 'para', 'world', 'drawing', 'day'],
#  ['haha',
#   'omg',
#   'stayin',
#   'steezy',
#   'mowin',
#   'the',
#   'lawn',
#   'loviie',
#   'still',
#   'here',
#   'goiing',
#   'tanning',
#   'soon'],
#  ['wanna',
#   'play',
#   'with',
#   'my',
#   'camera',
#   'but',
#   'will',
#   'settle',
#   'for',
#   'playing',
#   'with',
#   'iv',
#   'and',
#   'heart',
#   'monitors'],
#  ['lol', 'all', 'these', 'robotpickuplines', 'are', 'hilarious'],
#  ['man',
#   'oh',
#   'man',
#   'should',
#   'punch',
#   'myself',
#   'in',
#   'the',
#   'head',
#   'but',
#   'im',
#   'ok',
#   'with',
#   'that'],
#  ['my',
#   'friends',
#   'can',
#   'get',
#   'with',
#   'ur',
#   'friends',
#   'and',
#   'we',
#   'can',
#   'all',
#   'friends',
#   'shit',
#   'we',
#   'could',
#   'do',
#   'this',
#   'every',
#   'weeknd',
#   'aiigght',
#   'with',
#   'coop',
#   'the',
#   'crew'],
#  ['such',
#   'beautiful',
#   'satisfying',
#   'day',
#   'of',
#   'bargain',
#   'shopping',
#   'loves',
#   'it'],
#  ['thank', 'god', 'today', 'is', 'friday', 'love', 'ti', 'ti'],
#  ['thrilled', 'about', 'being', 'at', 'work', 'this', 'morning'],
#  ['we',
#   'break',
#   'dance',
#   'not',
#   'hearts',
#   'by',
#   'short',
#   'stack',
#   'is',
#   'my',
#   'ringtone',
#   'love',
#   'that',
#   'song'],
#  ['my', 'life', 'is', 'very', 'lazzzzyyyy'],
#  ['ish', 'in', 'good', 'mood', 'tlk', 'to', 'me'],
#  ['made', 'nice', 'twice', 'for', 'now'],
#  ['loves', 'life', 'atm', 'its', 'brilliant', 'xd'],
#  ['who', 'else', 'is', 'in', 'happy', 'mood'],
#  ['bye', 'everyone'],
#  ['so', 'far', 'so', 'good'],
#  ['today', 'was', 'great', 'day'],
#  ['lot',
#   'lot',
#   'lot',
#   'lot',
#   'lot',
#   'lot',
#   'lot',
#   'lot',
#   'lot',
#   'lot',
#   'lot',
#   'lot'],
#  ['tiger', 'woods', 'is', 'up', 'by', 'at', 'via'],
#  ['yippeeeee',
#   'yay',
#   'lets',
#   'gather',
#   'in',
#   'the',
#   'hay',
#   'his',
#   'love',
#   'found',
#   'it',
#   'way',
#   'boy',
#   'it',
#   'gonna',
#   'stay',
#   'added',
#   'the',
#   'master',
#   'holy',
#   'way',
#   'all',
#   'his',
#   'will',
#   'way'],
#  ['hardest',
#   'working',
#   'chica',
#   'know',
#   'mii',
#   'boss',
#   'lady',
#   'look',
#   'up',
#   'to',
#   'her',
#   'seriously',
#   'lol'],
#  ['thanks', 'for', 'being', 'the', 'bestttttttttttttttttttt', 'dawg'],
#  ['praise', 'god', 'for', 'this', 'beautiful', 'day'],
#  ['love', 'you', 'guyssss', 'those', 'rings', 'mmmyeahh', 'bling', 'blingg'],
#  ['chance', 'is', 'boo'],
#  ['thank',
#   'you',
#   'very',
#   'much',
#   'for',
#   'the',
#   'dvd',
#   'suggestion',
#   'very',
#   'nice',
#   'of',
#   'you',
#   'looks',
#   'good'],
#  ['had', 'wonderful', 'day', 'is', 'grrrrrrrrreat'],
#  ['have', 'passed', 'exam', 'today'],
#  ['want', 'to', 'write', 'song', 'think', 'will'],
#  ['always',
#   'thought',
#   'time',
#   'estimates',
#   'should',
#   'use',
#   'value',
#   'of',
#   'pi',
#   'rule',
#   'only',
#   'exception',
#   'being',
#   'pi',
#   'squared',
#   'rule'],
#  ['creativity', 'via', 'twitter'],
#  ['you', 'tease', 'wanna', 'hear', 'the', 'tracks'],
#  ['traveltips', 'student', 'safety', 'in', 'roughplaces'],
#  ['what', 'is', 'fml'],
#  ['gotta',
#   'love',
#   'blip',
#   'fm',
#   'john',
#   'mayer',
#   'trio',
#   'california',
#   'dreamin',
#   'as',
#   'heard',
#   'on',
#   'conan'],
#  ['just', 'in', 'case', 'you', 'need', 'some', 'help', 'that'],
#  ['im', 'sure', 'he', 'love', 'that', 'lol'],
#  ['on',
#   'karl',
#   'lagerfeld',
#   'twitter',
#   'profile',
#   'lol',
#   'heart',
#   'the',
#   'first',
#   'pic'],
#  ['my',
#   'avatar',
#   'can',
#   'not',
#   'figure',
#   'out',
#   'what',
#   'you',
#   'people',
#   'are',
#   'either'],
#  ['what',
#   'happened',
#   'to',
#   'movies',
#   'anyway',
#   'it',
#   'like',
#   'hollywood',
#   'forgot',
#   'in',
#   'rough',
#   'times',
#   'the',
#   'public',
#   'wants',
#   'to',
#   'see'],
#  ['whoops', 'credit', 'is', 'due', 'to', 'rb'],
#  ['how', 'not', 'to', 'exit', 'cessna', 'skydiving'],
#  ['chicken',
#   'mcnuggets',
#   'double',
#   'cheeseburgers',
#   'large',
#   'fries',
#   'and',
#   'lemonade',
#   'for',
#   'dinner',
#   'why',
#   'you',
#   'may',
#   'ask',
#   'because',
#   'hate',
#   'my',
#   'body'],
#  ['th',
#   'tweet',
#   'breakfast',
#   'everything',
#   'bagel',
#   'toasted',
#   'cream',
#   'cheese',
#   'with',
#   'an',
#   'iced',
#   'cap',
#   'delish'],
#  ['blessed', 'sunday', 'everyone'],
#  ['dog', 'riding', 'the', 'bicycle'],
#  ['problem', 'shared', 'is', 'buck', 'passed'],
#  ['hitech'],
#  ['am',
#   'quite',
#   'tired',
#   'can',
#   'not',
#   'wait',
#   'till',
#   'wwe',
#   'at',
#   'burswood'],
#  ['awake', 'and', 'ready', 'for', 'the', 'day'],
#  ['being',
#   'nasty',
#   'in',
#   'the',
#   'studio',
#   'with',
#   'my',
#   'woman',
#   'go',
#   'sleepies'],
#  ['feeling',
#   'ok',
#   'for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'few',
#   'days',
#   'thank',
#   'you'],
#  ['found', 'new', 'way', 'to', 'text', 'him', 'yey'],
#  ['going', 'for', 'paddle', 'moz'],
#  ['good',
#   'nite',
#   'hope',
#   'grandma',
#   'visits',
#   'my',
#   'dreams',
#   'again',
#   'tonight',
#   'last',
#   'night',
#   'was',
#   'uplifting',
#   'miss',
#   'her'],
#  ['goodbassplayer',
#   'that',
#   'is',
#   'funny',
#   'oilipo',
#   'hope',
#   'the',
#   'people',
#   'that',
#   'will',
#   'bring',
#   'us',
#   'good',
#   'things',
#   'are',
#   'started',
#   'early',
#   'this',
#   'week'],
#  ['here',
#   'to',
#   'tell',
#   'ya',
#   'very',
#   'yummy',
#   'decided',
#   'to',
#   'go',
#   'on',
#   'hunt',
#   'for',
#   'blender',
#   'drinks',
#   'know',
#   'any',
#   'good',
#   'ones'],
#  ['is', 'listenin', 'to', 'my', 'new', 'fav', 'band', 'more', 'amor'],
#  ['just', 'another', 'day', 'in', 'paradise'],
#  ['love', 'you'],
#  ['about',
#   'to',
#   'pop',
#   'in',
#   'movie',
#   'chill',
#   'bit',
#   'get',
#   'it',
#   'innnnn',
#   'call',
#   'text'],
#  ['about', 'to', 'swim'],
#  ['ahh', 'school', 'on', 'monday', 'not', 'ready'],
#  ['ahhh', 'drizzy', 'mr', 'rogers', 'you', 'are', 'indeed', 'the', 'best'],
#  ['all', 'the', 'small', 'things'],
#  ['always',
#   'nice',
#   'thing',
#   'to',
#   'wake',
#   'up',
#   'to',
#   'yay',
#   'gosh',
#   'such',
#   'typical',
#   'lame',
#   'overanalyzing',
#   'teenager',
#   'lmao',
#   'had',
#   'nice',
#   'nap'],
#  ['am', 'excited'],
#  ['am', 'feelin', 'very', 'happy'],
#  ['am', 'feeding', 'the', 'pig'],
#  ['an',
#   'alarm',
#   'clock',
#   'is',
#   'device',
#   'for',
#   'waking',
#   'up',
#   'people',
#   'who',
#   'do',
#   'not',
#   'have',
#   'small',
#   'children'],
#  ['anoron',
#   'reedcourty',
#   'operaunite',
#   'com',
#   'webserver',
#   'content',
#   'home',
#   'sch',
#   'alternat',
#   'va'],
#  ['another', 'friday', 'night', 'of', 'rock', 'band'],
#  ['million',
#   'making',
#   'difference',
#   'can',
#   'not',
#   'help',
#   'but',
#   'to',
#   'believe',
#   'came',
#   'in',
#   'believing',
#   'will',
#   'leave',
#   'believing',
#   'god',
#   'is'],
#  ['good', 'morning', 'all', 'have', 'great', 'day'],
#  ['having', 'luvly', 'day'],
#  ['he', 'is', 'so', 'hot'],
#  ['hmm', 'what', 'to', 'do'],
#  ['iowa', 'no', 'in', 'happy', 'yea'],
#  ['just', 'got', 'home'],
#  ['just',
#   'saw',
#   'sink',
#   'into',
#   'me',
#   'the',
#   'whole',
#   'video',
#   'on',
#   'kerrang',
#   'ive',
#   'seen',
#   'it',
#   'before',
#   'loads',
#   'but',
#   'its',
#   'so',
#   'much',
#   'better',
#   'on',
#   'tv'],
#  ['my', 'mom', 'is', 'the', 'funniest', 'person', 'ever'],
#  ['pie', 'seems', 'to', 'have', 'quite', 'good', 'appetite', 'now'],
#  ['nhl',
#   'penguins',
#   'red',
#   'wings',
#   'final',
#   'red',
#   'wings',
#   'lead',
#   'series',
#   'for',
#   'stats',
#   'stars',
#   'and',
#   'more',
#   'visit'],
#  ['young',
#   'teke',
#   'miss',
#   'you',
#   'cuzin',
#   'it',
#   'has',
#   'been',
#   'year',
#   'sence',
#   'you',
#   'died',
#   'dont',
#   'be',
#   'ashamed',
#   'of',
#   'your',
#   'faith'],
#  ['she', 'is', 'amazing', 'bjork', 'bachelorette'],
#  ['thank', 'you'],
#  ['andyhurleyday'],
#  ['asot'],
#  ['followfriday'],
#  ['mcflyforgermany',
#   'mcflyforgermany',
#   'mcflyforgermany',
#   'mcflyforgermany',
#   'mcflyforgermany',
#   'mcflyforgermany',
#   'mcflyforgermany',
#   'mcflyforgermany'],
#  ['that', 'was', 'then', 'this', 'is', 'now'],
#  ['this', 'pic', 'if', 'want', 'more', 'tell', 'me', 'cause', 'got', 'more'],
#  ['my', 'expression', 'watching', 'this', 'again'],
#  ['freelance',
#   'writer',
#   'for',
#   'braille',
#   'porn',
#   'and',
#   'stunt',
#   'double',
#   'for',
#   'hand',
#   'model',
#   'for',
#   'palmolive',
#   'dishwashing',
#   'liquid',
#   'from'],
#  ['im', 'in', 'love', 'and', 'do', 'not', 'care', 'who', 'knows', 'it', 'elf'],
#  ['must',
#   'people',
#   'insist',
#   'on',
#   'talking',
#   'about',
#   'stupid',
#   'politics',
#   'on',
#   'the',
#   'comments',
#   'of',
#   'bubblegum',
#   'pop',
#   'song',
#   'sorry',
#   'get',
#   'out'],
#  ['as', 'simple', 'as', 'it', 'gets'],
#  ['at',
#   'my',
#   'tweets',
#   'lady',
#   'saying',
#   'goodnite',
#   'tweets',
#   'later',
#   'lady',
#   'is',
#   'saying',
#   'good',
#   'morning',
#   'that',
#   'crazy',
#   'would',
#   'never',
#   'imagined',
#   'this',
#   'yrs',
#   'ago'],
#  ['at',
#   'the',
#   'nursery',
#   'the',
#   'wailing',
#   'have',
#   'just',
#   'ended',
#   'all',
#   'sleeping',
#   'soundly',
#   'working',
#   'morning',
#   'shift',
#   'tmrw',
#   'grr'],
#  ['at',
#   'the',
#   'random',
#   'mention',
#   'about',
#   'core',
#   'deals',
#   'that',
#   'are',
#   'almost',
#   'twice',
#   'as',
#   'much',
#   'sense',
#   'as',
#   'it',
#   'not',
#   'tied',
#   'to',
#   'himself',
#   'about',
#   'tv',
#   'every',
#   'night'],
#  ['awake',
#   'finally',
#   'random',
#   'dream',
#   'was',
#   'penguin',
#   'but',
#   'lived',
#   'in',
#   'jersey',
#   'and',
#   'oddly',
#   'lived',
#   'in',
#   'icecream',
#   'store',
#   'lolz'],
#  ['awesome', 'black', 'coffee', 'anyone'],
#  ['aww', 'great', 'song', 'picture', 'to', 'burn'],
#  ['baby',
#   'sitting',
#   'today',
#   'shopping',
#   'tomorrow',
#   'rue',
#   'is',
#   'the',
#   'best',
#   'ever'],
#  ['baby',
#   'you',
#   'like',
#   'my',
#   'favorite',
#   'dessert',
#   'just',
#   'can',
#   'not',
#   'get',
#   'enough',
#   'of',
#   'you',
#   'love',
#   'you',
#   'yours',
#   'eva'],
#  ['back', 'to', 'basics'],
#  ['bahahaha',
#   'me',
#   'and',
#   'jodie',
#   'burst',
#   'out',
#   'doing',
#   'kevin',
#   'sos',
#   'dance',
#   'epiccc',
#   'xd'],
#  ['bas', 'one', 'last', 'time', 'update', 'my', 'status'],
#  ['baseball'],
#  ['been', 'up', 'for', 'days', 'straight', 'lol', 'never', 'sleep'],
#  ['such', 'nice', 'day'],
#  ['summertime', 'by', 'dj', 'jazzy', 'jeff', 'and', 'the', 'fresh', 'prince'],
#  ['the', 'weather', 'is', 'lushhh'],
#  ['third', 'date', 'went', 'well', 'moving', 'on', 'to', 'fourth'],
#  ['to',
#   'the',
#   'death',
#   'an',
#   'awesome',
#   'random',
#   'comic',
#   'for',
#   'the',
#   'certifiably',
#   'not',
#   'sane'],
#  ['twilight'],
#  ['two', 'more', 'days'],
#  ['what', 'canadians', 'have', 'to', 'be', 'proud', 'of'],
#  ['xd', 'go', 'day'],
#  ['yay',
#   'for',
#   'star',
#   'testing',
#   'week',
#   'start',
#   'school',
#   'at',
#   'am',
#   'this',
#   'week',
#   'and',
#   'have',
#   'no',
#   'school',
#   'on',
#   'thursday',
#   'maybe',
#   'sf'],
#  ['hello',
#   'world',
#   'this',
#   'is',
#   'where',
#   'live',
#   'beautiful',
#   'am',
#   'woop',
#   'bed',
#   'now'],
#  ['shortstack',
#   'tokiohotel',
#   'shortstack',
#   'tokiohotel',
#   'shortstack',
#   'tokiohotel',
#   'shortstack',
#   'tokiohotel',
#   'shortstack',
#   'tokiohotel',
#   'shortstack'],
#  ['free'],
#  ['that', 'me', 'smiling'],
#  ['nintendo',
#   'dsi',
#   'portable',
#   'game',
#   'system',
#   'what',
#   'will',
#   'you',
#   'and',
#   'do'],
#  ['promote',
#   'my',
#   'site',
#   'getting',
#   'to',
#   'the',
#   'front',
#   'page',
#   'and',
#   'other',
#   'places',
#   'in',
#   'social',
#   'media'],
#  ['the',
#   'universe',
#   'is',
#   'living',
#   'being',
#   'and',
#   'it',
#   'conscious',
#   'and',
#   'it',
#   'very',
#   'old',
#   'and',
#   'it',
#   'cares',
#   'about',
#   'itself',
#   'in',
#   'lots',
#   'of',
#   'ways',
#   'drunvalo',
#   'melchizedek'],
#  ['the', 'world', 'makes', 'music', 'for', 'people', 'who', 'listen'],
#  ['will', 'digg', 'new', 'share', 'feature', 'pollute', 'twitter'],
#  ['exited',
#   'just',
#   'bought',
#   'some',
#   'oreos',
#   'hope',
#   'everyone',
#   'likes',
#   'oreos'],
#  ['babbbbbbbbyy', 'missed', 'you', 'much'],
#  ['well',
#   'then',
#   'you',
#   'gon',
#   'have',
#   'to',
#   'stop',
#   'that',
#   'idc',
#   'shit',
#   'just',
#   'be',
#   'faithful',
#   'like',
#   'points',
#   'to',
#   'em',
#   'moi'],
#  ['its', 'jonas', 'day'],
#  ['the', 'last', 'gadget', 'geek', 'and', 'poke'],
#  ['july', 'flowers', 'july', 'holiday'],
#  ['finally', 'got', 'twitter', 'haha'],
#  ['think',
#   'there',
#   'may',
#   'be',
#   'connection',
#   'between',
#   'paul',
#   'reubens',
#   'and',
#   'the',
#   'reason',
#   'why',
#   'movie',
#   'theater',
#   'fl'],
#  ['temperature',
#   'is',
#   'down',
#   'but',
#   'the',
#   'pain',
#   'is',
#   'still',
#   'bad',
#   'hoping',
#   'antibiotics',
#   'kick',
#   'in',
#   'soon',
#   'thanks',
#   'for',
#   'asking'],
#  ['said', 'tweets', 'less', 'these', 'days', 'so', 'hi'],
#  ['would',
#   'love',
#   'to',
#   'see',
#   'you',
#   'guys',
#   'sometime',
#   'grin',
#   'and',
#   'aw',
#   'rats',
#   'maybe',
#   'it',
#   'll',
#   'warm',
#   'up',
#   'real',
#   'fast',
#   'lol'],
#  ['to', 'all', 'you'],
#  ['what', 'happened', 'while', 'was', 'gone', 'anybody', 'get', 'arrested'],
#  ['ll',
#   'know',
#   'if',
#   'can',
#   'not',
#   'find',
#   'replacement',
#   'me',
#   'll',
#   'still',
#   'pay',
#   'if',
#   'not',
#   'will',
#   'not',
#   'let',
#   'hang'],
#  ['seeing',
#   'guy',
#   'dressed',
#   'up',
#   'as',
#   'banana',
#   'totally',
#   'made',
#   'my',
#   'day',
#   'phallic',
#   'symbol',
#   'ftw'],
#  ['yep', 'coz', 'of', 'the', 'england', 'game', 'on', 'wednesday'],
#  ['there', 'my', 'boo', 'blushes'],
#  ['byyeee', 'ily', 'jamarcusssssss'],
#  ['you', 'aint', 'gotta', 'apologize', 'know', 'not', 'ugly'],
#  ['that', 'is', 'all'],
#  ['butterfly', 'day', 'jun', 'holiday'],
#  ['what', 'does', 'it', 'means'],
#  ['work',
#   'only',
#   'hours',
#   'of',
#   'it',
#   'today',
#   'and',
#   'then',
#   'weeeekend',
#   'can',
#   'not',
#   'wait',
#   'for',
#   'the',
#   'long',
#   'weekend',
#   'to',
#   'begin',
#   'gonna',
#   'get',
#   'some',
#   'things',
#   'done',
#   'for',
#   'sure'],
#  ['praying',
#   'for',
#   'my',
#   'cold',
#   'to',
#   'go',
#   'to',
#   'my',
#   'head',
#   'because',
#   'skunk',
#   'just',
#   'sprayed',
#   'my',
#   'yard',
#   'this',
#   'is',
#   'the'],
#  ['created',
#   'from',
#   'the',
#   'realms',
#   'of',
#   'light',
#   'pure',
#   'love',
#   'commands',
#   'the',
#   'fold',
#   'when',
#   'you',
#   'think',
#   'and',
#   'speak',
#   'with',
#   'love',
#   'new',
#   'world',
#   'you',
#   'll',
#   'behold'],
#  ['the',
#   'music',
#   'was',
#   'so',
#   'quiet',
#   'that',
#   'he',
#   'was',
#   'sure',
#   'there',
#   'was',
#   'massive',
#   'hoax',
#   'being',
#   'played',
#   'on',
#   'him',
#   'alone'],
#  ['speaking',
#   'as',
#   'historian',
#   'wtf',
#   'do',
#   'you',
#   'incorporate',
#   'twitter',
#   'buzz',
#   'by',
#   'upper',
#   'middle',
#   'class',
#   'north',
#   'ame'],
#  ['yes',
#   'before',
#   'the',
#   'show',
#   'suggested',
#   'that',
#   'we',
#   'ought',
#   'to',
#   'do',
#   'celebrity',
#   'deathmatch'],
#  ['dear',
#   'hyper',
#   'chihuahua',
#   'we',
#   'only',
#   'have',
#   'minutes',
#   'left',
#   'together',
#   'on',
#   'this',
#   'drive',
#   'but',
#   'have'],
#  ['washington',
#   'capitals',
#   'would',
#   'be',
#   'one',
#   'of',
#   'myweakness',
#   'as',
#   'well'],
#  ['looking',
#   'fwd',
#   'to',
#   'twitpic',
#   'of',
#   'selma',
#   'soon',
#   'cool',
#   'name',
#   'add',
#   'to',
#   'the',
#   'end',
#   'and',
#   'it',
#   'tok',
#   'ra'],
#  ['yea', 'really', 'wanna', 'see', 'win', 'for', 'him', 'at', 'daytona'],
#  ['great', 'to', 'follow'],
#  ['aww',
#   'sorry',
#   'bae',
#   'kno',
#   'be',
#   'grindin',
#   'but',
#   'got',
#   'swear',
#   'needa',
#   'go',
#   'buy',
#   'an',
#   'artbook',
#   'that',
#   'or',
#   'construction',
#   'paper'],
#  ['nobody',
#   'told',
#   'me',
#   'violent',
#   'femmes',
#   'covered',
#   'gnarls',
#   'barkley',
#   'tks',
#   'dude'],
#  ['started',
#   'working',
#   'on',
#   'warm',
#   'fluffy',
#   'fart',
#   'tweet',
#   'before',
#   'realizing',
#   'don',
#   'especially',
#   'like',
#   'far'],
#  ['news', 'google', 'getting', 'twitterpated'],
#  ['lol', 'nooooooooo'],
#  ['thanx',
#   'for',
#   'the',
#   'post',
#   'the',
#   'warm',
#   'wishes',
#   'enjoy',
#   'ur',
#   'day'],
#  ['youu', 'welcomee'],
#  ['if',
#   'thru',
#   'the',
#   'miracle',
#   'of',
#   'modern',
#   'science',
#   'bruce',
#   'and',
#   'danny',
#   'had',
#   'child'],
#  ['now',
#   'try',
#   'sex',
#   'in',
#   'bing',
#   'deactivate',
#   'safe',
#   'search',
#   'and',
#   'go',
#   'to',
#   'video',
#   'you',
#   'are',
#   'now',
#   'on',
#   'porn',
#   'site',
#   'without',
#   'lea'],
#  ['is', 'not', 'at', 'thanks'],
#  ['well',
#   'praise',
#   'the',
#   'lord',
#   'gud',
#   'moods',
#   'kno',
#   'need',
#   'im',
#   'workn',
#   'out',
#   'ma',
#   'thighs',
#   'these',
#   'dark',
#   'clouds',
#   'is',
#   'scaring',
#   'me'],
#  ['aw',
#   'sweet',
#   'leslie',
#   'was',
#   'tweeting',
#   'luv',
#   'last',
#   'night',
#   'you',
#   'are',
#   'my',
#   'and',
#   'absolute',
#   'fave'],
#  ['big',
#   'ass',
#   'kool',
#   'aid',
#   'smile',
#   'on',
#   'my',
#   'face',
#   'from',
#   'talkin',
#   'to',
#   'my',
#   'boo'],
#  ['blowdrying', 'my', 'hair'],
#  ['bored', 'doing', 'nothing', 'at', 'all', 'okay', 'pretty', 'shy', 'girl'],
#  ['boredddd', 'going', 'to', 'do', 'powerpoint'],
#  ['bosco', 'graduation', 'then', 'sara', 'voice', 'recital'],
#  ['breakfast', 'with', 'family'],
#  ['britains',
#   'got',
#   'talent',
#   'on',
#   'right',
#   'now',
#   'good',
#   'luck',
#   'susan',
#   'boyle'],
#  ['but',
#   'suddenly',
#   'something',
#   'happens',
#   'write',
#   'it',
#   'in',
#   'portuguese'],
#  ['can', 'not', 'wait', 'for', 'hills', 'finale', 'tonight'],
#  ['can', 'not', 'wait', 'for', 'the', 'weekend', 'bmth', 'on', 'saturday'],
#  ['certification',
#   'test',
#   'at',
#   'this',
#   'morning',
#   'feeling',
#   'much',
#   'better',
#   'about',
#   'this',
#   'one',
#   'today'],
#  ['changin',
#   'my',
#   'name',
#   'to',
#   'ambergirl',
#   'haha',
#   'my',
#   'youtube',
#   'name',
#   'and',
#   'it',
#   'mathces',
#   'my',
#   'background'],
#  ['chilling', 'with', 'my', 'niggahz', 'haley', 'and', 'dylan'],
#  ['chocolate', 'cake', 'with', 'delicious', 'strawberry', 'yummy', 'yummy'],
#  ['church',
#   'with',
#   'matt',
#   'was',
#   'good',
#   'think',
#   'going',
#   'to',
#   'be',
#   'churchgirl',
#   'now'],
#  ['city', 'tonight', 'for', 'mae'],
#  ['come',
#   'to',
#   'manchester',
#   'while',
#   'your',
#   'in',
#   'england',
#   'id',
#   'love',
#   'to',
#   'meet',
#   'you',
#   'did',
#   'you',
#   'have',
#   'fun',
#   'in',
#   'germany',
#   'its',
#   'beautiful',
#   'love',
#   'it',
#   'xx'],
#  ['coming',
#   'up',
#   'to',
#   'the',
#   'home',
#   'stretch',
#   'now',
#   'with',
#   'this',
#   'fic',
#   'yay'],
#  ['congrats',
#   'to',
#   'al',
#   'newest',
#   'state',
#   'senator',
#   'elect',
#   'democrat',
#   'mark',
#   'keahey',
#   'alpolitics'],
#  ['content', 'made', 'pac', 'lets', 'see', 'how', 'long', 'it', 'last'],
#  ['cookies', 'the', 'first', 'time'],
#  ['def',
#   'have',
#   'no',
#   'studio',
#   'so',
#   'ur',
#   'jus',
#   'gunna',
#   'get',
#   'the',
#   'lyrics',
#   'shrug'],
#  ['did',
#   'not',
#   'have',
#   'time',
#   'updating',
#   'because',
#   'was',
#   'busy',
#   'enjoying',
#   'this',
#   'love',
#   'making',
#   'sleep',
#   'with',
#   'no',
#   'clothes',
#   'on',
#   'eating',
#   'bbq',
#   'weather',
#   'miss',
#   'this'],
#  ['dinner', 'bath', 'workout', 'run'],
#  ['diplomatic',
#   'husband',
#   'to',
#   'his',
#   'wife',
#   'how',
#   'do',
#   'expect',
#   'me',
#   'to',
#   'remember',
#   'ur',
#   'birthday',
#   'when',
#   'never',
#   'look',
#   'any',
#   'older',
#   'via'],
#  ['do', 'not', 'forget', 'to', 'vote', 'today'],
#  ['tweetwrath',
#   'think',
#   'just',
#   'coined',
#   'new',
#   'word',
#   'where',
#   'is',
#   'that',
#   'twitter',
#   'dictionary'],
#  ['funny',
#   'fact',
#   'has',
#   'about',
#   'his',
#   'town',
#   'population',
#   'following',
#   'him',
#   'on',
#   'tumblr',
#   'how',
#   'does'],
#  ['am',
#   'gonna',
#   'miss',
#   'you',
#   'too',
#   'if',
#   'it',
#   'really',
#   'gonna',
#   'be',
#   'years',
#   'might',
#   'end',
#   'up',
#   'visiting',
#   'you',
#   'in',
#   'aussie',
#   'land',
#   'wish'],
#  ['is', 'taking', 'me', 'to', 'lunch', 'today'],
#  ['lmao'],
#  ['twitter',
#   'maintenance',
#   'on',
#   'friday',
#   'night',
#   'they',
#   'really',
#   'have',
#   'not',
#   'been',
#   'listening',
#   'if',
#   'they',
#   'think',
#   'we',
#   'wo'],
#  ['are',
#   'you',
#   'exe',
#   'do',
#   'er',
#   'ppt',
#   'talk',
#   'er',
#   'or',
#   'txt',
#   'leafy',
#   'potted',
#   'plant'],
#  ['that', 'lovely', 'compliment', 'thx', 'much'],
#  ['thankyou'],
#  ['awesome', 'th', 'quarter', 'ladies', 'great', 'game'],
#  ['quite', 'the', 'opposite'],
#  ['night', 'and', 'thanks', 'for', 'the', 'call'],
#  ['no',
#   'do',
#   'know',
#   'the',
#   'difference',
#   'like',
#   'say',
#   'it',
#   'been',
#   'long',
#   'time',
#   'very',
#   'long',
#   'time'],
#  ['thank', 'you', 'am', 'genuinely', 'grateful'],
#  ['so',
#   'pretty',
#   'much',
#   'you',
#   'look',
#   'like',
#   'candy',
#   'floss',
#   'machine',
#   'today'],
#  ['posterous',
#   'looks',
#   'like',
#   'tumblr',
#   'for',
#   'iphone',
#   'looks',
#   'interesting',
#   'can',
#   'you',
#   'fold',
#   'this',
#   'content'],
#  ['dt', 'tonight', 'dt', 'tomorrow', 'day', 'night', 'beauty'],
#  ['elise', 'and', 'melanie', 'are', 'the', 'shiz'],
#  ['every',
#   'so',
#   'often',
#   'catch',
#   'my',
#   'own',
#   'reflection',
#   'think',
#   'now',
#   'that',
#   'one',
#   'cool',
#   'son',
#   'of',
#   'tch',
#   'today',
#   'one',
#   'of',
#   'those',
#   'days'],
#  ['explore', 'twitter'],
#  ['famed', 'michigan', 'bookstore', 'to', 'close', 'its', 'doors'],
#  ['field', 'trip', 'today', 'leaving', 'now'],
#  ['finally',
#   'at',
#   'home',
#   'bout',
#   'to',
#   'napp',
#   'then',
#   'get',
#   'ready',
#   'for',
#   'college',
#   'tomorrow',
#   'ughhh',
#   'sooo',
#   'excited'],
#  ['followfriday', 'these', 'ppl', 'or', 'catch', 'crabs'],
#  ['it',
#   'light',
#   'with',
#   'bit',
#   'of',
#   'punch',
#   'mission',
#   'san',
#   'francisco',
#   'gin',
#   'mexican',
#   'liqueur',
#   'seemed',
#   'an',
#   'apt',
#   'name'],
#  ['am',
#   'super',
#   'emo',
#   'about',
#   'stupid',
#   'stuff',
#   'rn',
#   'and',
#   'sg',
#   'is',
#   'making',
#   'me',
#   'feel',
#   'better'],
#  ['if', 'anyone', 'else', 'said', 'something', 'it', 'to', 'you', 'too'],
#  ['yeahuhh'],
#  ['lmao'],
#  ['just',
#   'said',
#   'on',
#   'flickr',
#   're',
#   'mac',
#   'that',
#   'would',
#   'not',
#   'install',
#   'os',
#   'yes',
#   'as',
#   'user',
#   'focused',
#   'design',
#   'goes',
#   'this',
#   'is',
#   'an',
#   'exploding',
#   'colostomy',
#   'bag'],
#  ['lvatt', 'is', 'comming'],
#  ['happy', 'sunday'],
#  ['ncaa', 'national', 'softball', 'champions', 'uw', 'huskies'],
#  ['first',
#   'days',
#   'are',
#   'always',
#   'good',
#   'wish',
#   'my',
#   'dentist',
#   'gave',
#   'me',
#   'more',
#   'hours',
#   'though'],
#  ['found', 'way', 'to', 'make', 'this', 'private', 'woot', 'woot'],
#  ['fucking', 'rur', 'mom'],
#  ['fwd',
#   'good',
#   'morn',
#   'happy',
#   'birthday',
#   'regardless',
#   'of',
#   'what',
#   'ppl',
#   'said',
#   'yesterday',
#   'they',
#   'do',
#   'not',
#   'realize',
#   'what',
#   'happend',
#   'behind',
#   'the',
#   'scene',
#   'one',
#   'of',
#   'the'],
#  ['getting', 'mani', 'pedi', 'with', 'the', 'husband'],
#  ['getting', 'webcam', 'today'],
#  ['getting',
#   'ready',
#   'to',
#   'watch',
#   'the',
#   'sprint',
#   'cup',
#   'boys',
#   'try',
#   'to',
#   'tame',
#   'the',
#   'concrete',
#   'monster',
#   'mile',
#   'hopefully',
#   'tires',
#   'will',
#   'not',
#   'be',
#   'too',
#   'much',
#   'of',
#   'an',
#   'issue'],
#  ['night',
#   'tweeties',
#   'talk',
#   'to',
#   'you',
#   'all',
#   'in',
#   'the',
#   'am',
#   'haha',
#   'you',
#   'have',
#   'work',
#   'in',
#   'the',
#   'am'],
#  ['go', 'follow', 'my', 'personal', 'twitter'],
#  ['go', 'wings', 'ftw'],
#  ['god',
#   'up',
#   'early',
#   'hayley',
#   'still',
#   'asleep',
#   'but',
#   'today',
#   'is',
#   'party',
#   'day',
#   'so',
#   'getting',
#   'stuff',
#   'ready'],
#  ['going',
#   'home',
#   'to',
#   'see',
#   'my',
#   'baby',
#   'dont',
#   'be',
#   'ashamed',
#   'of',
#   'your',
#   'faith'],
#  ['going', 'out', 'for', 'dinner', 'with', 'the', 'family'],
#  ['going', 'to', 'bed'],
#  ['going', 'to', 'bed'],
#  ['going', 'to', 'london', 'expo', 'this', 'weekend', 'can', 'not', 'wait'],
#  ['goingg', 'to', 'sleep', 'school', 'then', 'out', 'for', 'pizzaa'],
#  ['gonna', 'wow', 'for', 'bit', 'later', 'twitter'],
#  ['good', 'morning', 'lovely'],
#  ['good', 'morning', 'afternoon', 'things', 'will', 'be', 'great', 'today'],
#  ['ff',
#   'ff',
#   'them',
#   'tommy',
#   'chi',
#   'allday',
#   'sly',
#   'fly',
#   'juncity',
#   'manhattan',
#   'atl',
#   'owww',
#   'wordsmith',
#   'fiyah'],
#  ['online',
#   'reality',
#   'blogging',
#   'tweets',
#   'my',
#   'life',
#   'on',
#   'the',
#   'social',
#   'media',
#   'list'],
#  ['ooh',
#   'but',
#   'clean',
#   'sheet',
#   'day',
#   'is',
#   'awesome',
#   'woo',
#   'hope',
#   'you',
#   're',
#   'feeling',
#   'better',
#   'now'],
#  ['think',
#   've',
#   'won',
#   'the',
#   'battle',
#   'over',
#   'the',
#   'impending',
#   'crud',
#   'enjoy',
#   'your',
#   'drive',
#   'this',
#   'am'],
#  ['crickey',
#   'can',
#   'not',
#   'think',
#   'that',
#   'far',
#   'ahead',
#   'think',
#   'getting',
#   'to',
#   'followers',
#   'is',
#   'pretty',
#   'ambitious'],
#  ['coffee',
#   'keeps',
#   'me',
#   'running',
#   'in',
#   'fact',
#   'without',
#   'coffee',
#   'would',
#   'not',
#   'get',
#   'any',
#   'exercise',
#   'at',
#   'all'],
#  ['bookmarked',
#   'it',
#   'and',
#   'will',
#   'check',
#   'it',
#   'out',
#   'after',
#   'get',
#   'some',
#   'sleep',
#   'thanks',
#   'sam'],
#  ['it', 'is', 'always', 'your', 'next', 'move', 'napoleon', 'hil'],
#  ['ur', 'hot'],
#  ['that',
#   'it',
#   'removing',
#   'bots',
#   'is',
#   'like',
#   'weeding',
#   'garden',
#   'not',
#   'fun',
#   'but',
#   'must',
#   'be',
#   'done',
#   'eventually'],
#  ['hubby',
#   'has',
#   'briso',
#   'on',
#   'dvd',
#   'have',
#   'not',
#   'seen',
#   'it',
#   'all',
#   'yet',
#   'but',
#   'enjoy',
#   'it',
#   'saw',
#   'army',
#   'of',
#   'darkness',
#   'and',
#   'evil',
#   'dead',
#   'because',
#   'of',
#   'hubs',
#   'too'],
#  ['what',
#   'considerate',
#   'tooth',
#   'fairy',
#   'you',
#   'are',
#   'checking',
#   'to',
#   'make',
#   'sure',
#   'you',
#   'did',
#   'not',
#   'miss',
#   'anyone'],
#  ['we',
#   'are',
#   'perfectly',
#   'on',
#   'schedule',
#   'nobody',
#   'is',
#   'waisting',
#   'time',
#   'today',
#   'do',
#   'not',
#   'mention',
#   'the',
#   'sun',
#   'again',
#   'dedicated',
#   'audience'],
#  ['my',
#   'twenties',
#   'look',
#   'bed',
#   'wonder',
#   'what',
#   'we',
#   'can',
#   'do',
#   'my',
#   'thirties',
#   'look',
#   'be',
#   'zzzzzzzzzzzzz'],
#  ['if',
#   'it',
#   'were',
#   'not',
#   'for',
#   'unspeakable',
#   'things',
#   'do',
#   'not',
#   'know',
#   'what',
#   'do'],
#  ['bellacullen',
#   've',
#   'been',
#   'ok',
#   'just',
#   'got',
#   'through',
#   'crying',
#   'with',
#   'leah',
#   'frowns',
#   'at',
#   'the',
#   'thought',
#   'we',
#   'were',
#   'talking',
#   'about',
#   'our',
#   'dead',
#   'fathers'],
#  ['cooking'],
#  ['ncis'],
#  ['follower', 'wow'],
#  ['followers', 'yay'],
#  ['makee', 'wishhh', 'goodnight'],
#  ['know', 'what', 'wishing', 'for'],
#  ['days',
#   'until',
#   'the',
#   'jb',
#   'concert',
#   'in',
#   'milan',
#   'guarding',
#   'my',
#   'tickets'],
#  ['days', 'of', 'no', 'twittering', 'and', 'back', 'think'],
#  ['lbs', 'lost', 'since', 'feb', 'still', 'have', 'lot', 'more', 'to', 'go'],
#  ['good', 'night', 'okay', 'got', 'really', 'nothing', 'to', 'say'],
#  ['good', 'night', 'arrgghhhh', 'do', 'work', 'boys'],
#  ['good', 'to', 'hear', 'from', 'you'],
#  ['good', 'weekend'],
#  ['goodnight',
#   'math',
#   'spanish',
#   'finals',
#   'tomorrow',
#   'spanish',
#   'should',
#   'be',
#   'easy',
#   'woo'],
#  ['gooooood', 'morning', 'my', 'twitter', 'friends', 'have', 'nice', 'sunday'],
#  ['gossip', 'girl', 'tonight'],
#  ['got', 'escala', 'new', 'album', 'now', 'is', 'very', 'good'],
#  ['got',
#   'new',
#   'photoshop',
#   'magazine',
#   'but',
#   'need',
#   'my',
#   'dad',
#   'portable',
#   'cd',
#   'drive',
#   'to',
#   'use',
#   'the',
#   'cd',
#   'with',
#   'the',
#   'pics',
#   'on',
#   'it',
#   'think',
#   'stuck',
#   'there',
#   'tomorrow'],
#  ['gotta',
#   'love',
#   'her',
#   'glad',
#   'she',
#   'had',
#   'fun',
#   'looking',
#   'forward',
#   'to',
#   'the',
#   'beach',
#   'her'],
#  ['great',
#   'day',
#   'people',
#   'watching',
#   'in',
#   'berkeley',
#   'with',
#   'my',
#   'bro',
#   'love',
#   'him'],
#  ['great', 'nite'],
#  ['great', 'tights', 'good', 'outfit'],
#  ['great'],
#  ['had',
#   'good',
#   'night',
#   'love',
#   'my',
#   'best',
#   'buds',
#   'in',
#   'the',
#   'world',
#   'adamcheeeserosie'],
#  ['had', 'really', 'good', 'night', 'stoked', 'for', 'things', 'to', 'come'],
#  ['had', 'an', 'ok', 'day', 'it', 'went', 'by', 'fast'],
#  ['hah',
#   'that',
#   'was',
#   'awesome',
#   'just',
#   'listened',
#   'to',
#   'you',
#   'pretty',
#   'cool',
#   'love',
#   'for',
#   'crying',
#   'out',
#   'loud'],
#  ['haha',
#   'really',
#   'did',
#   'and',
#   'about',
#   'to',
#   'call',
#   'music',
#   'unlimited',
#   'tomorrow',
#   'for',
#   'simon',
#   'tryin',
#   'to',
#   'be',
#   'like',
#   'rod'],
#  ['for', 'my', 'msc', 'assignment', 'that', 'was', 'incomplete', 'relief'],
#  ['actually', 'might', 'be', 'crazy', 'cause', 'love', 'my', 'job'],
#  ['actually',
#   'quite',
#   'happy',
#   'toady',
#   'apart',
#   'from',
#   'the',
#   'agony',
#   'all',
#   'over',
#   'my',
#   'body',
#   'and',
#   'not',
#   'being',
#   'able',
#   'to',
#   'go',
#   'outside',
#   'done',
#   'some',
#   'revising',
#   'so',
#   'all',
#   'gd'],
#  ['ah',
#   'belhblehbleh',
#   'the',
#   'familys',
#   'watching',
#   'moviee',
#   'and',
#   'yes',
#   'imm',
#   'beingg',
#   'computerr',
#   'nerd',
#   'and',
#   'wish',
#   'jerkface',
#   'would',
#   'wake',
#   'up',
#   'onee',
#   'daaayyyy'],
#  ['alright',
#   'back',
#   'onto',
#   'being',
#   'bored',
#   'going',
#   'to',
#   'bed',
#   'any',
#   'time',
#   'soon',
#   'have',
#   'to',
#   'get',
#   'up',
#   'early'],
#  ['and',
#   'hug',
#   'is',
#   'there',
#   'waiting',
#   'line',
#   'to',
#   'get',
#   'into',
#   'club',
#   'blip'],
#  ['and',
#   'dunno',
#   'why',
#   'but',
#   'with',
#   'you',
#   'dance',
#   'in',
#   'storm',
#   'in',
#   'my',
#   'best',
#   'dress'],
#  ['annnnnd',
#   'website',
#   'has',
#   'launched',
#   'bookmark',
#   'it',
#   'check',
#   'back',
#   'often',
#   'itinerary',
#   'added',
#   'soon'],
#  ['days',
#   'to',
#   'the',
#   'musical',
#   'gonna',
#   'dance',
#   'wow',
#   'wow',
#   'wow',
#   'it',
#   'gonna',
#   'be',
#   'something',
#   'like',
#   'high',
#   'school',
#   'musical',
#   'ihihih',
#   'xoxo',
#   'petia'],
#  ['goodmorning', 'back', 'at', 'cha'],
#  ['perfect', 'weekend'],
#  ['pony',
#   'clop',
#   'clopping',
#   'down',
#   'the',
#   'hill',
#   'heard',
#   'him',
#   'long',
#   'before',
#   'saw',
#   'him',
#   'this',
#   'would',
#   'so',
#   'not',
#   'happen',
#   'in',
#   'brooklyn',
#   'barring',
#   'cop',
#   'on',
#   'horseback'],
#  ['adorei',
#   'zoffitcha',
#   'hj',
#   'dps',
#   'ponho',
#   'foto',
#   'no',
#   'tpic',
#   'goodnight',
#   'twitters'],
#  ['aint', 'supposed', 'to', 'be', 'happy'],
#  ['all', 'done', 'time', 'to', 'finally', 'start', 'shuting', 'down'],
#  ['all',
#   'smiles',
#   'im',
#   'fairly',
#   'hapy',
#   'with',
#   'what',
#   'has',
#   'happened',
#   'yesterday',
#   'even',
#   'though',
#   'some',
#   'other',
#   'had',
#   'to',
#   'put',
#   'damper',
#   'on',
#   'things',
#   'cough'],
#  ['all', 'the', 'snow', 'is', 'gone', 'that', 'did', 'not', 'take', 'long'],
#  ['almost',
#   'done',
#   'wit',
#   'the',
#   'painting',
#   'tired',
#   'as',
#   'crap',
#   'sleep',
#   'time',
#   'in',
#   'love',
#   'with',
#   'ziggy',
#   'marley',
#   'and',
#   'erykah',
#   'badu'],
#  ['also',
#   'made',
#   'masterful',
#   'roast',
#   'dinner',
#   'followed',
#   'by',
#   'apple',
#   'crumble',
#   'yum',
#   'need',
#   'gym',
#   'this',
#   'week',
#   'though'],
#  ['am', 'updates', 'in', 'twitter', 'stats'],
#  ['am',
#   'too',
#   'immature',
#   'for',
#   'year',
#   'old',
#   'just',
#   'really',
#   'like',
#   'ninja',
#   'ponies',
#   'that',
#   'have',
#   'only',
#   'legs'],
#  ['haha',
#   'someone',
#   'do',
#   'not',
#   'even',
#   'know',
#   'made',
#   'me',
#   'laugh',
#   'ryan',
#   'ross',
#   'win'],
#  ['hanging', 'out', 'with', 'steven', 'mohler', 'on', 'sunday', 'ah'],
#  ['happy',
#   'birthday',
#   'to',
#   'me',
#   'and',
#   'mom',
#   'why',
#   'am',
#   'always',
#   'the',
#   'first',
#   'one',
#   'up',
#   'so',
#   'here',
#   'am',
#   'falling',
#   'off',
#   'the',
#   'bed',
#   'cuz',
#   'someone',
#   'is',
#   'bed',
#   'hog'],
#  ['happy', 'face'],
#  ['happy', 'that', 'its', 'sunny'],
#  ['happy', 'to', 'see', 'him'],
#  ['happy', 'with', 'the', 'way', 'thing', 'are', 'goingg'],
#  ['happy', 'knowing', 'my', 'friends', 'are', 'still', 'my', 'friends'],
#  ['happy', 'spending', 'time', 'with', 'mum'],
#  ['has', 'just', 'got', 'up', 'is', 'listening', 'to', 'good', 'charlotte'],
#  ['has', 'something', 'very', 'special', 'in', 'mind'],
#  ['have', 'nice', 'day'],
#  ['have', 'nice', 'day', 'cause', 'will'],
#  ['havent', 'updated', 'in', 'forever'],
#  ['havin', 'fun', 'my', 'friend'],
#  ['healthy',
#   'butcher',
#   'exclusive',
#   'cheese',
#   'sexy',
#   'bread',
#   'lovely',
#   'beer',
#   'some',
#   'super',
#   'sparkly',
#   'wine',
#   'apple',
#   'fucking',
#   'tango',
#   'are',
#   'all',
#   'inside',
#   'my',
#   'belly'],
#  ['heard',
#   'it',
#   'on',
#   'pandora',
#   'because',
#   'that',
#   'site',
#   'is',
#   'that',
#   'cool'],
#  ['hee', 'hee', 'your', 'so', 'weird', 'and', 'did', 'not', 'shiver'],
#  ['hey',
#   'terri',
#   'the',
#   'game',
#   'is',
#   'not',
#   'too',
#   'expensive',
#   'but',
#   'over',
#   'time',
#   'you',
#   'll',
#   'have',
#   'made',
#   'quite',
#   'an',
#   'investment'],
#  ['hey', 'back', 'if', 'someone', 'want', 'to', 'talk', 'here', 'am'],
#  ['hmm', 'emotionless'],
#  ['home',
#   'finally',
#   'making',
#   'fettuccine',
#   'and',
#   'relaxing',
#   'my',
#   'sore',
#   'feetsies'],
#  ['home', 'sweet', 'home', 'finally', 'back', 'xd'],
#  ['homeish',
#   'lol',
#   'hella',
#   'fun',
#   'day',
#   'thanks',
#   'leela',
#   'thai',
#   'thanks',
#   'paul',
#   'thanks',
#   'michelle',
#   'mufid',
#   'cristina',
#   'kittykat',
#   'awkward',
#   'moose'],
#  ['any',
#   'comment',
#   'on',
#   'the',
#   'latest',
#   'star',
#   'trek',
#   'movie',
#   'is',
#   'it',
#   'nice'],
#  ['any', 'day', 'now', 'any', 'way', 'now', 'shall', 'be', 'released'],
#  ['ap', 'impact', 'alternative', 'medicine', 'goes', 'mainstream'],
#  ['apple', 'store', 'bbl'],
#  ['are', 'you', 'going', 'to', 'be', 'taking', 'photographs', 'tonight'],
#  ['arrrrrrgggh', 'cant', 'wait', 'till', 'next', 'weeeeeeeeek'],
#  ['at',
#   'last',
#   'successful',
#   'deployment',
#   'complete',
#   'soo',
#   'what',
#   'do',
#   'do',
#   'now'],
#  ['at', 'work', 'having', 'postive', 'attitude'],
#  ['awesome'],
#  ['awesome', 'day', 'soooooooooooooo', 'happy'],
#  ['awesome',
#   'man',
#   'miss',
#   'you',
#   'woke',
#   'up',
#   'thinking',
#   'about',
#   'you',
#   'it',
#   'looks',
#   'like',
#   'you',
#   've',
#   'been',
#   'in',
#   'my',
#   'dreams'],
#  ['awesome', 'teddy'],
#  ['aww', 'dont', 'make', 'me', 'blush'],
#  ['baby', 'strampelt', 'fast', 'im', 'takt', 'new', 'soul', 'yael', 'naim'],
#  ['back',
#   'here',
#   'was',
#   'busy',
#   'xd',
#   'wirting',
#   'stars',
#   'loves',
#   'almos',
#   'pages',
#   'xd',
#   'and',
#   'listenint',
#   'afh',
#   'and',
#   'tv'],
#  ['hope', 'you', 'all', 'are', 'having', 'good', 'day', 'night'],
#  ['agree'],
#  ['am', 'back'],
#  ['am', 'bored', 'and', 'ew', 'my', 'dog', 'just', 'killed', 'an', 'insect'],
#  ['am',
#   'falling',
#   'in',
#   'love',
#   'with',
#   'stockington',
#   'such',
#   'witty',
#   'wise',
#   'meow',
#   'meow'],
#  ['am', 'musical', 'today'],
#  ['am', 'very', 'happy', 'today', 'and', 'do', 'not', 'why'],
#  ['beat', 'you', 'video', 'on', 'youtube'],
#  ['can',
#   'not',
#   'wait',
#   'to',
#   'go',
#   'home',
#   'and',
#   'watch',
#   'danny',
#   'phantom',
#   'while',
#   'talking',
#   'to',
#   'stephen'],
#  ['can',
#   'not',
#   'wait',
#   'to',
#   'go',
#   'to',
#   'las',
#   'vegas',
#   'more',
#   'days',
#   'omg'],
#  ['cant',
#   'wait',
#   'to',
#   'watch',
#   'britians',
#   'got',
#   'talent',
#   'dont',
#   'like',
#   'holly'],
#  ['amazing', 'people', 'followfriday'],
#  ['an',
#   'online',
#   'number',
#   'lets',
#   'family',
#   'and',
#   'friends',
#   'call',
#   'you',
#   'at',
#   'local',
#   'rates',
#   'wherever',
#   'you',
#   'are',
#   'in',
#   'the',
#   'world',
#   'loving',
#   'skype'],
#  ['anyone',
#   'else',
#   'on',
#   'dropshots',
#   'my',
#   'id',
#   'is',
#   'katjrobertson',
#   'it',
#   'password',
#   'protected',
#   'tho',
#   'so',
#   'll',
#   'have',
#   'ask',
#   'me'],
#  ['arizona',
#   'real',
#   'estate',
#   'specialist',
#   'view',
#   'all',
#   'homes',
#   'for',
#   'sale',
#   'in',
#   'arizona',
#   'on',
#   'my',
#   'website',
#   'free',
#   'coldwell',
#   'banker'],
#  ['at',
#   'cabaret',
#   'with',
#   'my',
#   'family',
#   'love',
#   'them',
#   'in',
#   'my',
#   'comfort',
#   'zone'],
#  ['at', 'home', 'eating', 'mcdonalds', 'cinnamelts', 'oreo', 'frosty'],
#  ['at', 'my', 'grandmas', 'eating', 'good'],
#  ['at', 'the', 'manila', 'right', 'now'],
#  ['back', 'from', 'shower'],
#  ['back', 'to', 'hotel', 'time', 'to', 'start', 'work'],
#  ['bbl', 'ppl', 'have', 'to', 'go', 'to', 'school'],
#  ['bethenny', 'frankel', 'starred', 'in', 'hollywood', 'hills'],
#  ['bored', 'yo'],
#  ['boring',
#   'wait',
#   'will',
#   'comment',
#   'on',
#   'my',
#   'friend',
#   'in',
#   'fs',
#   'frst'],
#  ['bout', 'to', 'party', 'in', 'tent'],
#  ['brokeback',
#   'mountain',
#   'is',
#   'so',
#   'beautiful',
#   'and',
#   'so',
#   'amazing',
#   'and',
#   'so',
#   'freaking',
#   'sad'],
#  ['brooklyn', 'bridge', 'for', 'the', 'first', 'time', 'ever', 'yay', 'life'],
#  ['but',
#   'caught',
#   'bullet',
#   'boys',
#   'trixter',
#   'pete',
#   'was',
#   'great',
#   'la',
#   'guns',
#   'and',
#   'kix',
#   'who',
#   'stole',
#   'the',
#   'show',
#   'hung',
#   'out',
#   'backstage',
#   'like',
#   'real',
#   'rock',
#   'and',
#   'roller'],
#  ['do',
#   'not',
#   'know',
#   'why',
#   'can',
#   'not',
#   'dm',
#   'from',
#   'my',
#   'phone',
#   'this',
#   'suck'],
#  ['finally', 'have', 'updated', 'from', 'computer', 'thank', 'you', 'dad'],
#  ['be',
#   'careful',
#   'white',
#   'at',
#   'bbq',
#   'is',
#   'high',
#   'risk',
#   'but',
#   'the',
#   'dress',
#   'is',
#   'really',
#   'awesome'],
#  ['beautiful',
#   'day',
#   'here',
#   'on',
#   'stt',
#   'bout',
#   'to',
#   'head',
#   'to',
#   'magens',
#   'bay',
#   'soak',
#   'up',
#   'some',
#   'sun',
#   'loove',
#   'saturdayss'],
#  ['beboing',
#   'twitteringinging',
#   'tving',
#   'dihd',
#   'say',
#   'luv',
#   'twilight',
#   'yet',
#   'wel',
#   'luv',
#   'twilight'],
#  ['bouta', 'watch', 'mall', 'cop'],
#  ['camp',
#   'in',
#   'confirming',
#   'that',
#   'he',
#   'will',
#   'be',
#   'in',
#   'san',
#   'diego',
#   'this',
#   'fall',
#   'for',
#   'the',
#   'prssa',
#   'convention',
#   'haha'],
#  ['can', 'see', 'clearly', 'now', 'the', 'rain', 'is', 'gone'],
#  ['can', 'yah', 'figure', 'it', 'outt'],
#  ['can', 'not', 'see', 'his', 'copper', 'green', 'guys', 'though'],
#  ['can', 'not', 'sleep', 'must', 'be', 'the', 'time', 'change', 'right'],
#  ['can',
#   'not',
#   'stop',
#   'smiling',
#   'after',
#   'talking',
#   'to',
#   'him',
#   'all',
#   'day',
#   'why',
#   'could',
#   'not',
#   'have',
#   'met',
#   'him',
#   'months',
#   'ago'],
#  ['cant', 'waiit', 'xxx'],
#  ['can', 'not', 'wait', 'til', 'wednesday', 'champssss'],
#  ['can',
#   'not',
#   'wait',
#   'to',
#   'get',
#   'my',
#   'share',
#   'of',
#   'her',
#   'check',
#   'today',
#   'lol'],
#  ['cause',
#   'happy',
#   'but',
#   'disappointed',
#   'my',
#   'car',
#   'is',
#   'messing',
#   'up',
#   'my',
#   'poor',
#   'baby',
#   'now',
#   'hungry',
#   'with',
#   'no',
#   'way',
#   'to',
#   'get',
#   'food',
#   'what',
#   'in',
#   'this',
#   'house'],
#  ['change', 'of', 'screen', 'name'],
#  ['charging', 'phone'],
#  ['chillin'],
#  ['chinese',
#   'for',
#   'dinner',
#   'and',
#   'working',
#   'on',
#   'cool',
#   'website',
#   'template',
#   'so',
#   'proud',
#   'of',
#   'myself'],
#  ['choppin', 'it', 'up', 'love', 'you'],
#  ['concert', 'later', 'tonight'],
#  ['cool',
#   'ew',
#   'bought',
#   'the',
#   'things',
#   'they',
#   'carried',
#   'on',
#   'amazon',
#   'it',
#   'came',
#   'like',
#   'shit',
#   'cost',
#   'me',
#   'its',
#   'new'],
#  ['could', 'be'],
#  ['have', 'buzz'],
#  ['have',
#   'finally',
#   'seen',
#   'clerks',
#   'from',
#   'beginning',
#   'to',
#   'end',
#   'and',
#   'no',
#   'tv',
#   'swear',
#   'word',
#   'editing',
#   'poor',
#   'jay',
#   'xd',
#   'feel',
#   'somehow',
#   'fulfilled'],
#  ['have',
#   'not',
#   'been',
#   'on',
#   'twitter',
#   'all',
#   'day',
#   'thought',
#   'make',
#   'some',
#   'late',
#   'twitters'],
#  ['hope', 'everyone', 'has', 'great', 'day'],
#  ['hope', 'you', 'find', 'great', 'trousers'],
#  ['just',
#   'got',
#   'to',
#   'my',
#   'tweet',
#   'do',
#   'get',
#   'prize',
#   'sidebar',
#   'cassidy',
#   'your',
#   'nasty',
#   'why',
#   'gots',
#   'to',
#   'hear',
#   'about',
#   'your',
#   'wide',
#   'peen',
#   'for',
#   'smh'],
#  ['just',
#   'saw',
#   'one',
#   'of',
#   'the',
#   'new',
#   'camaros',
#   'in',
#   'the',
#   'wild',
#   'for',
#   'the',
#   'first',
#   'time',
#   'cool'],
#  ['can', 'not', 'wait', 'to', 'come', 'home'],
# ...
#   'wilder'],
#  ['just', 'saw', 'the', 'hottest', 'thing', 'ever'],
#  ['just',
#   'watched',
#   'my',
#   'son',
#   'be',
#   'promoted',
#   'to',
#   'red',
#   'belt',
#   'karate',
#   'class',
#   'cute',
#   'and',
#   'exciting'],
#  ['know', 'syllable', 'whore', 'sorry', 'but', 'did', 'it', 'on', 'purpose'],
#  ['like',
#   'how',
#   'you',
#   'can',
#   'change',
#   'the',
#   'colour',
#   'of',
#   'stuffs',
#   'on',
#   'bebo',
#   'how',
#   'you',
#   'can',
#   'do',
#   'the',
#   'underline',
#   'italics',
#   'bold',
#   'thingys',
#   'haha'],
#  ['like',
#   'it',
#   'when',
#   'things',
#   'work',
#   'like',
#   'they',
#   'should',
#   'was',
#   'expecting',
#   'this',
#   'upgrade',
#   'to',
#   'break',
#   'something',
#   'bigtime'],
#  ['like', 'you', 'so', 'much', 'better', 'when', 'you', 're', 'naked'],
#  ['loove', 'the', 'songs', 'of', 'david', 'archuleta'],
#  ['love',
#   'getting',
#   'off',
#   'work',
#   'and',
#   'smelling',
#   'the',
#   'scent',
#   'after',
#   'it',
#   'rains',
#   'the',
#   'best'],
#  ['love', 'my', 'fly', 'with', 'me', 'friends', 'and'],
#  ['love',
#   'singing',
#   'along',
#   'with',
#   'my',
#   'baby',
#   'our',
#   'favorite',
#   'song',
#   'is',
#   'the',
#   'best',
#   'and',
#   'sex',
#   'was',
#   'delicious',
#   'hahaha'],
#  ['love', 'you', 'daddy'],
#  ['love', 'you', 'you', 'know', 'who', 'you', 'are'],
#  ['love', 'you', 'jef', 'ivey', 'is', 'bastard', 'save', 'me'],
#  ['meant',
#   've',
#   'been',
#   'thinking',
#   'what',
#   'is',
#   'there',
#   'to',
#   'say',
#   'to',
#   'such',
#   'great',
#   'nation',
#   'only',
#   'that',
#   'they',
#   'remain',
#   'united',
#   'as',
#   'they',
#   'were',
#   'before'],
#  ['might',
#   'get',
#   'in',
#   'trouble',
#   'for',
#   'this',
#   'but',
#   'abby',
#   'does',
#   'not',
#   'count'],
#  ['my', 'cuzdem', 'juss', 'joined'],
#  ['my',
#   'girlies',
#   'are',
#   'going',
#   'to',
#   'be',
#   'here',
#   'in',
#   'approx',
#   'hours',
#   'road',
#   'trip'],
#  ['my', 'hoodie', 'came', 'today', 'thank', 'you'],
#  ['my', 'man', 'is', 'home'],
#  ['my',
#   'mom',
#   'likes',
#   'milow',
#   'version',
#   'of',
#   'ayo',
#   'technology',
#   'it',
#   'good',
#   'thing',
#   'she',
#   'does',
#   'not',
#   'have',
#   'clue',
#   'what',
#   'it',
#   'about'],
#  ['my',
#   'new',
#   'wallpaper',
#   'is',
#   'lxlight',
#   'based',
#   'from',
#   'deathnote',
#   'if',
#   'you',
#   'did',
#   'not',
#   'know'],
#  ['my', 'prom', 'dress', 'please', 'excuse', 'the', 'horrible', 'lighting'],
#  ['love',
#   'morning',
#   'calls',
#   'from',
#   'my',
#   'baby',
#   'amazing',
#   'way',
#   'to',
#   'start',
#   'off',
#   'my',
#   'day'],
#  ['love',
#   'my',
#   'parents',
#   'they',
#   'already',
#   'bought',
#   'me',
#   'movie',
#   'studio',
#   'and',
#   'they',
#   'are',
#   'still',
#   'getting',
#   'me',
#   'camera',
#   'and',
#   'they',
#   'got',
#   'me',
#   'the',
#   'swift',
#   'tickets'],
#  ['love', 'south', 'america'],
#  ['love', 'talking', 'to', 'people', 'that', 'love'],
#  ['love', 'weddings'],
#  ['love', 'you'],
#  ['loved',
#   'today',
#   'ohhh',
#   'missed',
#   'the',
#   'old',
#   'group',
#   'glad',
#   'we',
#   're',
#   'back'],
#  ['made', 'practically', 'every', 'biblical', 'question', 'in', 're', 'up'],
#  ['miss', 'my', 'friend'],
#  ['miss', 'nm', 'awww', 'good', 'times'],
#  ['never',
#   'thought',
#   'the',
#   'word',
#   'randomly',
#   'could',
#   'be',
#   'so',
#   'funny',
#   'until',
#   'my',
#   'husband',
#   'just',
#   'said',
#   'it',
#   'cracking',
#   'up',
#   'haha',
#   'goodnight',
#   'all',
#   'be',
#   'blessed'],
#  ['needd', 'coke', 'reallyy', 'bad', 'video', 'ideass'],
#  ['presented',
#   'my',
#   'script',
#   'to',
#   'the',
#   'production',
#   'in',
#   'class',
#   'and',
#   'they',
#   'liked',
#   'it',
#   'gonna',
#   'be',
#   'an',
#   'interesting',
#   'shooting'],
#  ['rocked',
#   'summerrs',
#   'dot',
#   'dot',
#   'curve',
#   'shirt',
#   'pinstriped',
#   'skinnys',
#   'chuck',
#   'hightops',
#   'glasses',
#   'yen',
#   'necklace'],
#  ['said', 'it', 'like', 'him', 'teehheee'],
#  ['my', 'video', 'is', 'almost', 'uploaded'],
#  ['nice', 'song'],
#  ['think',
#   'finally',
#   'figured',
#   'out',
#   'how',
#   'to',
#   'twitter',
#   'on',
#   'my',
#   'phone'],
#  ['think', 'it', 'would', 'be', 'fun'],
#  ['thought', 'it', 'would', 'be', 'like', 'pm', 'by', 'now'],
#  ['wanna',
#   'write',
#   'some',
#   'reviews',
#   'of',
#   'films',
#   'music',
#   'releases',
#   'so',
#   'go',
#   'leave',
#   'this',
#   'place',
#   'not',
#   'for',
#   'long',
#   'time',
#   'of',
#   'course'],
#  ['want', 'the', 'sims', 'soooo', 'bad'],
#  ['wish', 'had', 'my', 'tablet', 'pen'],
#  ['really',
#   'wanna',
#   'watch',
#   'the',
#   'david',
#   'cook',
#   'and',
#   'archuleta',
#   'concert',
#   'sooo',
#   'hott'],
#  ['said',
#   'get',
#   'summer',
#   'flu',
#   'not',
#   'the',
#   'swine',
#   'flu',
#   'but',
#   'now',
#   'bilions',
#   'of',
#   'swineflu',
#   'tweeters',
#   'are',
#   'following',
#   'me'],
#  ['sang', 'early', 'tonight', 'one', 'song', 'twas', 'fun'],
#  ['see', 'you', 'babes', 'follow', 'my', 'boy'],
#  ['shine',
#   'through',
#   'my',
#   'smile',
#   'someone',
#   'said',
#   'just',
#   'jamba',
#   'ing'],
#  ['think',
#   'did',
#   'good',
#   'in',
#   'the',
#   'math',
#   'test',
#   'need',
#   'to',
#   'write',
#   'nao',
#   'words'],
#  ['try',
#   'remind',
#   'myself',
#   'often',
#   'that',
#   'even',
#   'the',
#   'smallest',
#   'input',
#   'can',
#   'produce',
#   'big',
#   'results'],
#  ['not', 'now', 'is', 'on', 'tv'],
#  ['nothing',
#   'left',
#   'to',
#   'do',
#   'but',
#   'sit',
#   'back',
#   'relax',
#   'have',
#   'fun',
#   'and',
#   'enjoy',
#   'the',
#   'ride',
#   'lmbo',
#   'xd'],
#  ['notsugripp', 'via'],
#  ['seara', 'perfekta', 'vodka', 'bertolucci', 'the', 'dreamers'],
#  ['off',
#   'to',
#   'kokomo',
#   'to',
#   'see',
#   'if',
#   'can',
#   'squeeze',
#   'into',
#   'this',
#   'dress',
#   'then',
#   'shoe',
#   'shopping',
#   'with',
#   'my',
#   'seeester',
#   'and',
#   'visiting',
#   'my',
#   'brandice'],
#  ['oh', 'man', 'when', 'you', 'make', 'fishhes', 'you', 'end', 'up', 'fishy'],
#  ['ok',
#   'good',
#   'im',
#   'not',
#   'the',
#   'only',
#   'one',
#   'this',
#   'weather',
#   'makes',
#   'me',
#   'so',
#   'happy'],
#  ['ok',
#   'how',
#   'about',
#   'just',
#   'pray',
#   'for',
#   'mental',
#   'clarity',
#   'while',
#   'drumming',
#   'today',
#   'since',
#   'enough',
#   'sleep',
#   'did',
#   'not',
#   'happen',
#   'have'],
#  ['omfg',
#   'ekkkkk',
#   'im',
#   'so',
#   'excited',
#   'to',
#   'see',
#   'paramore',
#   'im',
#   'only',
#   'going',
#   'cause',
#   'paramore',
#   'is',
#   'going',
#   'to',
#   'be',
#   'there',
#   'and',
#   'this',
#   'is',
#   'my',
#   'birthday',
#   'present'],
#  ['on',
#   'big',
#   'boat',
#   'bobbing',
#   'up',
#   'and',
#   'down',
#   'on',
#   'the',
#   'thames',
#   'sun',
#   'shinning',
#   'the',
#   'aroma',
#   'of',
#   'our',
#   'lunch',
#   'filling',
#   'the',
#   'restaurant',
#   'and',
#   'beer',
#   'on',
#   'it',
#   'way'],
#  ['one', 'happy', 'man', 'right', 'here', 'people'],
#  ['work', 'at'],
#  ['cold', 'today', 'is', 'here'],
#  ['im',
#   'little',
#   'spoiled',
#   'brat',
#   'dont',
#   'hate',
#   'me',
#   'for',
#   'hacking',
#   'you',
#   'sista'],
#  ['im', 'am', 'going', 'to', 'send', 'some', 'twits', 'to', 'some', 'folk'],
#  ['awake', 'it', 'amazin'],
#  ['im', 'bored', 'anyone', 'wanna', 'talk'],
#  ['chill', 'he', 'the', 'one', 'freaking', 'out'],
#  ['confused', 'with', 'this', 'twitter', 'lark'],
#  ['going', 'to', 'play', 'with', 'my', 'camera', 'today'],
#  ['gonna',
#   'have',
#   'some',
#   'ramen',
#   'and',
#   'play',
#   'ff',
#   'game',
#   'have',
#   'not',
#   'decided',
#   'which',
#   'yet'],
#  ['in', 'great', 'mood', 'but', 'feel', 'little', 'guilty', 'xd'],
#  ['in', 'garden', 'chillin'],
#  ['not', 'cold'],
#  ['want',
#   'to',
#   'buy',
#   'the',
#   'game',
#   'bayonetta',
#   'and',
#   'cosplay',
#   'her',
#   'definite',
#   'video',
#   'game',
#   'vixen'],
#  ['will', 'can', 'you', 'believe', 'its', 'been', 'month', 'already'],
#  ['will', 'watch', 'supernatural', 'now', 'niahahahahaaa', 'awesome', 'show'],
#  ['one', 'more', 'final', 'then', 'bye', 'bye', 'school'],
#  ['ooh', 'such', 'lovely', 'morning', 'xoxo'],
#  ['paranoid', 'looooooooove', 'that', 'song', 'good', 'job', 'amazing'],
#  ['party',
#   'the',
#   'sats',
#   'pixie',
#   'th',
#   'party',
#   'bbq',
#   'party',
#   'vacation',
#   'the',
#   'bestie',
#   'forrrrreal',
#   'dude',
#   'xx'],
#  ['patrick', 'wolf', 'came', 'on', 'to', 'introduce', 'serafina'],
#  ['perfectly',
#   'cooked',
#   'half',
#   'boiled',
#   'eggs',
#   'my',
#   'favourite',
#   'spoon',
#   'and',
#   'that',
#   'home',
#   'brand',
#   'dark',
#   'soya',
#   'sauce',
#   'makes',
#   'my',
#   'day'],
#  ['phe',
#   'did',
#   'better',
#   'then',
#   'expected',
#   'on',
#   'my',
#   'mid',
#   'term',
#   'one',
#   'more',
#   'to',
#   'gooo',
#   'and',
#   'then',
#   'ammm',
#   'freeeeeeeeeeee'],
#  ['picking',
#   'up',
#   'new',
#   'mcfly',
#   'tickets',
#   'at',
#   'the',
#   'venue',
#   'so',
#   'effing',
#   'excited',
#   'nearly',
#   'cried',
#   'with',
#   'relief',
#   'haha'],
#  ['please'],
#  ['ponte',
#   'winery',
#   'in',
#   'temecula',
#   'has',
#   'amazing',
#   'wines',
#   'you',
#   'should',
#   'go',
#   'out',
#   'there',
#   'and',
#   'try',
#   'it',
#   'love',
#   'love',
#   'the',
#   'beverino',
#   'cheers'],
#  ['positivity',
#   'inspiration',
#   'from',
#   'magazine',
#   'in',
#   'world',
#   'full',
#   'of',
#   'negativity',
#   'it',
#   'is',
#   'sometimes',
#   'hard',
#   'to',
#   'stay',
#   'positive'],
#  ['im', 'not', 'going', 'to', 'school', 'today'],
#  ['off', 'to', 'sleep', 'goodnight', 'tweetts', 'enjoy', 'your', 'day', 'xxx'],
#  ['im',
#   'pretty',
#   'sure',
#   'it',
#   'would',
#   'fit',
#   'into',
#   'my',
#   'pants',
#   'as',
#   'well',
#   'its',
#   'amazing',
#   'but',
#   'jus',
#   'found',
#   'my',
#   'tiny',
#   'lil',
#   'greg',
#   'guy',
#   'that',
#   'got',
#   'from',
#   'pbmall'],
#  ['rollin',
#   'ova',
#   'here',
#   'smh',
#   'caus',
#   'can',
#   'imagine',
#   'my',
#   'daughter',
#   'doin',
#   'that',
#   'rite',
#   'now',
#   'she',
#   'jumps',
#   'sumtime',
#   'too',
#   'lol'],
#  ['smiling',
#   'because',
#   'lost',
#   'lost',
#   'lbs',
#   'so',
#   'far',
#   'join',
#   'the',
#   'thousands',
#   'of',
#   'losers'],
#  ['im', 'so', 'awesome'],
#  ['im', 'so', 'excited'],
#  ['im',
#   'so',
#   'fucking',
#   'rad',
#   'points',
#   'at',
#   'last',
#   'tweet',
#   'only',
#   'missed',
#   'tt',
#   'which',
#   'happen',
#   'to',
#   'be',
#   'clothdiapers',
#   'and',
#   'jbarsodmg',
#   'haha',
#   'done'],
#  ['so', 'happy', 'right', 'now', 'have', 'no', 'idea', 'why'],
#  ['surprisingly',
#   'happy',
#   'and',
#   'people',
#   'who',
#   'make',
#   'rumours',
#   'obviously',
#   'do',
#   'not',
#   'have',
#   'life'],
#  ['im',
#   'the',
#   'happiest',
#   'could',
#   'ever',
#   'be',
#   'baby',
#   'stayed',
#   'with',
#   'me',
#   'at',
#   'my',
#   'elementary',
#   'school',
#   'love',
#   'you',
#   'babe'],
#  ['random',
#   'silly',
#   'texts',
#   'from',
#   'great',
#   'friends',
#   'makes',
#   'face',
#   'and',
#   'tummy',
#   'hurt',
#   'from',
#   'laughing',
#   'too',
#   'much',
#   'simple',
#   'mind',
#   'simple',
#   'pleasures',
#   'lol'],
#  ['really', 'lol'],
#  ['relay', 'for', 'lifee'],
#  ['revised',
#   'biochemistry',
#   'bit',
#   'now',
#   'taking',
#   'break',
#   've',
#   'deserved',
#   'it',
#   'letting',
#   'go',
#   'bit',
#   'xd'],
#  ['ts',
#   'studio',
#   'jess',
#   'killah',
#   'is',
#   'back',
#   'where',
#   'the',
#   'fuck',
#   'is',
#   'you'],
#  ['she', 'makes', 'all', 'the', 'bullish', 'worth', 'it'],
#  ['very',
#   'very',
#   'happy',
#   'lalalalala',
#   'in',
#   'my',
#   'taylor',
#   'lautner',
#   'world',
#   'haha'],
#  ['in', 'good', 'mood'],
#  ['in', 'good', 'mood'],
#  ['in',
#   'case',
#   'you',
#   'missed',
#   'it',
#   'check',
#   'the',
#   'new',
#   'love',
#   'on',
#   'the',
#   'bloggety',
#   'leave',
#   'comments',
#   'to',
#   'let',
#   'me',
#   'know',
#   'what',
#   'ya',
#   'think'],
#  ['is', 'anyone', 'as', 'turned', 'on', 'as', 'am'],
#  ['is',
#   'doing',
#   'alright',
#   'this',
#   'morning',
#   'lovees',
#   'calculating',
#   'collapse'],
#  ['is', 'it', 'me', 'or', 'is', 'jeremih', 'lil', 'cutie'],
#  ['is',
#   'juss',
#   'chillin',
#   'outz',
#   'listenin',
#   'to',
#   'dem',
#   'mad',
#   'tunes',
#   'beautiful',
#   'night',
#   'feelin',
#   'goooood',
#   'waitin',
#   'cuz',
#   'to',
#   'come',
#   'on',
#   'over'],
#  ['is', 'not', 'today', 'wonderful', 'day'],
#  ['it',
#   'makes',
#   'the',
#   'format',
#   'tighter',
#   'prefer',
#   'it',
#   'now',
#   'new',
#   'to',
#   'me',
#   'then',
#   'lol',
#   'only',
#   'started',
#   'getting',
#   'serious',
#   'about',
#   'my',
#   'writing'],
#  ['sims',
#   'is',
#   'pure',
#   'awesome',
#   'ness',
#   'created',
#   'simon',
#   'cowell',
#   'terri',
#   'seymour',
#   'they',
#   're',
#   'living',
#   'in',
#   'the',
#   'same',
#   'house',
#   'haha'],
#  ['sitting',
#   'ion',
#   'the',
#   'garden',
#   'with',
#   'hayley',
#   'drinking',
#   'cider',
#   'lovely',
#   'relax',
#   'after',
#   'yesterday',
#   'my',
#   'first',
#   'day',
#   'tomorrow',
#   'ohhhhhh'],
#  ['sitting', 'making', 'cookies', 'with', 'my', 'cuzzy'],
#  ['sleeping',
#   'is',
#   'for',
#   'losers',
#   'and',
#   'people',
#   'who',
#   'arent',
#   'vampires'],
#  ['smile', 'happy', 'looks', 'good', 'on', 'you'],
#  ['smile',
#   'that',
#   'what',
#   'doing',
#   'shining',
#   'and',
#   'blooming',
#   'because',
#   'so',
#   'happy',
#   'just',
#   'wanna',
#   'dream',
#   'of',
#   'happy',
#   'thoughts',
#   'forever',
#   'hahaha'],
#  ['smiley', 'faces'],
#  ['so', 'excited'],
#  ['so', 'good', 'so', 'good'],
#  ['so', 'happy', 'less', 'than', 'week'],
#  ['so',
#   'many',
#   'old',
#   'but',
#   'good',
#   'movies',
#   'on',
#   'tv',
#   'tonight',
#   'national',
#   'lampoons',
#   'vacation',
#   'then',
#   'the',
#   'princess',
#   'bride',
#   'wonder',
#   'of',
#   'will',
#   'ever',
#   'get',
#   'to',
#   'bed'],
#  ['so', 'still', 'curious', 'as', 'to', 'this', 'whole', 'david', 'thing'],
#  ['sold', 'another', 'shirt', 'on', 'cafepress'],
#  ['wov', 'you'],
#  ['just',
#   'happy',
#   'although',
#   'have',
#   'few',
#   'things',
#   'in',
#   'mind',
#   'damn',
#   'tricky',
#   'mind',
#   'of',
#   'mine'],
#  ['iam', 'bored'],
#  ['rather',
#   'have',
#   'you',
#   'and',
#   'my',
#   'girlfriend',
#   'at',
#   'my',
#   'crib',
#   'runnin',
#   'round',
#   'naked',
#   'girl',
#   'gotta',
#   'girlfriend',
#   'on',
#   'in',
#   'bed',
#   'nice',
#   'work'],
#  ['if',
#   'you',
#   'end',
#   'having',
#   'to',
#   'eat',
#   'your',
#   'words',
#   'do',
#   'not',
#   'worry',
#   'they',
#   'taste',
#   'like',
#   'chicken'],
#  ['ihop', 'sounds', 'good'],
#  ['feeling', 'greate'],
#  ['doing', 'shalah', 'nails', 'wootness'],
#  ['im', 'in', 'such', 'good', 'mood', 'right', 'now', 'guys'],
#  ['like',
#   'so',
#   'on',
#   'the',
#   'radio',
#   'right',
#   'now',
#   'or',
#   'fm',
#   'if',
#   'you',
#   'are',
#   'in',
#   'canterbury',
#   'and',
#   'wanna',
#   'hear',
#   'some',
#   'music',
#   'and',
#   'me'],
#  ['spoke',
#   'at',
#   'an',
#   'urban',
#   'youth',
#   'conference',
#   'reload',
#   'this',
#   'morning',
#   'now',
#   'at',
#   'riley',
#   'softball',
#   'games',
#   'then',
#   'on',
#   'to',
#   'for',
#   'nightlight',
#   'whew'],
#  ['starbucks', 'tonight', 'love', 'my', 'dysfunctional', 'family'],
#  ['steak', 'and', 'shrimp', 'excited'],
#  ['stray', 'cats', 'stray', 'cat', 'strut'],
#  ['study', 'leave', 'finally'],
#  ['subscribing',
#   'to',
#   'swoozie',
#   'on',
#   'youtube',
#   'and',
#   'following',
#   'on',
#   'twitter',
#   'adds',
#   'to',
#   'your',
#   'street',
#   'cred'],
#  ['sunrise', 'worth', 'waiting', 'for'],
#  ['im',
#   'not',
#   'putting',
#   'no',
#   'weave',
#   'inmy',
#   'head',
#   'though',
#   'gonna',
#   'have',
#   'to',
#   'deal',
#   'my',
#   'short',
#   'cut'],
#  ['tired',
#   'gonna',
#   'go',
#   'to',
#   'bed',
#   'most',
#   'probably',
#   'hah',
#   'gonna',
#   'watch',
#   'some',
#   'tv',
#   'and',
#   'then',
#   'hit',
#   'the',
#   'hay'],
#  ['im',
#   'up',
#   'and',
#   'iiiiiiiiiiiiimmmmmmmmm',
#   'ready',
#   'ready',
#   'ready',
#   'ready',
#   'ready',
#   'lol'],
#  ['im', 'watchin', 'taken', 'again', 'yay', 'haha'],
#  ['in', 'good', 'mood', 'anyway', 'love', 'music'],
#  ['in', 'love', 'with', 'some', 'guy', 'who', 'lives', 'in', 'miami', 'fail'],
#  ['in',
#   'the',
#   'lab',
#   'right',
#   'now',
#   'cooking',
#   'up',
#   'sum',
#   'farout',
#   'ent',
#   'hotness',
#   'admire',
#   'greatness',
#   'at',
#   'it',
#   'works'],
#  ['init',
#   'woo',
#   'lol',
#   'wait',
#   'can',
#   'you',
#   'see',
#   'the',
#   'videos',
#   'on',
#   'the',
#   'side'],
#  ['inky', 'eating', 'crackers'],
#  ['insomniac', 'enjoying', 'life', 'am'],
#  ['is',
#   'finishing',
#   'off',
#   'the',
#   'semester',
#   'with',
#   'less',
#   'than',
#   'week',
#   'remaining'],
#  ['is',
#   'going',
#   'out',
#   'to',
#   'watford',
#   'text',
#   'me',
#   'if',
#   'you',
#   'need',
#   'me'],
#  ['it',
#   'went',
#   'like',
#   'this',
#   'he',
#   'asked',
#   'and',
#   'smiled',
#   'and',
#   'said',
#   'yes'],
#  ['it',
#   'should',
#   'go',
#   'home',
#   'good',
#   'bye',
#   'work',
#   'see',
#   'you',
#   'tomorrow'],
#  ['its', 'wiccan', 'wedding', 'too', 'love', 'this', 'show'],
#  ...]

# %%
# import numpy as np
# pos_reviews = np.array([row for row in tweet_data[tweet_data.sentiment == 1].text.str.split()])
neg_reviews = [row for row in tweet_data[tweet_data.sentiment == 0].text.str.split()]
# [value for (index, value) in pos_reviews.items()]
neg_reviews
# Out:
# [['is', 'so', 'sad', 'for', 'my', 'apl', 'friend'],
#  ['missed', 'the', 'new', 'moon', 'trailer'],
#  ['omgaga',
#   'im',
#   'sooo',
#   'im',
#   'gunna',
#   'cry',
#   've',
#   'been',
#   'at',
#   'this',
#   'dentist',
#   'since',
#   'was',
#   'suposed',
#   'just',
#   'get',
#   'crown',
#   'put',
#   'on',
#   'mins'],
#  ['think', 'mi', 'bf', 'is', 'cheating', 'on', 'me'],
#  ['or', 'just', 'worry', 'too', 'much'],
#  ['sunny', 'again', 'work', 'tomorrow', 'tv', 'tonight'],
#  ['must', 'think', 'about', 'positive'],
#  ['this', 'weekend', 'has', 'sucked', 'so', 'far'],
#  ['jb', 'isnt', 'showing', 'in', 'australia', 'any', 'more'],
#  ['ok', 'thats', 'it', 'you', 'win'],
#  ['this', 'is', 'the', 'way', 'feel', 'right', 'now'],
#  ['awhhe',
#   'man',
#   'completely',
#   'useless',
#   'rt',
#   'now',
#   'funny',
#   'all',
#   'can',
#   'do',
#   'is',
#   'twitter'],
#  ['huge', 'roll', 'of', 'thunder', 'just', 'now', 'so', 'scary'],
#  ['just',
#   'cut',
#   'my',
#   'beard',
#   'off',
#   'it',
#   'only',
#   'been',
#   'growing',
#   'for',
#   'well',
#   'over',
#   'year',
#   'gonna',
#   'start',
#   'it',
#   'over',
#   'is',
#   'happy',
#   'in',
#   'the',
#   'meantime'],
#  ['very', 'sad', 'about', 'iran'],
#  ['wompppp', 'wompp'],
#  ['sad',
#   'level',
#   'is',
#   'was',
#   'writing',
#   'massive',
#   'blog',
#   'tweet',
#   'on',
#   'myspace',
#   'and',
#   'my',
#   'comp',
#   'shut',
#   'down',
#   'now',
#   'it',
#   'all',
#   'lost',
#   'lays',
#   'in',
#   'fetal',
#   'position'],
#  ['headed',
#   'to',
#   'hospitol',
#   'had',
#   'to',
#   'pull',
#   'out',
#   'of',
#   'the',
#   'golf',
#   'tourny',
#   'in',
#   'rd',
#   'place',
#   'think',
#   're',
#   'ripped',
#   'something',
#   'yeah',
#   'that'],
#  ['boring', 'whats', 'wrong', 'with', 'him', 'please', 'tell', 'me'],
#  ['can',
#   'not',
#   'be',
#   'bothered',
#   'wish',
#   'could',
#   'spend',
#   'the',
#   'rest',
#   'of',
#   'my',
#   'life',
#   'just',
#   'sat',
#   'here',
#   'and',
#   'going',
#   'to',
#   'gigs',
#   'seriously'],
#  ['feeeling',
#   'like',
#   'shit',
#   'right',
#   'now',
#   'really',
#   'want',
#   'to',
#   'sleep',
#   'but',
#   'nooo',
#   'have',
#   'hours',
#   'of',
#   'dancing',
#   'and',
#   'an',
#   'art',
#   'assignment',
#   'to',
#   'finish'],
#  ['did',
#   'not',
#   'realize',
#   'it',
#   'was',
#   'that',
#   'deep',
#   'geez',
#   'give',
#   'girl',
#   'warning',
#   'atleast'],
#  ['hate',
#   'it',
#   'when',
#   'any',
#   'athlete',
#   'appears',
#   'to',
#   'tear',
#   'an',
#   'acl',
#   'on',
#   'live',
#   'television'],
#  ['miss',
#   'you',
#   'guys',
#   'too',
#   'think',
#   'wearing',
#   'skinny',
#   'jeans',
#   'cute',
#   'sweater',
#   'and',
#   'heels',
#   'not',
#   'really',
#   'sure',
#   'what',
#   'are',
#   'you',
#   'doing',
#   'today'],
#  ['meet', 'your', 'meat'],
#  ['my', 'horsie', 'is', 'moving', 'on', 'saturday', 'morning'],
#  ['no', 'sat', 'off', 'need', 'to', 'work', 'days', 'week'],
#  ['really',
#   'dont',
#   'like',
#   'doing',
#   'my',
#   'room',
#   'its',
#   'so',
#   'boring',
#   'sick',
#   'of',
#   'doing',
#   'my',
#   'wardrobe',
#   'out',
#   'cant',
#   'waiit',
#   'till',
#   'have',
#   'my',
#   'walk',
#   'in',
#   'one',
#   'yay'],
#  ['sox', 'floyd', 'was', 'great', 'but', 'relievers', 'need', 'scolding'],
#  ['times', 'by', 'like', 'million'],
#  ['what',
#   'type',
#   'of',
#   'spaz',
#   'downloads',
#   'virus',
#   'my',
#   'brother',
#   'that',
#   'who',
#   'msn',
#   'is',
#   'now',
#   'fucked',
#   'forever'],
#  ['fightiin', 'wiit', 'the', 'babes'],
#  ['enough', 'said'],
#  ['it',
#   'really',
#   'makes',
#   'me',
#   'sad',
#   'when',
#   'look',
#   'at',
#   'muslims',
#   'reality',
#   'now'],
#  ['all',
#   'time',
#   'low',
#   'shall',
#   'be',
#   'my',
#   'motivation',
#   'for',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'week'],
#  ['and',
#   'the',
#   'entertainment',
#   'is',
#   'over',
#   'someone',
#   'complained',
#   'properly',
#   'experimental',
#   'you',
#   'say',
#   'he',
#   'should',
#   'experiment',
#   'with',
#   'melody'],
#  ['another', 'year', 'of', 'lakers', 'that', 'neither', 'magic', 'nor', 'fun'],
#  ['baddest', 'day', 'eveer'],
#  ['but', 'proud'],
#  ['congrats', 'to', 'helio', 'though'],
#  ['david',
#   'must',
#   'be',
#   'hospitalized',
#   'for',
#   'five',
#   'days',
#   'end',
#   'of',
#   'july',
#   'palatine',
#   'tonsils',
#   'will',
#   'probably',
#   'never',
#   'see',
#   'katie',
#   'in',
#   'concert'],
#  ['friends', 'are', 'leaving', 'me', 'cause', 'of', 'this', 'stupid', 'love'],
#  ['hand', 'quilting', 'it', 'is', 'then'],
#  ['hate', 'leysh', 'ar'],
#  ['love', 'you', 'guys', 'so', 'much', 'that', 'it', 'hurts'],
#  ['miss', 'earl'],
#  ['miss', 'new', 'jersey'],
#  ['missed',
#   'the',
#   'first',
#   'hour',
#   'of',
#   'sytycd',
#   'last',
#   'night',
#   'and',
#   'can',
#   'not',
#   'find',
#   'it',
#   'online'],
#  ['need', 'fix', 'now'],
#  ['never', 'thought', 'become', 'second', 'choice'],
#  ['think', 'may', 'be', 'too', 'friendly', 'lol', 'well'],
#  ['think',
#   'manuel',
#   'my',
#   'basil',
#   'plant',
#   'only',
#   'has',
#   'days',
#   'to',
#   'live'],
#  ['wanna',
#   'be',
#   'at',
#   'home',
#   'church',
#   'wonder',
#   'wht',
#   'they',
#   'are',
#   'doing'],
#  ['wanna', 'make', 'my', 'own', 'pizza'],
#  ['want',
#   'gb',
#   'harddrive',
#   'or',
#   'inch',
#   'tv',
#   'or',
#   'new',
#   'guitar',
#   'anyonefeeling',
#   'generous'],
#  ['want', 'hug'],
#  ['want', 'miley', 'to', 'tour', 'australia'],
#  ['wanted',
#   'to',
#   'sleep',
#   'in',
#   'this',
#   'morning',
#   'but',
#   'mean',
#   'kid',
#   'through',
#   'popsicle',
#   'stick',
#   'at',
#   'me',
#   'head',
#   'wish',
#   'could',
#   'fly',
#   'away',
#   'like',
#   'those',
#   'squirrels'],
#  ['was', 'too', 'slow', 'to', 'get', 'up', 'tix'],
#  ['will',
#   'send',
#   'sunshine',
#   'to',
#   'northern',
#   'ireland',
#   'are',
#   'you',
#   'going',
#   'swimming',
#   'today'],
#  ['wish',
#   'could',
#   'go',
#   'to',
#   'on',
#   'the',
#   'beach',
#   'would',
#   'be',
#   'great',
#   'to',
#   'see'],
#  ['would',
#   'be',
#   'so',
#   'much',
#   'happier',
#   'if',
#   'the',
#   'walls',
#   'of',
#   'my',
#   'bedroom',
#   'were',
#   'painted',
#   'white'],
#  ['idk',
#   'wat',
#   'do',
#   'who',
#   'can',
#   'trust',
#   'me',
#   'im',
#   'sorry',
#   'all',
#   'da',
#   'pain',
#   'have',
#   'caused',
#   'nebody',
#   'ima',
#   'take',
#   'dis',
#   'time',
#   'out',
#   'straighten',
#   'myself',
#   'out',
#   'luv',
#   'yall'],
#  ['finding',
#   'the',
#   'intercept',
#   'slope',
#   'and',
#   'banging',
#   'my',
#   'head',
#   'against',
#   'the',
#   'wall',
#   'math',
#   'brain',
#   'heads',
#   'come',
#   'save',
#   'me'],
#  ['im', 'sick', 'cough', 'cough'],
#  ['in', 'cab', 'headed', 'to', 'the', 'airport', 'going', 'home', 'christy'],
#  ['in',
#   'case',
#   'feel',
#   'emo',
#   'in',
#   'camp',
#   'feeling',
#   'wee',
#   'bit',
#   'of',
#   'it',
#   'alr',
#   'am',
#   'bringing',
#   'in',
#   'the',
#   'human',
#   'rights',
#   'watch',
#   'world',
#   'report',
#   'hope',
#   'it',
#   'll',
#   'work'],
#  ['jonas', 'day', 'is', 'almost', 'over'],
#  ['jus',
#   'got',
#   'hom',
#   'fr',
#   'tda',
#   'funeral',
#   'so',
#   'sad',
#   'cried',
#   'so',
#   'much',
#   'times',
#   'much',
#   'love',
#   'grandpa',
#   'never',
#   'got',
#   'to',
#   'say',
#   'my',
#   'last',
#   'goodbye',
#   'to',
#   'him'],
#  ['longest', 'night', 'ever', 'ugh'],
#  ['mi',
#   'momacita',
#   'will',
#   'not',
#   'let',
#   'me',
#   'go',
#   'to',
#   'my',
#   'bf',
#   'bball',
#   'game',
#   'grrr'],
#  ['mom',
#   'says',
#   'have',
#   'to',
#   'get',
#   'new',
#   'phone',
#   'immediately',
#   'off',
#   'to',
#   'mobile',
#   'she',
#   'paying'],
#  ['my',
#   'new',
#   'car',
#   'was',
#   'stolen',
#   'by',
#   'my',
#   'mother',
#   'who',
#   'wanted',
#   'to',
#   'go',
#   'pose',
#   'at',
#   'church'],
#  ['no', 'hang', 'out', 'with', 'the', 'girls', 'day', 'moro', 'hope', 'so'],
#  ['no',
#   'movie',
#   'times',
#   'for',
#   'sunday',
#   'rats',
#   'will',
#   'have',
#   'to',
#   'plan',
#   'tomorrow',
#   'guess',
#   'this',
#   'means',
#   'have',
#   'to',
#   'work',
#   'on',
#   'those',
#   'two',
#   'presentations',
#   'am',
#   'doing'],
#  ['no', 'pavel', 'tonight', 'tigersfan'],
#  ['not', 'cool', 'night'],
#  ['probably',
#   'guna',
#   'get',
#   'off',
#   'soon',
#   'since',
#   'no',
#   'one',
#   'is',
#   'talkin',
#   'no',
#   'more'],
#  ['really',
#   'wanted',
#   'safina',
#   'to',
#   'pull',
#   'out',
#   'win',
#   'to',
#   'lose',
#   'like',
#   'that'],
#  ['rip', 'david', 'eddings'],
#  ['sannesias',
#   'aww',
#   'no',
#   'neighbor',
#   'we',
#   'need',
#   'to',
#   'watch',
#   'mean',
#   'girls'],
#  ['so', 'whats', 'the', 'status', 'on', 'next', 'weekend'],
#  ['sorry',
#   'the',
#   'ex',
#   'husband',
#   'has',
#   'overdosed',
#   'on',
#   'his',
#   'daily',
#   'dose',
#   'of',
#   'haterade'],
#  ['thanks',
#   'for',
#   'your',
#   'definition',
#   'of',
#   'throwbie',
#   'editors',
#   'reviewed',
#   'your',
#   'entry',
#   'and',
#   'have',
#   'decided',
#   'to',
#   'not',
#   'publish',
#   'it'],
#  ['told',
#   'not',
#   'to',
#   'drink',
#   'my',
#   'rx',
#   'so',
#   'just',
#   'gave',
#   'all',
#   'the',
#   'porter',
#   'obs',
#   'stout',
#   'that',
#   'brought',
#   'home',
#   'from',
#   'or',
#   'to',
#   'my',
#   'neighbors',
#   'sad'],
#  ['guys', 'knw', 'whyy'],
#  ['very', 'much', 'so'],
#  ['waahhh', 'now', 'getting', 'sad', 'miss', 'hub'],
#  ['we',
#   'were',
#   'standing',
#   'out',
#   'in',
#   'the',
#   'pouring',
#   'rain',
#   'we',
#   'were',
#   'sitting',
#   'on',
#   'top',
#   'of',
#   'the',
#   'world',
#   'summer',
#   'sucks'],
#  ['went',
#   'to',
#   'get',
#   'dog',
#   'from',
#   'vets',
#   'theyve',
#   'stitched',
#   'her',
#   'ear',
#   'charged',
#   'us',
#   'for',
#   'it',
#   'but',
#   'she',
#   'still',
#   'bleeds',
#   'like',
#   'waterfall',
#   'everytime',
#   'she',
#   'moves',
#   'why'],
#  ['where', 'is', 'my', 'picture', 'feel', 'naked'],
#  ['why',
#   'are',
#   'not',
#   'there',
#   'any',
#   'trains',
#   'going',
#   'to',
#   'manchester',
#   'on',
#   'sunday',
#   'now',
#   'can',
#   'not',
#   'go',
#   'to',
#   'the',
#   'concert'],
#  ['why',
#   'must',
#   'people',
#   'be',
#   'so',
#   'picky',
#   'mean',
#   'hours',
#   'work',
#   'and',
#   'no',
#   'dice',
#   'what',
#   'up',
#   'with',
#   'that'],
#  ['why', 'twitter', 'will', 'soon', 'become', 'obsolete'],
#  ['you',
#   'hi',
#   'stranger',
#   'hello',
#   'am',
#   'frank',
#   'lampard',
#   'how',
#   'are',
#   'you',
#   'you',
#   'fine',
#   'you',
#   'and',
#   'urself',
#   'stranger',
#   'am',
#   'gay',
#   'your'],
#  ['you', 'll', 'always', 'be', 'my', 'one', 'and', 'only'],
#  ['turnoffwords', 'this', 'shit', 'sucks'],
#  ['asylm',
#   'panel',
#   'is',
#   'over',
#   'guess',
#   'it',
#   'back',
#   'to',
#   'normal',
#   'life'],
#  ['squarespace', 'brighten', 'my', 'bad', 'day', 'never', 'win', 'anything'],
#  ['susan',
#   'boyle',
#   'didnt',
#   'win',
#   'mh',
#   'well',
#   'diversity',
#   'was',
#   'very',
#   'good',
#   'though',
#   'congratz'],
#  ['twenty'],
#  ['graduate'],
#  ['vandals',
#   'paint',
#   'swastikas',
#   'on',
#   'home',
#   'of',
#   'author',
#   'of',
#   'gay',
#   'lesbian',
#   'church',
#   'story',
#   'naples',
#   'daily',
#   'news'],
#  ['an',
#   'unknown',
#   'error',
#   'occured',
#   'uh',
#   'oh',
#   'iphone',
#   'os',
#   'fail',
#   'so',
#   'far'],
#  ['experts',
#   'homers',
#   'predict',
#   'eagles',
#   'to',
#   'go',
#   'and',
#   'giants',
#   'to',
#   'go',
#   'bs'],
#  ['want', 'you', 'so', 'bad', 'it', 'driving', 'me', 'mad'],
#  ['try',
#   'to',
#   'turn',
#   'on',
#   'my',
#   'tv',
#   'to',
#   'get',
#   'you',
#   'out',
#   'of',
#   'my',
#   'head',
#   've',
#   'got',
#   'this',
#   'feeling',
#   'inside',
#   'that',
#   'just',
#   'will',
#   'not',
#   'admit',
#   'that',
#   'is',
#   'literally',
#   'how',
#   'feel'],
#  ['well', 'the', 'truth', 'is', 'miss', 'you', 'so', 'coldplay'],
#  ['tears',
#   'today',
#   'is',
#   'the',
#   'last',
#   'day',
#   'with',
#   'my',
#   'kids',
#   'they',
#   'go',
#   'on',
#   'summer',
#   'break',
#   'at',
#   'their',
#   'dads',
#   'tomorrow',
#   'sighs'],
#  ['unsure', 'annoyed'],
#  ['via',
#   'are',
#   'designed',
#   'gallery',
#   'exhibition',
#   'postcards',
#   'mailers',
#   'going',
#   'extinct',
#   'via',
#   'nyt'],
#  ['beautifulylost'],
#  ['cries',
#   'going',
#   'to',
#   'miss',
#   'harry',
#   'potter',
#   'when',
#   'it',
#   'comes',
#   'out',
#   'leaving',
#   'to',
#   'vietnam',
#   'on',
#   'july',
#   'th',
#   'going',
#   'to',
#   'cry'],
#  ['going',
#   'back',
#   'to',
#   'bed',
#   'because',
#   'lookin',
#   'around',
#   'and',
#   'do',
#   'not',
#   'see',
#   'reason',
#   'to',
#   'be',
#   'awake',
#   'atm',
#   'be',
#   'up',
#   'in',
#   'little'],
#  ['wantt', 'hiim', 'soo', 'badd'],
#  ['watching',
#   'tv',
#   'bed',
#   'shopping',
#   'mom',
#   'out',
#   'trent',
#   'hopefully',
#   'need',
#   'my',
#   'best',
#   'friend'],
#  ['had',
#   'weird',
#   'encounters',
#   'with',
#   'so',
#   'many',
#   'homeless',
#   'creeps',
#   'on',
#   'the',
#   'walk',
#   'home',
#   'tonight',
#   'all',
#   'by',
#   'myself',
#   'awesome',
#   'really'],
#  ['rained', 'out', 'truck', 'race'],
#  ['why', 'am', 'feeling', 'worse'],
#  ['feeling',
#   'pain',
#   'and',
#   'happiness',
#   'at',
#   'the',
#   'same',
#   'time',
#   'how',
#   'confusing'],
#  ['in', 'shirt', 'and', 'panties', 'celulite'],
#  ['had',
#   'to',
#   'turn',
#   'back',
#   'to',
#   'north',
#   'due',
#   'to',
#   'body',
#   'on',
#   'line',
#   'so',
#   'missing',
#   'design',
#   'council',
#   'design',
#   'tech',
#   'transfer',
#   'event'],
#  ['everything', 'is', 'so', 'hard'],
#  ['bueno', 'good', 'bye', 'good', 'night'],
#  ['let', 'have', 'fun', 'when', 'give', 'ya', 'what', 'give', 'ya'],
#  ['do', 'not', 'want', 'to', 'move'],
#  ['the', 'train', 'crash', 'in', 'dc'],
#  ['what',
#   'happened',
#   'to',
#   'angels',
#   'and',
#   'demons',
#   'and',
#   'lions',
#   'and',
#   'tigers',
#   'and',
#   'bears'],
#  ['well', 'that', 'sure', 'minimizes', 'the', 'impact', 'lol'],
#  ['went',
#   'to',
#   'work',
#   'once',
#   'last',
#   'year',
#   'with',
#   'no',
#   'pants',
#   'ironically',
#   'that',
#   'was',
#   'my',
#   'last',
#   'day',
#   'of',
#   'work',
#   'at',
#   'that',
#   'job',
#   'fml'],
#  ['there', 'many', 'gr', 'science', 'cartoons'],
#  ['edinburgh',
#   'fringe',
#   'is',
#   'only',
#   'weeks',
#   'away',
#   'need',
#   'monies',
#   'btw',
#   'elliott',
#   'from',
#   'blame',
#   'for',
#   'the',
#   'twitter',
#   'intrusion'],
#  ['why',
#   'didnt',
#   'you',
#   'come',
#   'to',
#   'school',
#   'have',
#   'you',
#   'done',
#   'the',
#   'short',
#   'stack',
#   'thing',
#   'by',
#   'yourself',
#   'or',
#   'do',
#   'you',
#   'still',
#   'need',
#   'me'],
#  ['which',
#   'one',
#   'or',
#   'latter',
#   'for',
#   'the',
#   'us',
#   'store',
#   'only',
#   'iphone',
#   'comics'],
#  ['magic',
#   'thinking',
#   'less',
#   'than',
#   'chance',
#   'hedo',
#   'stays',
#   'in',
#   'orlando',
#   'he',
#   'gonna',
#   'go',
#   'for',
#   'the',
#   'they',
#   'all',
#   'do',
#   'can',
#   'not',
#   'blame',
#   'him',
#   'though'],
#  ['now', 'who', 'wud', 'make', 'this', 'beautiful', 'plc', 'cry'],
#  ['it', 'is', 'now', 'the', 'outer', 'fat', 'kid'],
#  ['se', 'morrea', 'mi', 'joseph', 'no', 'no', 'se', 'vale'],
#  ['why',
#   'is',
#   'your',
#   'youtube',
#   'account',
#   'suspended',
#   'lol',
#   'single',
#   'ladies',
#   'dance',
#   'need',
#   'to',
#   'watch',
#   'it',
#   'again'],
#  ['know', 'sold', 'out', 'though'],
#  ['should', 'get', 'on', 'aim', 'and', 'talk', 'to', 'me', 'miss', 'her'],
#  ['kashrut',
#   'convo',
#   'makes',
#   'me',
#   'want',
#   'to',
#   'keep',
#   'more',
#   'kosher',
#   'but',
#   'my',
#   'roomies',
#   'catholic',
#   'he',
#   'has',
#   'pork',
#   'loin',
#   'in',
#   'the',
#   'fridge',
#   'kosherfail'],
#  ['is', 'not', 'home', 'neither', 'is', 'better', 'have', 'it'],
#  ['immune',
#   'to',
#   'dentists',
#   'drills',
#   'etc',
#   'now',
#   'it',
#   'just',
#   'does',
#   'not',
#   'bother',
#   'me',
#   'at',
#   'all',
#   'having',
#   'gum',
#   'lift',
#   'surgery',
#   'next',
#   'week',
#   'tho',
#   'eek'],
#  ['where', 'tonite', 'im', 'still', 'awake'],
#  ['hates', 'bebot', 'app'],
#  ['what', 'are', 'referring', 'to'],
#  ['miss', 'her', 'so', 'much', 'already'],
#  ['just', 'practising', 'how', 'feel'],
#  ['miss', 'my', 'love', 'jamie'],
#  ['fuck', 'you'],
#  ['my', 'head', 'feels', 'like', 'bowling', 'ball'],
#  ['my', 'heart', 'hurts', 'badly'],
#  ['fs', 'keeps', 'crashing', 'when', 'try', 'to', 'load', 'bungie', 'plane'],
#  ['my',
#   'current',
#   'headset',
#   'is',
#   'on',
#   'its',
#   'deathbed',
#   'now',
#   'my',
#   'dad',
#   'gave',
#   'it',
#   'to',
#   'me',
#   'just',
#   'weeks',
#   'back'],
#  ['my', 'mood', 'is', 'currently', 'blah', 'sitting', 'in', 'parking', 'lot'],
#  ['that', 'is', 'all'],
#  ['everyone',
#   'went',
#   'home',
#   'and',
#   'not',
#   'everyone',
#   'was',
#   'even',
#   'here',
#   'cmf'],
#  ['fed', 'up'],
#  ['fuck', 'fuck', 'fuuuuck'],
#  ['not',
#   'feeling',
#   'it',
#   'today',
#   'and',
#   'to',
#   'make',
#   'matters',
#   'worst',
#   'its',
#   'super',
#   'nasty',
#   'and',
#   'rainy',
#   'outside',
#   'yuck'],
#  ['wanted', 'aiden', 'davis', 'win', 'him', 'so', 'bummed', 'he', 'didnt'],
#  ['bed', 'time', 'now'],
#  ['friends', 'like', 'these', 'no', 'thanks', 'not', 'fake'],
#  ['think', 'my', 'bf', 'is', 'cheating', 'on', 'me'],
#  ['want', 'an', 'octo', 'drive'],
#  ['want',
#   'to',
#   'display',
#   'my',
#   'pretty',
#   'voltron',
#   'upside',
#   'get',
#   'two',
#   'pretty',
#   'voltrons'],
#  ['want',
#   'to',
#   'find',
#   'way',
#   'to',
#   'put',
#   'my',
#   'photos',
#   'on',
#   'phone',
#   'here',
#   'have',
#   'bluetooth',
#   'in',
#   'both',
#   'phone',
#   'and',
#   'computer',
#   'but',
#   'it',
#   'does',
#   'not',
#   'work'],
#  ['in',
#   'an',
#   'effort',
#   'to',
#   'bring',
#   'you',
#   'the',
#   'best',
#   'content',
#   'we',
#   'just',
#   'added',
#   'at',
#   'lease',
#   'hours',
#   'to',
#   'the',
#   'release',
#   'of',
#   'the',
#   'digital',
#   'rapture',
#   'soon',
#   'hang',
#   'tight'],
#  ['is',
#   'our',
#   'response',
#   'to',
#   'what',
#   'happened',
#   'today',
#   'and',
#   'that',
#   'is',
#   'all'],
#  ['you', 'are', 'right', 'it', 'hurts'],
#  ['kinda', 'but', 'not', 'really', 'but', 'kinda'],
#  ['let',
#   'have',
#   'moment',
#   'of',
#   'silence',
#   'for',
#   'our',
#   'childhood',
#   'homes',
#   'sadly',
#   'it',
#   'can',
#   'not',
#   'be',
#   'replaced',
#   'and',
#   'we',
#   'can',
#   'never',
#   'go',
#   'back'],
#  ['no',
#   'man',
#   'is',
#   'worth',
#   'your',
#   'tears',
#   'and',
#   'the',
#   'one',
#   'that',
#   'is',
#   'will',
#   'not',
#   'make',
#   'you',
#   'cry'],
#  ['rain', 'rain', 'go', 'away'],
#  ['storms', 'are', 'scary'],
#  ['tell', 'those', 'girls', 'your', 'clocking', 'out', 'lol'],
#  ['the',
#   'batt',
#   'to',
#   'my',
#   'internet',
#   'connection',
#   'died',
#   'guess',
#   'its',
#   'back',
#   'to',
#   'the',
#   'mobile'],
#  ['now', 'has', 'it', 'for', 'the', 'th'],
#  ['squarespace',
#   'trackle',
#   'no',
#   'apple',
#   'iphone',
#   'card',
#   'for',
#   'us',
#   'maybe',
#   'tomorrow',
#   'guess',
#   'it',
#   'helps',
#   'if',
#   'you',
#   'tweet',
#   'it',
#   'huh',
#   'we',
#   'forgot'],
#  ['unsure', 'hassle', 'music'],
#  ['exhausted'],
#  ['want', 'some', 'ben', 'jerrys', 'cake', 'batter', 'please', 'ugh'],
#  ['wish', 'ella', 'was', 'on', 'or', 'somebody'],
#  ['think',
#   'going',
#   'to',
#   'go',
#   'long',
#   'drive',
#   'then',
#   'when',
#   'get',
#   'to',
#   'the',
#   'pacific',
#   'ocean',
#   'open',
#   'my',
#   'car',
#   'door',
#   'and',
#   'throw',
#   'my',
#   'pc',
#   'in',
#   'the',
#   'ocean'],
#  ['what', 'the', 'hell', 'bbc'],
#  ['canucks'],
#  ['dont', 'like', 'this', 'weekend', 'huhuhu'],
#  ['ll', 'get', 'on', 'it', 'right', 'away'],
#  ['lonely', 'night'],
#  ['blue', 'does', 'not', 'work'],
#  ['geez', 'feeling', 'their', 'pain'],
#  ['miss', 'my', 'summertime', 'daley'],
#  ['on',
#   'the',
#   'computer',
#   'ill',
#   'lol',
#   'no',
#   'fuckin',
#   'goin',
#   'to',
#   'portugal'],
#  ['ughhhhhhhhhhhhhhhhhhhhhhhhhhhhh'],
#  ['battleground'],
#  ['wanted', 'aiden', 'davis', 'win', 'him', 'so', 'bummed', 'he', 'didnt'],
#  ['curtain', 'drops', 'at', 'the', 'crown', 'uptown', 'after', 'ye'],
#  ['eh', 'must', 'leave', 'new', 'mexico', 'and', 'soon'],
#  ['fail', 'maths', 'knew', 'it', 'was', 'just', 'too', 'slow'],
#  ['from',
#   'gongwer',
#   'oh',
#   'report',
#   'sounds',
#   'like',
#   'leadership',
#   'still',
#   'considering',
#   'library',
#   'cuts',
#   'not',
#   'considering',
#   'tax',
#   'increases',
#   'saveohiolibraries'],
#  ['fuck', 'sake', 'why', 'can', 'things', 'never', 'work', 'out', 'for', 'me'],
#  ['going',
#   'in',
#   'town',
#   'toda',
#   'with',
#   'cousinnn',
#   'netball',
#   'match',
#   'was',
#   'cancelledd'],
#  ['hoping', 'to', 'see', 'my', 'baby', 'girl'],
#  ['do', 'not', 'even', 'know'],
#  ['just', 'lost', 'member', 'of', 'my', 'family'],
#  ['sick', 'of', 'bedtime', 'battles'],
#  ['so', 'cold', 'this', 'morning', 'have', 'chills', 'all', 'over'],
#  ['just'],
#  ['no',
#   'no',
#   'no',
#   'tonight',
#   'goes',
#   'on',
#   'the',
#   'books',
#   'as',
#   'the',
#   'worst',
#   'sytycd',
#   'results',
#   'show'],
#  ['no', 'shopping'],
#  ['poor',
#   'lil',
#   'mousey',
#   'just',
#   'out',
#   'enjoying',
#   'the',
#   'sunny',
#   'day',
#   'do',
#   'not',
#   'think',
#   'feel',
#   'so',
#   'bad',
#   'if',
#   'it',
#   'was',
#   'big',
#   'gnarly',
#   'rat',
#   'though',
#   'dbl',
#   'standard',
#   'yep'],
#  ['that', 'an', 'epic', 'sad', 'face'],
#  ['this',
#   'magazine',
#   'story',
#   'just',
#   'broke',
#   'my',
#   'heart',
#   'at',
#   'the',
#   'dentist',
#   'office',
#   'today'],
#  ['wanna', 'go', 'meet', 'wifey', 'but', 'can', 'not', 'this', 'sux'],
#  ['wondering',
#   'why',
#   'feel',
#   'like',
#   'do',
#   'll',
#   'feel',
#   'better',
#   'though',
#   'its',
#   'all',
#   'good',
#   'll',
#   'be',
#   'happy',
#   'inspite',
#   'of',
#   'tweet',
#   'ya',
#   'lata'],
#  ['iranelection', 'no', 'one', 'realizes', 'how', 'deep', 'this', 'goes'],
#  ['bodies', 'from', 'air', 'france', 'crash', 'have', 'been', 'found', 'via'],
#  ['that',
#   'is',
#   'the',
#   'story',
#   'of',
#   'my',
#   'life',
#   'whole',
#   'bunch',
#   'of',
#   'frownies'],
#  ['have',
#   'noooooooooo',
#   'friends',
#   'on',
#   'twitter',
#   'it',
#   'makes',
#   'me',
#   'sad',
#   'will',
#   'someone',
#   'follow',
#   'me'],
#  ['just',
#   'want',
#   'to',
#   'hear',
#   'from',
#   'you',
#   'guess',
#   'that',
#   'asking',
#   'too',
#   'much'],
#  ['really', 'do', 'not', 'like', 'this', 'condition', 'sucksssssss'],
#  ['orlando',
#   'lost',
#   'the',
#   'series',
#   'oh',
#   'well',
#   'maybe',
#   'phoenix',
#   'or',
#   'boston',
#   'or',
#   'cleveland',
#   'the',
#   'teams',
#   'like',
#   'will',
#   'make',
#   'it',
#   'next',
#   'year'],
#  ['rinitis', 'sucks'],
#  ['mad',
#   'and',
#   'sad',
#   'right',
#   'now',
#   'played',
#   'so',
#   'terrible',
#   'today',
#   'in',
#   'both',
#   'soccer',
#   'and',
#   'basketball'],
#  ['but', 'mustache', 'man', 'is', 'not', 'that', 'desperate'],
#  ['my', 'face', 'because', 'missing', 'zoro', 'tonight'],
#  ['know', 'huh', 'im', 'bout', 'to', 'cry', 'thanks', 'marco', 'muah'],
#  ['angry'],
#  ['sry', 'matt', 'hear', 'that'],
#  ['what', 'the', 'fucccckkkkkkkkkk'],
#  ['bye', 'world'],
#  ['couldnt', 'even', 'have', 'one', 'fairytale', 'night'],
#  ['ll',
#   'be',
#   'working',
#   'when',
#   'pottercast',
#   'lupins',
#   'willows',
#   'come',
#   'near',
#   'me',
#   'fail'],
#  ['my',
#   'cell',
#   'phone',
#   'screen',
#   'is',
#   'dead',
#   'sooooooooooo',
#   'no',
#   'texts',
#   'and',
#   'do',
#   'not',
#   'know',
#   'who',
#   'calling',
#   'fuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuck'],
#  ['no',
#   'more',
#   'sickness',
#   'strike',
#   'say',
#   'strike',
#   'ohhhh',
#   'well',
#   'nother',
#   'day',
#   'off',
#   'school',
#   'guess'],
#  ['nobody',
#   'likes',
#   'year',
#   'one',
#   'in',
#   'the',
#   'reviews',
#   've',
#   'read',
#   'disappointed',
#   'but',
#   'maybe',
#   'now',
#   'll',
#   'like',
#   'it',
#   'more',
#   'since',
#   'not',
#   'expecting',
#   'much'],
#  ['must', 'say', 'more'],
#  ['old', 'me', 'dead', 'and', 'gone'],
#  ['have', 'to', 'go', 'now', 'more', 'minutes', 'please', 'please', 'please'],
#  ['really', 'hate', 'this'],
#  ['bad', 'day'],
#  ['bad',
#   'day',
#   'damn',
#   'you',
#   'what',
#   'kind',
#   'of',
#   'ticket',
#   'sale',
#   'was',
#   'that'],
#  ['boston', 'globe', 'could', 'be', 'shut', 'down', 'in', 'days'],
#  ['bye',
#   'guys',
#   'ma',
#   'miss',
#   'ya',
#   'll',
#   'sooo',
#   'sooo',
#   'much',
#   'but',
#   'do',
#   'not',
#   'worry',
#   'll',
#   'be',
#   'back',
#   'on',
#   'monday',
#   'have',
#   'an',
#   'awesome',
#   'weekend',
#   'peace'],
#  ['can',
#   'have',
#   'some',
#   'followers',
#   'so',
#   'sad',
#   'now',
#   'that',
#   'losing',
#   'hope',
#   'pressure'],
#  ['could', 'not', 'bless', 'da', 'mic', 'my', 'bra', 'in', 'music', 'day'],
#  ['cry', 'cry', 'cry'],
#  ['kn', 'day'],
#  ['goodnight'],
#  ['grandma',
#   'is',
#   'very',
#   'sick',
#   'not',
#   'doing',
#   'well',
#   'going',
#   'to',
#   'the',
#   'emergency',
#   'room'],
#  ['am',
#   'going',
#   'to',
#   'shed',
#   'tears',
#   'if',
#   'the',
#   'cavs',
#   'have',
#   'to',
#   'go',
#   'home',
#   'tonight',
#   'like',
#   'seriously'],
#  ['am',
#   'soooo',
#   'sad',
#   'at',
#   'this',
#   'point',
#   'of',
#   'night',
#   'be',
#   'cuddling',
#   'with',
#   'jonathan',
#   'like',
#   'did',
#   'for',
#   'years'],
#  ['hate', 'you', 'forever'],
#  ['missed', 'it'],
#  ['still', 'feel', 'like', 'douchebag'],
#  ['never', 'answering', 'my', 'im'],
#  ['it',
#   'now',
#   'fathers',
#   'day',
#   'and',
#   'you',
#   'have',
#   'not',
#   'picked',
#   'me',
#   'yet',
#   'kind',
#   'of',
#   'want',
#   'to',
#   'incessantly',
#   'bother',
#   'you',
#   'squarespace'],
#  ['is',
#   'no',
#   'longer',
#   'in',
#   'the',
#   'cab',
#   'to',
#   'say',
#   'heartbroken',
#   'is',
#   'an',
#   'understatement',
#   'good',
#   'luck',
#   'with',
#   'everything',
#   'you',
#   're',
#   'amazing',
#   'ian'],
#  ['broke', 'my', 'twitter'],
#  ['is',
#   'off',
#   'clubbing',
#   'must',
#   'come',
#   'over',
#   'to',
#   'sheffield',
#   'sometime',
#   'party',
#   'but',
#   'really',
#   'probably',
#   'should',
#   'not',
#   'atm',
#   'tech',
#   'conference',
#   'is',
#   'conf',
#   'etc'],
#  ['is',
#   'fulfilling',
#   'my',
#   'life',
#   'ambition',
#   'go',
#   'jonas',
#   'brothers',
#   'concert',
#   'went',
#   'hmv',
#   'and',
#   'the',
#   'new',
#   'album',
#   'is',
#   'already',
#   'sold',
#   'out',
#   'why',
#   'me'],
#  ['just',
#   'yelled',
#   'at',
#   'me',
#   'for',
#   'picking',
#   'apple',
#   'store',
#   'over',
#   'food'],
#  ['of',
#   'me',
#   'cats',
#   'kittens',
#   'died',
#   'only',
#   'days',
#   'old',
#   'too',
#   'rip',
#   'ming'],
#  ['week',
#   'before',
#   'the',
#   'palm',
#   'pre',
#   'comes',
#   'out',
#   'and',
#   'my',
#   'centro',
#   'dies',
#   'have',
#   'temp',
#   'phone',
#   'but',
#   'my',
#   'contacts',
#   'are',
#   'not',
#   'transfered',
#   'yet',
#   'sadpanda',
#   'fb'],
#  ['hrs', 'on', 'da', 'phone', 'lol', 'dude', 'is', 'hilarious'],
#  ['gb',
#   'of',
#   'video',
#   'to',
#   'upload',
#   'to',
#   'utube',
#   'dam',
#   'sony',
#   'vegas',
#   'making',
#   'it',
#   'so',
#   'big'],
#  ['of',
#   'the',
#   'new',
#   'footwear',
#   'labeling',
#   'norm',
#   'is',
#   'definitions',
#   'that',
#   'are',
#   'never',
#   'referred',
#   'to',
#   'in',
#   'the',
#   'document',
#   'who',
#   'wrote',
#   'this',
#   'up'],
#  ['big',
#   'angry',
#   'spider',
#   'was',
#   'crawling',
#   'in',
#   'my',
#   'blankeys',
#   'flicked',
#   'it',
#   'to',
#   'the',
#   'floor',
#   'and',
#   'cant',
#   'sleep',
#   'now'],
#  ['couple',
#   'years',
#   'of',
#   'sickness',
#   'all',
#   'piled',
#   'up',
#   'to',
#   'this',
#   'one',
#   'day'],
#  ['fly',
#   'just',
#   'landed',
#   'in',
#   'my',
#   'green',
#   'chile',
#   'stew',
#   've',
#   'never',
#   'been',
#   'big',
#   'on',
#   'killing',
#   'bugs',
#   'but',
#   'this',
#   'asshole',
#   'asked',
#   'for',
#   'it',
#   'there',
#   'goes',
#   'my',
#   'appetite'],
#  ['just',
#   'got',
#   'the',
#   'same',
#   'handshake',
#   'in',
#   'her',
#   'meeting',
#   'vibe',
#   'here',
#   'sucks'],
#  ['jonah', 'whats', 'tweet', 'sharon'],
#  ['alice',
#   'is',
#   'beating',
#   'be',
#   'at',
#   'my',
#   'scooby',
#   'doo',
#   'board',
#   'game'],
#  ['anyone',
#   'have',
#   'any',
#   'advice',
#   'on',
#   'how',
#   'to',
#   'cope',
#   'with',
#   'break',
#   'up'],
#  ['arrrrrrrgggggggghhhhhhhh',
#   'that',
#   'it',
#   'all',
#   'lines',
#   'of',
#   'communications',
#   'are',
#   'temporarily',
#   'suspended'],
#  ['but', 'understand'],
#  ['cars',
#   'being',
#   'inspected',
#   'today',
#   'gonna',
#   'cost',
#   'me',
#   'over',
#   'dollars'],
#  ['is', 'out'],
#  ['everythings', 'wrong'],
#  ['exercise',
#   'build',
#   'muscle',
#   'mass',
#   'is',
#   'only',
#   'thing',
#   'that',
#   'speeds',
#   'metabolism'],
#  ['friends', 'dying', 'is', 'just', 'horrible'],
#  ['he', 'was', 'the', 'best', 'there'],
#  ['hungover',
#   'and',
#   'craving',
#   'chocolate',
#   'omg',
#   'how',
#   'funny',
#   'was',
#   'the',
#   'pub',
#   'last',
#   'night',
#   'lol'],
#  ['dont',
#   'want',
#   'my',
#   'sister',
#   'to',
#   'leave',
#   'me',
#   'for',
#   'the',
#   'whole',
#   'summer'],
#  ['hope',
#   'everyone',
#   'is',
#   'at',
#   'church',
#   'so',
#   'can',
#   'just',
#   'go',
#   'to',
#   'my',
#   'concert',
#   'in',
#   'peace',
#   'on',
#   'wed',
#   'dont',
#   'have',
#   'to',
#   'worry',
#   'about',
#   'rushing',
#   'back',
#   'to',
#   'church',
#   'to',
#   'visit'],
#  ['just',
#   'spilt',
#   'the',
#   'last',
#   'of',
#   'my',
#   'jordans',
#   'cereal',
#   'on',
#   'the',
#   'floor',
#   'distraught'],
#  ['miss', 'my', 'family', 'and', 'friends'],
#  ['see', 'missed', 'the', 'nectar', 'sucking', 'dirty', 'talk'],
#  ['want',
#   'freaking',
#   'puppy',
#   'now',
#   'cute',
#   'little',
#   'black',
#   'yorkshire',
#   'terrier'],
#  ['want', 'irissa', 'back'],
#  ['glad', 'diversity', 'got', 'through', 'but', 'what', 'about', 'stavros'],
#  ['out', 'of', 'nutella'],
#  ['is',
#   'it',
#   'rlly',
#   'tht',
#   'serious',
#   'abt',
#   'to',
#   'go',
#   'thru',
#   'my',
#   'fonebook'],
#  ['it',
#   'is',
#   'on',
#   'environmental',
#   'studies',
#   'and',
#   'driving',
#   'me',
#   'mental'],
#  ['ve',
#   'always',
#   'seen',
#   'bits',
#   'pieces',
#   'of',
#   'shottas',
#   'now',
#   've',
#   'seen',
#   'the',
#   'whole',
#   'movie',
#   'it',
#   'ends',
#   'sooooo',
#   'sad',
#   'gonna',
#   'cry'],
#  ['just', 'found', 'bone', 'in', 'my', 'chicken', 'nugget', 'not', 'cool'],
#  ['like',
#   'said',
#   'my',
#   'back',
#   'still',
#   'fucking',
#   'hurts',
#   'and',
#   'going',
#   'to',
#   'complain',
#   'about',
#   'it',
#   'like',
#   'no',
#   'one',
#   'business'],
#  ['my',
#   'aunties',
#   'dog',
#   'is',
#   'getting',
#   'put',
#   'down',
#   'hes',
#   'my',
#   'dogs',
#   'brother',
#   'aswell'],
#  ['my',
#   'head',
#   'feels',
#   'like',
#   'its',
#   'going',
#   'to',
#   'explode',
#   'mmm',
#   'what',
#   'horrendous',
#   'image',
#   'the',
#   'mess'],
#  ['my', 'head', 'is', 'killing', 'meee'],
#  ['my',
#   'name',
#   'is',
#   'amy',
#   'only',
#   'three',
#   'my',
#   'eyes',
#   'are',
#   'swollen',
#   'cannot',
#   'see',
#   'must',
#   'be',
#   'stupid',
#   'must',
#   'be',
#   'bad',
#   'what'],
#  ['my',
#   'picture',
#   'with',
#   'kris',
#   'karmada',
#   'is',
#   'gone',
#   'forever',
#   'its',
#   'not',
#   'in',
#   'my',
#   'comments',
#   'on',
#   'my',
#   'mysapce',
#   'or',
#   'on',
#   'my'],
#  ['confirmed',
#   'missing',
#   'air',
#   'france',
#   'flight',
#   'has',
#   'crashed',
#   'in',
#   'the',
#   'atlantic'],
#  ['about',
#   'of',
#   'my',
#   'myspace',
#   'comments',
#   'are',
#   'gone',
#   'cause',
#   'someone',
#   'hacked',
#   'onto',
#   'wills',
#   'account',
#   'and',
#   'kept',
#   'abusing',
#   'others',
#   'so',
#   'he',
#   'had',
#   'to',
#   'delete',
#   'it'],
#  ['about',
#   'school',
#   'it',
#   'will',
#   'all',
#   'be',
#   'over',
#   'soon',
#   'can',
#   'not',
#   'wait',
#   'to',
#   'celebrate',
#   'stres',
#   'till',
#   'then'],
#  ['abt',
#   'missing',
#   'air',
#   'france',
#   'plane',
#   'follow',
#   'here',
#   'for',
#   'best',
#   'air',
#   'news',
#   'source'],
#  ['afi', 'are', 'not', 'at', 'reading', 'til', 'sunday', 'this', 'sucks'],
#  ['after',
#   'crap',
#   'night',
#   'was',
#   'looking',
#   'forward',
#   'to',
#   'being',
#   'cheered',
#   'up',
#   'but',
#   'no',
#   'never',
#   'mind'],
#  ['ah',
#   'the',
#   'postman',
#   'did',
#   'not',
#   'have',
#   'my',
#   'package',
#   'what',
#   'am',
#   'goon',
#   'to',
#   'do',
#   'for',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'day'],
#  ['airport',
#   'express',
#   'does',
#   'not',
#   'rock',
#   'enough',
#   'to',
#   'allow',
#   'wireless',
#   'scanning',
#   'with',
#   'the',
#   'canon',
#   'pixma',
#   'mx',
#   'but',
#   'otherwise',
#   'it',
#   'wireless',
#   'goodness'],
#  ['alistair',
#   'friends',
#   'are',
#   'all',
#   'in',
#   'the',
#   'kitchen',
#   'and',
#   'in',
#   'my',
#   'pjs',
#   'just',
#   'want',
#   'cup',
#   'of',
#   'tea',
#   'dammit'],
#  ['all', 'day', 'no', 'play'],
#  ['all',
#   'dressed',
#   'up',
#   'and',
#   'no',
#   'bicyclist',
#   'for',
#   'monday',
#   'nite',
#   'ride',
#   'henderson',
#   'ky'],
#  ['all',
#   'want',
#   'is',
#   'my',
#   'ma',
#   'in',
#   'my',
#   'arms',
#   'that',
#   'all',
#   'want',
#   'is',
#   'you',
#   'in',
#   'my',
#   'arms'],
#  ['all',
#   'my',
#   'friends',
#   'are',
#   'gone',
#   'haley',
#   'katie',
#   'camp',
#   'paris',
#   'moms',
#   'landin',
#   'ayonna',
#   'aunts',
#   'moms',
#   'im',
#   'so',
#   'bored'],
#  ['all',
#   'nighter',
#   'yeeeeeeeeeeeessshhhh',
#   'what',
#   'nightmare',
#   'up',
#   'coming',
#   'weeks',
#   'cannot',
#   'wait',
#   'to',
#   'graduate'],
#  ['all',
#   'those',
#   'non',
#   'robsten',
#   'posts',
#   'are',
#   'making',
#   'me',
#   'sad',
#   'mean',
#   'knew',
#   'that',
#   'but',
#   'to',
#   'see',
#   'it',
#   'from',
#   'others',
#   'in',
#   'words',
#   'so',
#   'sad'],
#  ['allison', 'didnt', 'win', 'she', 'should', 'have'],
#  ['almost', 'time', 'to', 'leave'],
#  ['already',
#   'getting',
#   'sleepy',
#   'really',
#   'want',
#   'to',
#   'get',
#   'my',
#   'psych',
#   'quizzes',
#   'done',
#   'tonight'],
#  ['am',
#   'losing',
#   'my',
#   'mind',
#   'cause',
#   'wanna',
#   'see',
#   'my',
#   'tc',
#   'on',
#   'tv',
#   'right',
#   'now',
#   'this',
#   'min',
#   'fu',
#   'want',
#   'see',
#   'candygirls',
#   'not',
#   'daisy',
#   'dammit'],
#  ['am',
#   'sad',
#   'to',
#   'say',
#   'did',
#   'not',
#   'get',
#   'my',
#   'results',
#   'today',
#   'somehow',
#   'the',
#   'school',
#   'forgot',
#   'to',
#   'mail',
#   'my',
#   'results',
#   'to',
#   'me',
#   'typical',
#   'ugh'],
#  ['and', 'how', 'can', 'you', 'mend', 'broken', 'heart'],
#  ['and',
#   'think',
#   'that',
#   'why',
#   'felt',
#   'really',
#   'sick',
#   'and',
#   'depressed',
#   'in',
#   'school',
#   'today',
#   'cuz',
#   'of',
#   'all',
#   'the',
#   'stress',
#   'glad',
#   'got',
#   'that',
#   'off',
#   'my',
#   'chest'],
#  ['and',
#   'was',
#   'just',
#   'starting',
#   'to',
#   'get',
#   'confident',
#   'in',
#   'myself',
#   'you',
#   'have',
#   'torn',
#   'me',
#   'down'],
#  ['another', 'mins'],
#  ['another', 'early', 'day'],
#  ['another',
#   'father',
#   'day',
#   'weekend',
#   'do',
#   'not',
#   'get',
#   'to',
#   'spend',
#   'with',
#   'my',
#   'dad'],
#  ['anticipating', 'tough', 'day', 'ahead'],
#  ['anyone',
#   'know',
#   'if',
#   'ghostbusters',
#   'is',
#   'region',
#   'free',
#   'on',
#   'and',
#   'where',
#   'to',
#   'get',
#   'us',
#   'copy',
#   'in',
#   'britain',
#   'if',
#   'it',
#   'is'],
#  ['ove'],
#  ['what', 'wrong', 'wit', 'it'],
#  ['alergic',
#   'nose',
#   'itchy',
#   'and',
#   'eyes',
#   'burning',
#   'hope',
#   'it',
#   'getting',
#   'better',
#   'soon'],
#  ['and', 'they', 'keep', 'on', 'coming', 'xox'],
#  ['another', 'expensive', 'weekend', 'trip', 'to', 'the', 'vet'],
#  ['are',
#   'there',
#   'any',
#   'parties',
#   'tonight',
#   'im',
#   'hella',
#   'bored',
#   'at',
#   'home',
#   'and',
#   'its',
#   'seems',
#   'like',
#   'everyone',
#   'is',
#   'busy',
#   'lammmmeee'],
#  ['but', 'chilli', 'prawns', 'will', 'make', 'the', 'pain', 'better'],
#  ['daughter',
#   'beloved',
#   'diabetic',
#   'dwarf',
#   'hamster',
#   'died',
#   'in',
#   'her',
#   'hands',
#   'this',
#   'morning',
#   'all',
#   'creatures',
#   'are',
#   'worthy',
#   'of',
#   'love'],
#  ['dd', 'has', 'pinkeye', 'not', 'fun'],
#  ['farrah', 'fawcett', 'dies', 'of', 'cancer', 'at', 'abc', 'news', 'via'],
#  ['feeling', 'hopeless', 'and', 'useless'],
#  ['forgot', 'my', 'lunch', 'at', 'home'],
#  ['general', 'motors', 'sold', 'hummer'],
#  ['goodnight'],
#  ['gooood', 'night', 'must', 'prepare', 'for', 'tomorrows', 'meeting', 'now'],
#  ['great',
#   'im',
#   'bored',
#   'at',
#   'the',
#   'moment',
#   'and',
#   'just',
#   'have',
#   'no',
#   'idea',
#   'on',
#   'what',
#   'to',
#   'do',
#   'missing',
#   'boyfie',
#   'too',
#   'damn'],
#  ['five',
#   'guys',
#   'locations',
#   'closed',
#   'after',
#   'visit',
#   'from',
#   'em',
#   'inside',
#   'edition',
#   'em',
#   'rat',
#   'patrol'],
#  ['am', 'actually', 'crying', 'now', 'because', 'of', 'sore', 'throat'],
#  ['feel',
#   'irresponsible',
#   'and',
#   'sort',
#   'of',
#   'horrible',
#   'marshmallows',
#   'unless',
#   'otherwise',
#   'stated',
#   'have',
#   'gelatin',
#   'fuck'],
#  ['miss', 'my', 'brother', 'worry', 'about', 'him'],
#  ['need', 'to', 'think', 'of', 'something', 'else', 'first'],
#  ['wanted', 'julian', 'to', 'win'],
#  ['jus', 'got', 'some', 'bad', 'news'],
#  ['just', 'mean'],
#  ['limp', 'bizkit', 'rollin', 'songstuckinmyheadwheniwokeup'],
#  ['love', 'save', 'the', 'empty'],
#  ['my', 'camera', 'broke'],
#  ['my', 'parents', 'left'],
#  ['nadal',
#   'is',
#   'out',
#   'french',
#   'open',
#   'now',
#   'to',
#   'my',
#   'back',
#   'up',
#   'go',
#   'andy',
#   'roddick'],
#  ['no',
#   'ass',
#   'beatings',
#   'checked',
#   'out',
#   'playhouse',
#   'in',
#   'baltimore',
#   'this',
#   'weekend',
#   'as',
#   'well',
#   'feeling',
#   'quite',
#   'rested',
#   'and',
#   'bit',
#   'out',
#   'of',
#   'sorts'],
#  ['nothing'],
#  ['ok',
#   'we',
#   'll',
#   'talk',
#   'about',
#   'your',
#   'boyfriends',
#   'and',
#   'stuff',
#   'tomorrow',
#   'lmao',
#   'and',
#   'we',
#   'll',
#   'talk',
#   'for',
#   'real',
#   'soon',
#   'too',
#   'wooo',
#   'hehe',
#   'ilysfm',
#   'doodle',
#   'xxxx'],
#  ['server',
#   'problems',
#   'motivating',
#   'me',
#   'to',
#   'change',
#   'hosting',
#   'providers',
#   'though',
#   'fb'],
#  ['shakes', 'head'],
#  ['shock',
#   'loss',
#   'to',
#   'sparks',
#   'bummer',
#   'had',
#   'great',
#   'game',
#   'but',
#   'shock',
#   'too',
#   'many',
#   'injuries',
#   'to',
#   'start',
#   'the',
#   'season',
#   'rematch',
#   'monday'],
#  ['some',
#   'asshole',
#   'got',
#   'hold',
#   'of',
#   'my',
#   'email',
#   'and',
#   'signed',
#   'me',
#   'up',
#   'for',
#   'all',
#   'this',
#   'spam',
#   'mail',
#   'ughhhh',
#   'it',
#   'non',
#   'stop',
#   'anyone',
#   'have',
#   'spam',
#   'blocker'],
#  ['someone',
#   'just',
#   'said',
#   'ast',
#   'least',
#   'your',
#   'pretty',
#   'thanks',
#   'but',
#   'but',
#   'being',
#   'pretty',
#   'gets',
#   'you',
#   'nowhere',
#   'you',
#   'have',
#   'to',
#   'much',
#   'integrity'],
#  ['myspace',
#   'people',
#   'can',
#   'get',
#   'really',
#   'angry',
#   'if',
#   'do',
#   'not',
#   'answer',
#   'them',
#   'right',
#   'away',
#   'ja'],
#  ['never', 'get', 'any', 'photo', 'comments', 'on', 'space', 'and', 'more'],
#  ['no', 'tickets', 'in', 'germany', 'for', 'the', 'miley', 'cyrus', 'tour'],
#  ['photo', 'shoot', 'rained', 'out', 'oh', 'well', 'back', 'to', 'post'],
#  ['rip',
#   'charles',
#   'the',
#   'world',
#   'is',
#   'with',
#   'one',
#   'less',
#   'fine',
#   'fellow'],
#  ['rsl',
#   'was',
#   'at',
#   'the',
#   'paley',
#   'talk',
#   'now',
#   'even',
#   'more',
#   'depressed',
#   'could',
#   'not',
#   'get',
#   'ticket',
#   'oh',
#   'wells'],
#  ['so', 'bored'],
#  ['so', 'much', 'for', 'good', 'weekend'],
#  ['the',
#   'hotel',
#   'does',
#   'not',
#   'know',
#   'where',
#   'it',
#   'is',
#   'either',
#   'that',
#   'was',
#   'my',
#   'favorite',
#   'how',
#   'poopie',
#   'is',
#   'that'],
#  ['thelovelybones', 'plan', 'on', 'owning', 'this', 'don', 'judge', 'me'],
#  ['this',
#   'year',
#   'million',
#   'children',
#   'from',
#   'hunger',
#   'related',
#   'causes'],
#  ['ticketsandpassports',
#   'lmao',
#   'your',
#   'not',
#   'nerd',
#   'think',
#   'its',
#   'cool',
#   'when',
#   'guys',
#   'like',
#   'anime'],
#  ['to',
#   'all',
#   'the',
#   'mothers',
#   'whose',
#   'day',
#   'may',
#   'not',
#   'be',
#   'so',
#   'happy',
#   'god',
#   'loves',
#   'you',
#   'tlc',
#   'waterfalls'],
#  ['today',
#   'is',
#   'not',
#   'good',
#   'day',
#   'but',
#   'guess',
#   'laying',
#   'around',
#   'the',
#   'house',
#   'in',
#   'your',
#   'undies',
#   'is',
#   'not',
#   'so',
#   'bad'],
#  ['went',
#   'to',
#   'maggie',
#   'bday',
#   'party',
#   'came',
#   'home',
#   'without',
#   'my',
#   'phone',
#   'feel',
#   'lost',
#   'and',
#   'reaallly',
#   'confused',
#   'but',
#   'thats',
#   'just',
#   'the',
#   'booze',
#   'talking'],
#  ['when', 'will', 'rb', 'get', 'an', 'australian', 'release', 'date'],
#  ['my',
#   'grandma',
#   'just',
#   'told',
#   'me',
#   'she',
#   'thinks',
#   'stupid',
#   'well',
#   'hey',
#   'thanks'],
#  ['betseyjohnson',
#   'why',
#   'are',
#   'you',
#   'doing',
#   'this',
#   'to',
#   'me',
#   'this',
#   'necklace',
#   'is',
#   'rather',
#   'than',
#   'the',
#   'usual',
#   'want',
#   'it'],
#  ['imisscath',
#   'imisscath',
#   'imisscath',
#   'imisscath',
#   'imisscath',
#   'imisscath',
#   'imisscath',
#   'imisscath',
#   'imisscath',
#   'imisscath',
#   'imisscath',
#   'imisscath'],
#  ['wimax', 'no', 'signal', 'detected', 'here', 'at', 'the', 'gardens'],
#  ['trackle'],
#  ['beach', 'ball', 'fail', 'lol', 'fail'],
#  ['it', 'raining', 'again', 'supertramp'],
#  ['you', 'have', 'to', 'do', 'it', 'all', 'alone'],
#  ['apparently',
#   'the',
#   'new',
#   'is',
#   'the',
#   'same',
#   'build',
#   'as',
#   'the',
#   'gm',
#   'meaning',
#   'll',
#   'likely',
#   'have',
#   'the',
#   'same',
#   'minute',
#   'issues',
#   'was',
#   'having',
#   'with',
#   'the',
#   'gm',
#   'mlia'],
#  ['archie',
#   'annoying',
#   'me',
#   'this',
#   'morning',
#   'says',
#   'hogged',
#   'the',
#   'bed',
#   'all',
#   'night',
#   'and',
#   'will',
#   'not',
#   'get',
#   'up',
#   'for',
#   'his',
#   'shower',
#   'him',
#   'and',
#   'his',
#   'little',
#   'black',
#   'kettle',
#   'self'],
#  ['are', 'you', 'ok'],
#  ['argh',
#   'the',
#   'speakers',
#   'on',
#   'my',
#   'macbook',
#   'are',
#   'screwing',
#   'up',
#   'and',
#   'slowly',
#   'dying'],
#  ['at',
#   'chris',
#   'brown',
#   'honestly',
#   'dont',
#   'feel',
#   'bad',
#   'for',
#   'rihanna',
#   'anyways',
#   'out',
#   'nd',
#   'such'],
#  ['at', 'last', 'night'],
#  ['at', 'work', 'fuck'],
#  ['at',
#   'work',
#   'and',
#   'got',
#   'loads',
#   'to',
#   'do',
#   'leave',
#   'today',
#   'toodles',
#   'lufflies',
#   'xxx'],
#  ['attempting',
#   'to',
#   'get',
#   'other',
#   'people',
#   'on',
#   'twitter',
#   'other',
#   'than',
#   'cate',
#   'to',
#   'talk',
#   'to',
#   'me',
#   'but',
#   'it',
#   'is',
#   'failing'],
#  ['aw', 'toy', 'story', 'is', 'coming', 'out', 'next', 'year'],
#  ['awesome'],
#  ['aww', 'gota', 'do', 'homework'],
#  ['aww', 'someone', 'borrowed', 'it', 'without', 'telling', 'me'],
#  ['is',
#   'at',
#   'work',
#   'back',
#   'to',
#   'making',
#   'kandie',
#   'with',
#   'the',
#   'little',
#   'ones'],
#  ['in',
#   'genetics',
#   'so',
#   'that',
#   'towards',
#   'my',
#   'gpa',
#   'what',
#   'really',
#   'sucks',
#   'is',
#   'that',
#   'got',
#   'in',
#   'the',
#   'class',
#   'and',
#   'an',
#   'is'],
#  ['baby', 'died', 'last', 'night', 'day'],
#  ['baby',
#   'girl',
#   'so',
#   'upset',
#   'not',
#   'where',
#   'need',
#   'to',
#   'be',
#   'with',
#   'my',
#   'sewing',
#   'and',
#   'it',
#   'almost',
#   'pm',
#   'and',
#   'finally',
#   'eating',
#   'little',
#   'dinner',
#   'sigh'],
#  ['back', 'from', 'cali', 'missing', 'itttttt'],
#  ['back', 'pain'],
#  ['bad', 'day', 'day', 'broken', 'glasses', 'rainy', 'weather', 'uof'],
#  ['bad', 'night', 'for', 'the', 'pens'],
#  ['bad',
#   'timing',
#   'new',
#   'mommy',
#   'just',
#   'called',
#   'for',
#   'newborn',
#   'pictures',
#   'and',
#   'can',
#   'not',
#   'fit',
#   'the',
#   'baby',
#   'into',
#   'my',
#   'schedule',
#   'no',
#   'matter',
#   'how',
#   'hard',
#   'try'],
#  ['bank', 'account', 'is', 'negative'],
#  ['bcd', 'closed', 'guess', 'nodaji', 'it', 'is'],
#  ['bed',
#   'gotta',
#   'get',
#   'up',
#   'early',
#   'only',
#   'more',
#   'days',
#   'of',
#   'this',
#   'bullshit',
#   'summer'],
#  ['bed', 'time'],
#  ['bedss', 'gayyyy', 'oh', 'well', 'goodnight', 'people', 'and'],
#  ['being', 'afraid', 'of', 'food', 'is', 'an', 'eating', 'disorder', 'right'],
#  ['being',
#   'told',
#   'im',
#   'beautiful',
#   'doesnt',
#   'make',
#   'my',
#   'tummy',
#   'better'],
#  ['besides',
#   'that',
#   'great',
#   'graduation',
#   'day',
#   'finaly',
#   'made',
#   'it',
#   'highschool',
#   'graduate',
#   'moms',
#   'word',
#   'chapter',
#   'close',
#   'keep',
#   'pushing',
#   'foward'],
#  ['still',
#   'no',
#   'phone',
#   'bukas',
#   'pa',
#   'raw',
#   'in',
#   'the',
#   'afternoon',
#   'oh',
#   'well',
#   'survived',
#   'days',
#   'what',
#   'one',
#   'more',
#   'day',
#   'another',
#   'day',
#   'another',
#   'destiny'],
#  ['the', 'iphone', 'will', 'be', 'out', 'of', 'commission', 'for', 'while'],
#  ['things',
#   'are',
#   'not',
#   'good',
#   'in',
#   'my',
#   'head',
#   'may',
#   'not',
#   'be',
#   'around',
#   'lot',
#   'this',
#   'weekend'],
#  ['try',
#   'and',
#   'enjoy',
#   'ur',
#   'family',
#   'am',
#   'here',
#   'if',
#   'need',
#   'anything',
#   'anything',
#   'love',
#   'you',
#   'sis',
#   'be',
#   'brave',
#   'know',
#   'strong',
#   'ur',
#   'in',
#   'my',
#   'prayers'],
#  ['twitter', 'wont', 'let', 'me', 'send', 'replies', 'today', 'boo', 'hoo'],
#  ['ughhh'],
#  ['uva', 'baseball', 'come', 'on', 'boys', 'you', 'can', 'do', 'it'],
#  ['water', 'works', 'are', 'gonna', 'start'],
#  ['well',
#   'wrote',
#   'missive',
#   'post',
#   'about',
#   'last',
#   'night',
#   'and',
#   'all',
#   'the',
#   'things',
#   'that',
#   'happened',
#   'it',
#   'got',
#   'deleted',
#   'tho',
#   'by'],
#  ['well', 'guess', 'knew', 'it', 'was', 'going', 'to', 'break', 'sometime'],
#  ['why', 'is', 'it', 'raining'],
#  ['why', 'me'],
#  ['squaresp',
#   'squarespac',
#   'squarespace',
#   'trackle',
#   'giveaways',
#   'giveway',
#   'iphonegiveway',
#   'squarespace',
#   'squarespce',
#   'trackle'],
#  ['you',
#   'were',
#   'asleep',
#   'while',
#   'gathered',
#   'my',
#   'things',
#   'in',
#   'the',
#   'dark',
#   'the',
#   'burns',
#   'on',
#   'my',
#   'fingers',
#   'were',
#   'all',
#   'that',
#   'was',
#   'left',
#   'of',
#   'the',
#   'spark'],
#  ['bbc',
#   'news',
#   'uk',
#   'maps',
#   'climate',
#   'change',
#   'forecasts',
#   'the',
#   'picture',
#   'it',
#   'paints',
#   'is',
#   'an',
#   'alarming',
#   'one'],
#  ['giving',
#   'up',
#   'on',
#   'you',
#   'do',
#   'not',
#   'care',
#   'how',
#   'you',
#   'mess',
#   'up',
#   'your',
#   'life',
#   'now'],
#  ['meteorologists',
#   'predict',
#   'chilly',
#   'rainy',
#   'midsummer',
#   'news',
#   'in',
#   'finland',
#   'yle',
#   'fi',
#   'thunder'],
#  ['angry', 'mixed', 'motions', 'but', 'soo', 'frustrated'],
#  ['mood', 'am', 'in'],
#  ['hugs'],
#  ['sends', 'you', 'hugs'],
#  ['tear'],
#  ['cries',
#   'so',
#   'depressed',
#   'thanks',
#   'to',
#   'you',
#   'my',
#   'angel',
#   'gonna',
#   'find',
#   'someone',
#   'someday',
#   'who',
#   'might',
#   'actually',
#   'treat',
#   'me',
#   'well'],
#  ['on',
#   'my',
#   'way',
#   'to',
#   'the',
#   'doctors',
#   'with',
#   'my',
#   'duo',
#   'my',
#   'ass',
#   'has',
#   'not',
#   'even',
#   'had',
#   'breakfast',
#   'yet',
#   'lol'],
#  ['sob', 'must', 'be', 'in', 'bed'],
#  ['wishes', 'she', 'was', 'at', 'summer', 'jam'],
#  ['school',
#   'grrr',
#   'im',
#   'not',
#   'in',
#   'the',
#   'mood',
#   'to',
#   'take',
#   'my',
#   'make',
#   'up',
#   'back',
#   'off',
#   'then',
#   'put',
#   'it',
#   'on',
#   'again',
#   'when',
#   'the',
#   'teachers',
#   'leave'],
#  ['sunday', 'is', 'over'],
#  ['why', 'the', 'jonas', 'are', 'bad', 'with', 'us', 'come', 'to', 'paraguay'],
#  ['ughh',
#   'anybody',
#   'wanna',
#   'come',
#   'to',
#   'my',
#   'house',
#   'and',
#   'cook',
#   'my',
#   'mom',
#   'is',
#   'leavin',
#   'for',
#   'work',
#   'and',
#   'aint',
#   'cook',
#   'me',
#   'shit',
#   'can',
#   'not',
#   'trust',
#   'dem',
#   'hoes'],
#  ['do', 'not', 'know', 'what', 'to', 'do'],
#  ['think', 'lost', 'my', 'spanish', 'book'],
#  ['life',
#   'can',
#   'be',
#   'so',
#   'complicated',
#   'know',
#   'god',
#   'has',
#   'plan',
#   'just',
#   'have',
#   'to',
#   'trust',
#   'in',
#   'him'],
#  ['oh',
#   'well',
#   'at',
#   'least',
#   'suzumiya',
#   'haruhi',
#   'no',
#   'yuuutsu',
#   'is',
#   'on',
#   'air'],
#  ['not', 'really', 'good', 'night', 'guys', 'buu', 'huu'],
#  ['did',
#   'not',
#   'get',
#   'cast',
#   'in',
#   'but',
#   'will',
#   'keep',
#   'looking',
#   'for',
#   'some',
#   'dance',
#   'opportunities',
#   'need',
#   'some',
#   'exercise'],
#  ['the',
#   'ground',
#   'around',
#   'me',
#   'is',
#   'wet',
#   'looked',
#   'up',
#   'to',
#   'see',
#   'if',
#   'any',
#   'drops',
#   'fall',
#   'on',
#   'my',
#   'face',
#   'it',
#   'was',
#   'drizzle',
#   'all',
#   'around',
#   'but',
#   'am',
#   'missing',
#   'my',
#   'drops'],
#  ['forgot',
#   'to',
#   'bring',
#   'my',
#   'new',
#   'sharpie',
#   'pens',
#   'to',
#   'school',
#   'today',
#   'booo'],
#  ['omg',
#   'my',
#   'celly',
#   'is',
#   'off',
#   'this',
#   'has',
#   'not',
#   'happened',
#   'to',
#   'me',
#   'in',
#   'years',
#   'wtf',
#   'gota',
#   'get',
#   'my',
#   'bill',
#   'paid'],
#  ['this', 'is', 'so', 'horrible'],
#  ['where',
#   'ius',
#   'that',
#   'one',
#   'person',
#   'that',
#   'can',
#   'make',
#   'me',
#   'smile'],
#  ['this', 'tweetdeck', 'is', 'killing', 'me', 'hate', 'it'],
#  ['last', 'fm', 'not', 'working'],
#  ['saw',
#   'that',
#   'earlier',
#   'can',
#   'not',
#   'even',
#   'comprehend',
#   'what',
#   'that',
#   'couple',
#   'were',
#   'feeling',
#   'really',
#   'tragic'],
#  ['hope',
#   'it',
#   'not',
#   'actually',
#   'on',
#   'here',
#   'birthday',
#   'that',
#   'she',
#   'getting',
#   'shots'],
#  ['signature',
#   'has',
#   'rubbed',
#   'off',
#   'my',
#   'mondayeyes',
#   'bracelet',
#   'at',
#   'least',
#   'have',
#   'plenty',
#   'of',
#   'autographs',
#   'from',
#   'him',
#   'but',
#   'still',
#   'sad',
#   'day'],
#  ['alllllan', 'ruins', 'my', 'lifeeee'],
#  ['was',
#   'want',
#   'to',
#   'buy',
#   'the',
#   'sims',
#   'but',
#   'it',
#   'sold',
#   'out',
#   'wtf',
#   'haha'],
#  ['just'],
#  ['yep',
#   'have',
#   'things',
#   'my',
#   'way',
#   'all',
#   'the',
#   'time',
#   'am',
#   'selfish',
#   'everything',
#   'revolves',
#   'around',
#   'me',
#   'yep',
#   'im',
#   'bitch',
#   'great',
#   'for',
#   'me'],
#  ['do',
#   'not',
#   'wanna',
#   'get',
#   'rid',
#   'of',
#   'twitter',
#   'you',
#   'guys',
#   'are',
#   'too',
#   'cool'],
#  ['try',
#   'try',
#   'so',
#   'hard',
#   'and',
#   'seem',
#   'to',
#   'get',
#   'no',
#   'credit',
#   'for',
#   'it',
#   'wats',
#   'the',
#   'prob'],
#  ['wide',
#   'awake',
#   'but',
#   'dont',
#   'actually',
#   'wanna',
#   'go',
#   'to',
#   'school',
#   'xxx'],
#  ['dream', 'beautiful'],
#  ['now', 'only', 'have', 'one', 'roommate'],
#  ['im',
#   'givin',
#   'myself',
#   'minutes',
#   'to',
#   'turn',
#   'that',
#   'frown',
#   'upside',
#   'down'],
#  ['cant', 'even', 'say', 'word', 'right', 'now'],
#  ['why',
#   'am',
#   'so',
#   'sad',
#   'becuz',
#   'of',
#   'or',
#   'becuz',
#   'of',
#   'the',
#   'exam',
#   'think',
#   'becuz',
#   'of'],
#  ['frustrated'],
#  ['and',
#   'feel',
#   'shallow',
#   'breath',
#   'that',
#   'squeezes',
#   'past',
#   'the',
# ...
#  ['am', 'crying', 'you', 'all', 'river'],
#  ['am',
#   'not',
#   'awake',
#   'yet',
#   'and',
#   'do',
#   'not',
#   'get',
#   'to',
#   'workout',
#   'until',
#   'this',
#   'afternoon',
#   'because',
#   'have',
#   'to',
#   'go',
#   'to',
#   'the',
#   'nashville',
#   'airport'],
#  ['am',
#   'so',
#   'sick',
#   'of',
#   'this',
#   'have',
#   'chest',
#   'pains',
#   'stomach',
#   'pains',
#   'sickness',
#   'and',
#   'im',
#   'exhausted',
#   'cant',
#   'they',
#   'make',
#   'me',
#   'better'],
#  ['ate',
#   'too',
#   'much',
#   'now',
#   'can',
#   'not',
#   'sleep',
#   'because',
#   'feel',
#   'sick',
#   'and',
#   'there',
#   'are',
#   'lot',
#   'of',
#   'sirens'],
#  ['can',
#   'almost',
#   'hear',
#   'my',
#   'wallet',
#   'saying',
#   'here',
#   'here',
#   'but',
#   'can',
#   'not',
#   'find',
#   'her'],
#  ['can',
#   'already',
#   'tell',
#   'that',
#   'it',
#   'going',
#   'to',
#   'be',
#   'one',
#   'of',
#   'those',
#   'days'],
#  ['can', 'find', 'my', 'eye', 'shadow', 'pursh'],
#  ['can', 'not', 'deal', 'with', 'this', 'again'],
#  ['can', 'not', 'find', 'my', 'name', 'badge'],
#  ['cant',
#   'get',
#   'kristen',
#   'srewart',
#   'to',
#   'add',
#   'me',
#   'lol',
#   'she',
#   'prob',
#   'thinks',
#   'im',
#   'stalker',
#   'lol'],
#  ['can', 'not', 'get', 'my', 'new', 'picture', 'to', 'show', 'up'],
#  ['can', 'not', 'go', 'too', 'much', 'to', 'do'],
#  ['can', 'not', 'hear', 'damn', 'word', 'that', 'tbs', 'is', 'singing'],
#  ['cant', 'make', 'it', 'today'],
#  ['cant',
#   'stand',
#   'ma',
#   'brother',
#   'he',
#   'got',
#   'the',
#   'new',
#   'jordans',
#   'want',
#   'tear'],
#  ['can',
#   'not',
#   'wait',
#   'til',
#   'my',
#   'lil',
#   'man',
#   'is',
#   'here',
#   'more',
#   'weeks'],
#  ['could', 'have', 'stayed', 'cell'],
#  ['did',
#   'not',
#   'get',
#   'to',
#   'see',
#   'beth',
#   'rachel',
#   'or',
#   'ginny',
#   'today',
#   'll',
#   'see',
#   'them',
#   'tomorrow'],
#  ['didnt', 'get', 'head', 'boy', 'oh', 'well'],
#  ['did',
#   'not',
#   'get',
#   'to',
#   'cook',
#   'instead',
#   'had',
#   'dogs',
#   'it',
#   'was',
#   'ok',
#   'guess',
#   'kinda',
#   'tired',
#   'but',
#   'not',
#   'sleepy',
#   'btw',
#   'so',
#   'my',
#   'new',
#   'book',
#   'lol'],
#  ['dislike',
#   'myself',
#   'right',
#   'now',
#   'maybe',
#   'letter',
#   'to',
#   'you',
#   'will',
#   'help',
#   'bit',
#   'gonna',
#   'lay',
#   'down'],
#  ['am', 'meetings', 'suck'],
#  ['am', 'so', 'upset', 'but', 'wont', 'tell', 'you'],
#  ['am',
#   'suddenly',
#   'sad',
#   'and',
#   'tired',
#   'also',
#   'can',
#   'anyone',
#   'think',
#   'of',
#   'great',
#   'hero',
#   'anthems',
#   'counterpart',
#   'to',
#   'heroine'],
#  ['and', 'have', 'to', 'get', 'going', 'mcrchat'],
#  ['and',
#   'so',
#   'it',
#   'begins',
#   'again',
#   'll',
#   'be',
#   'at',
#   'subway',
#   'if',
#   'you',
#   'need',
#   'me',
#   'sigh',
#   'sigh',
#   'sigh'],
#  ['animal',
#   'crossing',
#   'crashed',
#   'on',
#   'me',
#   'after',
#   'minutes',
#   'of',
#   'work',
#   'at',
#   'least',
#   'still',
#   'have',
#   'my',
#   'silver',
#   'shovel'],
#  ['another',
#   'day',
#   'of',
#   'running',
#   'today',
#   'is',
#   'fresh',
#   'to',
#   'death',
#   'friday',
#   'everyday',
#   'is',
#   'fresh',
#   'to',
#   'death',
#   'friday',
#   'me',
#   'ha',
#   'ha',
#   'lol'],
#  ['another',
#   'eye',
#   'infection',
#   'my',
#   'left',
#   'eye',
#   'is',
#   'contaminated',
#   'swear',
#   'get',
#   'eye',
#   'infections',
#   'every',
#   'month',
#   'haha'],
#  ['another',
#   'one',
#   'and',
#   'ill',
#   'expect',
#   'more',
#   'to',
#   'come',
#   'way',
#   'to',
#   'go',
#   'dy',
#   'aarrrrggghhhhh'],
#  ['another',
#   'saturday',
#   'without',
#   'mo',
#   'glad',
#   'rachel',
#   'is',
#   'coming',
#   'over'],
#  ['ants', 'are', 'evil'],
#  ['apparently',
#   'going',
#   'to',
#   'rain',
#   'please',
#   'do',
#   'not',
#   'rain',
#   'stay',
#   'sunny',
#   'please'],
#  ['apparently',
#   'you',
#   'only',
#   'need',
#   'like',
#   'lines',
#   'on',
#   'the',
#   'last',
#   'question',
#   'did',
#   'whole',
#   'page',
#   'uggggggghhhh'],
#  ['arghhhhhhhhhhhhhhh'],
#  ['as',
#   'my',
#   'old',
#   'comp',
#   'duied',
#   'on',
#   'me',
#   'weeks',
#   'ago',
#   'but',
#   'not',
#   'to',
#   'fear',
#   'will',
#   'find',
#   'way',
#   'to',
#   'post',
#   'up',
#   'music',
#   'no',
#   'matter',
#   'what'],
#  ['at', 'atl', 'trance', 'scene'],
#  ['at',
#   'katy',
#   'perry',
#   'delaying',
#   'her',
#   'birmingham',
#   'gig',
#   'for',
#   'nearly',
#   'months'],
#  ['at', 'least', 'today', 'is', 'ok'],
#  ['at', 'the', 'doctors', 'ian'],
#  ['at',
#   'the',
#   'hosp',
#   'waiting',
#   'on',
#   'my',
#   'taxi',
#   'been',
#   'waitin',
#   'over',
#   'mins',
#   'now',
#   'can',
#   'not',
#   'believe',
#   'crying'],
#  ['at', 'when', 'pac', 'got', 'shot', 'in', 'vegas'],
#  ['at', 'work'],
#  ['at', 'work', 'tears'],
#  ['aw',
#   'damn',
#   'somebody',
#   'hit',
#   'tiffany',
#   'on',
#   'nxt',
#   'weeks',
#   'episode',
#   'or',
#   'somethin',
#   'hellllllll',
#   'no',
#   'def',
#   'watchin',
#   'nxt',
#   'week',
#   'lol'],
#  ['aw', 'hate', 'my', 'heart', 'sooo', 'soo', 'much', 'but', 'it', 'ok'],
#  ['aw', 'just', 'missed', 'kim', 'possible'],
#  ['awwe',
#   'it',
#   'over',
#   'but',
#   'for',
#   'shuch',
#   'short',
#   'storm',
#   'we',
#   'had',
#   'it',
#   'all',
#   'thunder',
#   'lightning',
#   'wind',
#   'little',
#   'bit',
#   'of',
#   'rain',
#   'brief',
#   'blackout',
#   'more'],
#  ['moodswings'],
#  ['babe', 'miss', 'you', 'how', 'was', 'wet', 'wild'],
#  ['baby', 'ethans', 'leaving', 'for', 'the', 'pi', 'tomorrow'],
#  ['baby',
#   'so',
#   'sorry',
#   'your',
#   'back',
#   'hurts',
#   'maybe',
#   'when',
#   'you',
#   'come',
#   'here',
#   'can',
#   'oil',
#   'you',
#   'up',
#   'and',
#   'rub',
#   'you',
#   'down'],
#  ['back', 'freakin', 'hurts'],
#  ['back',
#   'to',
#   'college',
#   'for',
#   'me',
#   'now',
#   'havnt',
#   'had',
#   'any',
#   'sleep',
#   'very',
#   'tierd',
#   'hope',
#   'its',
#   'nice',
#   'and',
#   'sunny',
#   'day'],
#  ['back',
#   'to',
#   'maths',
#   'wish',
#   'could',
#   'stab',
#   'it',
#   'but',
#   'at',
#   'least',
#   'have',
#   'another',
#   'red',
#   'bull'],
#  ['bb', 'is', 'on', 'again', 'soon', 'argh'],
#  ['being', 'grounded', 'sucks'],
#  ['belllly', 'ache'],
#  ['bestee',
#   'went',
#   'to',
#   'get',
#   'pamperd',
#   'wit',
#   'out',
#   'me',
#   'sike',
#   'she',
#   'invited',
#   'me',
#   'but',
#   'me',
#   'not',
#   'in',
#   'the',
#   'mood',
#   'still',
#   'her',
#   'tho'],
#  ['beth',
#   'left',
#   'man',
#   'oh',
#   'man',
#   'wanted',
#   'to',
#   'go',
#   'tanning',
#   'today',
#   'but',
#   'dont',
#   'think',
#   'that',
#   'im',
#   'going',
#   'to',
#   'be',
#   'able',
#   'to',
#   'makes',
#   'me',
#   'sad',
#   'boo',
#   'hoo'],
#  ['big', 'giant', 'fail', 'on', 'my', 'part', 'this', 'morning'],
#  ['bit', 'disapponted', 'with', 'new', 'dm', 'album', 'hope', 'it', 'grower'],
#  ['blah', 'my', 'legs', 'still', 'hurt', 'stupid', 'steven', 'xd'],
#  ['blonde', 'moment', 'thihi'],
#  ['blonde',
#   'moment',
#   'apparently',
#   'booked',
#   'the',
#   'tickets',
#   'for',
#   'tomorrow',
#   'not',
#   'today',
#   'hm',
#   'oh',
#   'well',
#   'till',
#   'tomorrow'],
#  ['body',
#   'of',
#   'missing',
#   'northern',
#   'calif',
#   'girl',
#   'found',
#   'police',
#   'have',
#   'found',
#   'the',
#   'remains',
#   'of',
#   'missing',
#   'northern',
#   'california',
#   'girl'],
#  ['body',
#   'shop',
#   'morrow',
#   'side',
#   'veiw',
#   'mirror',
#   'is',
#   'still',
#   'mia',
#   'smh',
#   'at',
#   'price',
#   'tag'],
#  ['boo', 'always', 'miss', 'the', 'good', 'stuff'],
#  ['boooo', 'my', 'iphone', 'is', 'dying'],
#  ['bored',
#   'last',
#   'day',
#   'of',
#   'easter',
#   'has',
#   'been',
#   'ok',
#   'feels',
#   'bit',
#   'upset',
#   'but',
#   'dont',
#   'know',
#   'why',
#   'arggh',
#   'school',
#   'tomorrra',
#   'tht',
#   'has',
#   'made',
#   'me',
#   'feel',
#   'even',
#   'worse'],
#  ['bored', 'in', 'work', 'bleeehhh', 'just', 'had', 'chilli', 'for', 'lunch'],
#  ['bored',
#   'my',
#   'foot',
#   'is',
#   'killing',
#   'me',
#   'hopefully',
#   'can',
#   'still',
#   'go',
#   'to',
#   'sandhills',
#   'this',
#   'weekend',
#   'making',
#   'my',
#   'ramen',
#   'dles',
#   'so',
#   'can',
#   'take',
#   'my',
#   'medicine',
#   'brb'],
#  ['bored',
#   've',
#   'sat',
#   'inside',
#   'this',
#   'house',
#   'the',
#   'past',
#   'days',
#   'sucky'],
#  ['bout',
#   'to',
#   'leave',
#   'ny',
#   'bak',
#   'to',
#   'ct',
#   'damn',
#   'been',
#   'comin',
#   'out',
#   'here',
#   'err',
#   'day',
#   'this',
#   'week',
#   'lol',
#   'smh',
#   'jus',
#   'makin',
#   'quik',
#   'stops',
#   'handlin',
#   'bizzz'],
#  ['boys',
#   'are',
#   'stupid',
#   'clingy',
#   'puppies',
#   'who',
#   'need',
#   'to',
#   'be',
#   'kicked',
#   'sometimes'],
#  ['broken', 'again'],
#  ['broken', 'bones', 'suck'],
#  ['broken', 'hearts', 'will', 'heal', 'with', 'time'],
#  ['bron', 'it', 'okay', 'next', 'year'],
#  ['brug',
#   'says',
#   'swine',
#   'flu',
#   'reached',
#   'manila',
#   'now',
#   'the',
#   'do',
#   'not',
#   'have',
#   'reason',
#   'for',
#   'the',
#   'jb',
#   'to',
#   'come',
#   'here',
#   'as',
#   'refuge',
#   'from'],
#  ['bummer', 'what', 'happened', 'to', 'wednesday', 'nights'],
#  ['bus',
#   'only',
#   'just',
#   'arrived',
#   'was',
#   'sposed',
#   'to',
#   'be',
#   'here',
#   'mins',
#   'ago',
#   'cant',
#   'wait',
#   'till',
#   'can',
#   'drive',
#   'again',
#   'so',
#   'dnt',
#   'have',
#   'to',
#   'rely',
#   'on',
#   'busses'],
#  ['but', 'love', 'that', 'show'],
#  ['but',
#   'idk',
#   'he',
#   'like',
#   'does',
#   'not',
#   'even',
#   'want',
#   'to',
#   'be',
#   'my',
#   'friend',
#   'cause',
#   'trippin',
#   'idk',
#   'it',
#   'his',
#   'fault',
#   'and',
#   'can',
#   'not',
#   'handle',
#   'it',
#   'ughh',
#   'wanna',
#   'move'],
#  ['but', 'not', 'with', 'karen', 'anymore'],
#  ['but', 'pretty', 'good', 'acting', 'for', 'year', 'old', 'was', 'impressed'],
#  ['but', 'sticks', 'and', 'stones', 'still', 'break', 'my', 'bones'],
#  ['but', 'why', 'not'],
#  ['but', 'youre', 'taking', 'steps', 'to', 'change', 'it'],
#  ['bye',
#   'baby',
#   'up',
#   'next',
#   'one',
#   'way',
#   'ticket',
#   'to',
#   'hawaii',
#   'weird'],
#  ['byee', 'guysss'],
#  ['calculus', 'exam'],
#  ['dnt', 'knw', 'feel', 'lke', 'shuld', 'try'],
#  ['dnt', 'want', 'it', 'just', 'revenge'],
#  ['do', 'not', 'feel', 'good', 'want', 'some', 'partyrings', 'starbucks'],
#  ['dont', 'fell', 'happy', 'right', 'now'],
#  ['dont', 'know', 'wer', 'we', 'went', 'wrong'],
#  ['do', 'not', 'know', 'what', 'to', 'put'],
#  ['do',
#   'not',
#   'know',
#   'why',
#   'but',
#   'really',
#   'sad',
#   'and',
#   'worried',
#   'at',
#   'the',
#   'moment'],
#  ['do',
#   'not',
#   'know',
#   'why',
#   'sad',
#   'and',
#   'worried',
#   'at',
#   'the',
#   'moment',
#   'really',
#   'do',
#   'not',
#   'know'],
#  ['do', 'not', 'like', 'crying'],
#  ['do',
#   'not',
#   'think',
#   'my',
#   'dog',
#   'is',
#   'gonna',
#   'make',
#   'it',
#   'past',
#   'the',
#   'night'],
#  ['dont', 'think', 'yoru', 'there', 'bummma'],
#  ['do',
#   'not',
#   'wanna',
#   'be',
#   'at',
#   'work',
#   'right',
#   'now',
#   'sooo',
#   'tired',
#   'and',
#   'smidge',
#   'hungover'],
#  ['do', 'not', 'wanna', 'be', 'sick'],
#  ['dont', 'wanna', 'do', 'this', 'im', 'gunna', 'cry'],
#  ['do',
#   'not',
#   'wanna',
#   'go',
#   'to',
#   'work',
#   'tired',
#   'and',
#   'miss',
#   'my',
#   'papi'],
#  ['do', 'not', 'want', 'school', 'anymoreee'],
#  ['dunno', 'what', 'to', 'do', 'now'],
#  ['failed', 'my', 'math', 'final', 'part', 'hate', 'calculus', 'now'],
#  ['feel', 'bad', 'mewithoutyou'],
#  ['feel',
#   'just',
#   'like',
#   'my',
#   'car',
#   'inside',
#   'banged',
#   'up',
#   'and',
#   'sad',
#   'maybe',
#   'its',
#   'meant',
#   'for',
#   'me',
#   'to',
#   'get',
#   'new',
#   'can',
#   'borrow',
#   'some',
#   'cash',
#   'anyone',
#   'anyone'],
#  ['feel',
#   'like',
#   'horrible',
#   'human',
#   'being',
#   'did',
#   'not',
#   'take',
#   'the',
#   'dog',
#   'out',
#   'when',
#   'was',
#   'supposed',
#   'too'],
#  ['feel', 'like', 'crap'],
#  ['feel',
#   'like',
#   'crawling',
#   'into',
#   'my',
#   'bed',
#   'under',
#   'my',
#   'covers',
#   'listening',
#   'to',
#   'my',
#   'ipod',
#   'and',
#   'having',
#   'cry',
#   'session'],
#  ['feel',
#   'like',
#   'my',
#   'ipod',
#   'is',
#   'gonna',
#   'die',
#   'on',
#   'me',
#   'today',
#   'the',
#   'apple',
#   'of',
#   'my',
#   'eye',
#   'double',
#   'pun'],
#  ['feel', 'really', 'alone'],
#  ['fell',
#   'down',
#   'the',
#   'stairs',
#   'again',
#   'officially',
#   'hate',
#   'curvy',
#   'staircases',
#   'they',
#   're',
#   'nothing',
#   'but',
#   'bad',
#   'news'],
#  ['felt',
#   'so',
#   'sick',
#   'today',
#   'had',
#   'sore',
#   'throat',
#   'and',
#   'had',
#   'to',
#   'go',
#   'to',
#   'doctors',
#   'appointment',
#   'just',
#   'wanna',
#   'rest'],
#  ['forgot',
#   'to',
#   'bring',
#   'my',
#   'new',
#   'allegra',
#   'hour',
#   'to',
#   'work',
#   'today',
#   'so',
#   'singulair',
#   'and',
#   'are',
#   'flying',
#   'solo',
#   'today'],
#  ['forgot',
#   'to',
#   'tell',
#   'you',
#   'guys',
#   'that',
#   'didnt',
#   'make',
#   'the',
#   'cheer',
#   'team',
#   'gggrr'],
#  ['got', 'banned', 'forever', 'from', 'cp', 'mimo', 'dosnt', 'that', 'suck'],
#  ['got', 'ill', 'and', 'tomorrow', 've', 'got', 'birthday'],
#  ['got',
#   'sunburnt',
#   'day',
#   'in',
#   'blackpool',
#   'lol',
#   'my',
#   'little',
#   'boy',
#   'had',
#   'fun',
#   'tho',
#   'chucking',
#   'water',
#   'on',
#   'me',
#   'lol'],
#  ['guess', 'dont', 'have', 'boyfriend'],
#  ['guess',
#   'would',
#   'not',
#   'be',
#   'true',
#   'cleveland',
#   'sports',
#   'fan',
#   'without',
#   'years',
#   'of',
#   'collapse',
#   'and',
#   'disappointment'],
#  ['guess',
#   'll',
#   'be',
#   'home',
#   'while',
#   'everyone',
#   'is',
#   'at',
#   'bday',
#   'bash',
#   'having',
#   'the',
#   'time',
#   'of',
#   'their',
#   'lives',
#   'with',
#   'drake'],
#  ['guess', 'it', 'got', 'you', 'more', 'time', 'to', 'work', 'rofl'],
#  ['hat', 'seeing', 'friends', 'breakup', 'im', 'sorry', 'frankus'],
#  ['hate', 'goodbyes'],
#  ['hate',
#   'having',
#   'to',
#   'change',
#   'driving',
#   'instructor',
#   'new',
#   'one',
#   'has',
#   'dented',
#   'my',
#   'confidence',
#   'slightly'],
#  ['hate', 'having', 'to', 'work', 'weekend', 'duty'],
#  ['hate', 'him'],
#  ['hate', 'it', 'he', 'mad', 'at', 'me', 'again'],
#  ['hate', 'lightening'],
#  ['hate', 'not', 'having', 'anyone', 'to', 'talk', 'to'],
#  ['hate', 'pain'],
#  ['hate',
#   'summerschool',
#   'have',
#   'fun',
#   'at',
#   'work',
#   'even',
#   'though',
#   'you',
#   're',
#   'getting',
#   'off',
#   'at',
#   'doooit',
#   'll',
#   'visitt',
#   'you',
#   'my',
#   'fobby',
#   'friend'],
#  ['hate', 'the', 'cold', 'weather'],
#  ['bbc', 'champion', 'nadal', 'out', 'of', 'wimbledon'],
#  ['because',
#   'boston',
#   'and',
#   'fine',
#   'ass',
#   'eddie',
#   'house',
#   'whocangetit',
#   'by',
#   'the',
#   'way',
#   'lost',
#   'last',
#   'nite',
#   'boo',
#   'orlando',
#   'la',
#   'cle',
#   'in',
#   'the',
#   'finals',
#   'baby'],
#  ['because',
#   'safe',
#   'person',
#   'my',
#   'ego',
#   'was',
#   'little',
#   'damaged',
#   'after',
#   'lil',
#   'reboot',
#   'll',
#   'be',
#   'back',
#   'to',
#   'my',
#   'usual',
#   'harlem',
#   'swagg'],
#  ['becca',
#   'told',
#   'me',
#   'would',
#   'start',
#   'to',
#   'feel',
#   'better',
#   'after',
#   'food',
#   'still',
#   'stressing',
#   'about',
#   'this',
#   'exam',
#   'more',
#   'revision',
#   'in',
#   'bit'],
#  ['becomming',
#   'fan',
#   'of',
#   'bubble',
#   'shirts',
#   'haha',
#   'they',
#   'dont',
#   'make',
#   'me',
#   'look',
#   'as',
#   'chubby'],
#  ['been', 'crappy', 'day'],
#  ['being', 'girl', 'stinks', 'grrrrrrrrrr'],
#  ['being',
#   'forced',
#   'into',
#   'bed',
#   'guess',
#   'll',
#   'have',
#   'to',
#   'wait',
#   'until',
#   'moring',
#   'here',
#   'for',
#   'niley',
#   'news',
#   'in',
#   'uk',
#   'so'],
#  ['big',
#   'day',
#   'of',
#   'putting',
#   'in',
#   'dock',
#   'tomorrow',
#   'degress',
#   'outside',
#   'but',
#   'the',
#   'water',
#   'will',
#   'be',
#   'much',
#   'colder',
#   'than',
#   'that'],
#  ['bio',
#   'physics',
#   'math',
#   'health',
#   'filipino',
#   'english',
#   'elections',
#   'help',
#   'me',
#   'drowning',
#   'in',
#   'school',
#   'work'],
#  ['blah', 'blah', 'blah', 'perfect', 'for', 'you', 'and', 'you', 'know', 'it'],
#  ['blesh',
#   'no',
#   'feedback',
#   'and',
#   'no',
#   'one',
#   'in',
#   'my',
#   'house',
#   'will',
#   'tell',
#   'me',
#   'sheesh'],
#  ['bluetooth',
#   'still',
#   'does',
#   'not',
#   'work',
#   'on',
#   'iphone',
#   'pile',
#   'of',
#   'knob',
#   'sackage'],
#  ['boo', 'but', 'will', 'listen'],
#  ['boo',
#   'for',
#   'the',
#   'first',
#   'day',
#   'of',
#   'classes',
#   'summer',
#   'classes',
#   'ughhhh',
#   'has',
#   'anyone',
#   'ever',
#   'had',
#   'boob',
#   'cramps',
#   'lol'],
#  ['boo',
#   'hoo',
#   'trying',
#   'to',
#   'open',
#   'my',
#   'email',
#   'it',
#   'not',
#   'working',
#   'grrrr'],
#  ['boo',
#   'you',
#   'suck',
#   'but',
#   'thanks',
#   'for',
#   'one',
#   'thing',
#   'today',
#   'and',
#   'can',
#   'not',
#   'wait',
#   'for',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'week'],
#  ['bored', 'and', 'no', 'one', 'is', 'talking', 'anymore'],
#  ['bored', 'sad', 'no', 'one', 'tweeting'],
#  ['bored', 'wish', 'had', 'somewhere', 'go', 'ha'],
#  ['boredd', 'want', 'to', 'go', 'hommmmme'],
#  ...]

# %%
pos_reviews_set = []
for words in pos_reviews:
#     print(words)
    pos_reviews_set.append((bag_of_all_words(words), 'pos'))
pos_reviews_set
# Out:
# [({'omg': True, 'already': True, ('omg', 'already'): True}, 'pos'),
#  ({'handed': True,
#    'uniform': True,
#    'today': True,
#    'miss': True,
#    'already': True,
#    ('handed', 'uniform'): True,
#    ('uniform', 'today'): True,
#    ('today', 'miss'): True,
#    ('miss', 'already'): True},
#   'pos'),
#  ({'hmmmm': True,
#    'wonder': True,
#    'number': True,
#    ('hmmmm', 'wonder'): True,
#    ('wonder', 'number'): True},
#   'pos'),
#  ({'thanks': True,
#    'haters': True,
#    'face': True,
#    'day': True,
#    ('thanks', 'haters'): True,
#    ('haters', 'face'): True,
#    ('face', 'day'): True},
#   'pos'),
#  ({'feeling': True,
#    'strangely': True,
#    'fine': True,
#    'gonna': True,
#    'go': True,
#    'listen': True,
#    'semisonic': True,
#    'celebrate': True,
#    ('feeling', 'strangely'): True,
#    ('strangely', 'fine'): True,
#    ('fine', 'gonna'): True,
#    ('gonna', 'go'): True,
#    ('go', 'listen'): True,
#    ('listen', 'semisonic'): True,
#    ('semisonic', 'celebrate'): True},
#   'pos'),
#  ({'one': True,
#    'see': True,
#    'cause': True,
#    'else': True,
#    'following': True,
#    'pretty': True,
#    'awesome': True,
#    ('only', 'one'): True,
#    ('one', 'see'): True,
#    ('see', 'cause'): True,
#    ('cause', 'no'): True,
#    ('no', 'one'): True,
#    ('one', 'else'): True,
#    ('else', 'following'): True,
#    ('following', 'pretty'): True,
#    ('pretty', 'awesome'): True},
#   'pos'),
#  ({'goodbye': True,
#    'exams': True,
#    'hello': True,
#    'alcohol': True,
#    'tonight': True,
#    ('goodbye', 'exams'): True,
#    ('exams', 'hello'): True,
#    ('hello', 'alcohol'): True,
#    ('alcohol', 'tonight'): True},
#   'pos'),
#  ({'uploading': True,
#    'pictures': True,
#    'friendster': True,
#    ('uploading', 'pictures'): True,
#    ('pictures', 'friendster'): True},
#   'pos'),
#  ({'wrote': True,
#    'something': True,
#    'last': True,
#    'week': True,
#    'got': True,
#    'call': True,
#    'someone': True,
#    'new': True,
#    'york': True,
#    'office': True,
#    ('so', 'wrote'): True,
#    ('wrote', 'something'): True,
#    ('something', 'last'): True,
#    ('last', 'week'): True,
#    ('week', 'got'): True,
#    ('got', 'call'): True,
#    ('call', 'someone'): True,
#    ('someone', 'new'): True,
#    ('new', 'york'): True,
#    ('york', 'office'): True},
#   'pos'),
#  ({'need': True,
#    'even': True,
#    'say': True,
#    'well': True,
#    'go': True,
#    'anyways': True,
#    'chris': True,
#    'cornell': True,
#    'chicago': True,
#    'tonight': True,
#    ('need', 'even'): True,
#    ('even', 'say'): True,
#    ('say', 'well'): True,
#    ('well', 'go'): True,
#    ('go', 'anyways'): True,
#    ('anyways', 'chris'): True,
#    ('chris', 'cornell'): True,
#    ('cornell', 'chicago'): True,
#    ('chicago', 'tonight'): True},
#   'pos'),
#  ({'health': True,
#    'class': True,
#    'joke': True,
#    ('health', 'class'): True,
#    ('class', 'joke'): True},
#   'pos'),
#  ({'go': True,
#    'show': True,
#    'tonight': True,
#    ('go', 'show'): True,
#    ('show', 'tonight'): True},
#   'pos'),
#  ({'bathroom': True,
#    'clean': True,
#    'enjoyable': True,
#    'tasks': True,
#    ('bathroom', 'clean'): True,
#    ('clean', 'more'): True,
#    ('more', 'enjoyable'): True,
#    ('enjoyable', 'tasks'): True},
#   'pos'),
#  ({'boom': True, 'pow': True, ('boom', 'boom'): True, ('boom', 'pow'): True},
#   'pos'),
#  ({'go': True,
#    'give': True,
#    'ur': True,
#    'mom': True,
#    'hug': True,
#    'right': True,
#    ('go', 'give'): True,
#    ('give', 'ur'): True,
#    ('ur', 'mom'): True,
#    ('mom', 'hug'): True,
#    ('hug', 'right'): True},
#   'pos'),
#  ({'going': True,
#    'see': True,
#    'harry': True,
#    'sunday': True,
#    'happiness': True,
#    ('going', 'see'): True,
#    ('see', 'harry'): True,
#    ('harry', 'sunday'): True,
#    ('sunday', 'happiness'): True},
#   'pos'),
#  ({'always': True,
#    'get': True,
#    'want': True,
#    ('always', 'get'): True,
#    ('get', 'want'): True},
#   'pos'),
#  ({'bend': True, 'backwards': True, ('bend', 'backwards'): True}, 'pos'),
#  ({'get': True,
#    'work': True,
#    'sooooon': True,
#    'miss': True,
#    'cody': True,
#    'booo': True,
#    'seen': True,
#    'foreverr': True,
#    ('get', 'off'): True,
#    ('off', 'work'): True,
#    ('work', 'sooooon'): True,
#    ('sooooon', 'miss'): True,
#    ('miss', 'cody'): True,
#    ('cody', 'booo'): True,
#    ('booo', 'not'): True,
#    ('not', 'seen'): True,
#    ('seen', 'foreverr'): True},
#   'pos'),
#  ({'hate': True,
#    'allergies': True,
#    'get': True,
#    'hair': True,
#    'cut': True,
#    'tomorrow': True,
#    'taking': True,
#    'public': True,
#    'poll': True,
#    ('hate', 'allergies'): True,
#    ('allergies', 'get'): True,
#    ('get', 'hair'): True,
#    ('hair', 'cut'): True,
#    ('cut', 'tomorrow'): True,
#    ('tomorrow', 'taking'): True,
#    ('taking', 'public'): True,
#    ('public', 'poll'): True},
#   'pos'),
#  ({'really': True,
#    'going': True,
#    'bed': True,
#    ('really', 'going'): True,
#    ('going', 'bed'): True},
#   'pos'),
#  ({'jin': True, 'twitter': True, ('jin', 'twitter'): True}, 'pos'),
#  ({'gonna': True,
#    'smile': True,
#    'cuz': True,
#    'im': True,
#    'sure': True,
#    'could': True,
#    'want': True,
#    ('just', 'gonna'): True,
#    ('gonna', 'smile'): True,
#    ('smile', 'cuz'): True,
#    ('cuz', 'im'): True,
#    ('im', 'not'): True,
#    ('not', 'sure'): True,
#    ('sure', 'more'): True,
#    ('more', 'could'): True,
#    ('could', 'want'): True},
#   'pos'),
#  ({'got': True,
#    'home': True,
#    'see': True,
#    'friend': True,
#    'zahra': True,
#    'seen': True,
#    'since': True,
#    'graduated': True,
#    'makes': True,
#    'happy': True,
#    ('just', 'got'): True,
#    ('got', 'home'): True,
#    ('home', 'got'): True,
#    ('got', 'see'): True,
#    ('see', 'friend'): True,
#    ('friend', 'zahra'): True,
#    ('zahra', 'not'): True,
#    ('not', 'seen'): True,
#    ('seen', 'since'): True,
#    ('since', 'graduated'): True,
#    ('graduated', 'makes'): True,
#    ('makes', 'so'): True,
#    ('so', 'happy'): True},
#   'pos'),
#  ({'oh': True, 'thank': True, ('oh', 'thank'): True}, 'pos'),
#  ({'pleased': True}, 'pos'),
#  ({'rose': True,
#    'ood': True,
#    'back': True,
#    'xmas': True,
#    'special': True,
#    'yay': True,
#    'damn': True,
#    'half': True,
#    'year': True,
#    'away': True,
#    ('rose', 'ood'): True,
#    ('ood', 'back'): True,
#    ('back', 'xmas'): True,
#    ('xmas', 'special'): True,
#    ('special', 'yay'): True,
#    ('yay', 'damn'): True,
#    ('damn', 'half'): True,
#    ('half', 'year'): True,
#    ('year', 'away'): True},
#   'pos'),
#  ({'thanks': True,
#    'need': True,
#    'help': True,
#    'get': True,
#    ('thanks', 'need'): True,
#    ('need', 'help'): True,
#    ('help', 'get'): True},
#   'pos'),
#  ({'explains': True, 'alot': True, ('explains', 'alot'): True}, 'pos'),
#  ({'going': True,
#    'heathers': True,
#    'sequel': True,
#    'winona': True,
#    'ever': True,
#    'better': True,
#    'fuck': True,
#    ('going', 'heathers'): True,
#    ('heathers', 'sequel'): True,
#    ('sequel', 'winona'): True,
#    ('winona', 'ever'): True,
#    ('ever', 'better'): True,
#    ('better', 'not'): True,
#    ('not', 'fuck'): True},
#   'pos'),
#  ({'trae': True,
#    'sweet': True,
#    'bought': True,
#    'new': True,
#    'baithing': True,
#    'suit': True,
#    'wove': True,
#    ('trae', 'so'): True,
#    ('so', 'sweet'): True,
#    ('sweet', 'just'): True,
#    ('just', 'bought'): True,
#    ('bought', 'new'): True,
#    ('new', 'baithing'): True,
#    ('baithing', 'suit'): True,
#    ('suit', 'wove'): True},
#   'pos'),
#  ({'true': True,
#    'highly': True,
#    'subjective': True,
#    'tombre': True,
#    'actually': True,
#    'favorite': True,
#    'character': True,
#    'book': True,
#    'got': True,
#    'rishabh': True,
#    ('true', 'highly'): True,
#    ('highly', 'subjective'): True,
#    ('subjective', 'tombre'): True,
#    ('tombre', 'actually'): True,
#    ('actually', 'favorite'): True,
#    ('favorite', 'character'): True,
#    ('character', 'book'): True,
#    ('book', 'got'): True,
#    ('got', 'rishabh'): True},
#   'pos'),
#  ({'wide': True,
#    'awake': True,
#    ('wide', 'awake'): True,
#    ('awake', 'not'): True},
#   'pos'),
#  ({'yeah': True,
#    'awful': True,
#    'weather': True,
#    'last': True,
#    'week': True,
#    'stinks': True,
#    'kristis': True,
#    'comin': True,
#    'moe': True,
#    'said': True,
#    'mmmaybe': True,
#    'take': True,
#    'us': True,
#    ('yeah', 'too'): True,
#    ('too', 'awful'): True,
#    ('awful', 'weather'): True,
#    ('weather', 'last'): True,
#    ('last', 'week'): True,
#    ('week', 'so'): True,
#    ('so', 'stinks'): True,
#    ('stinks', 'kristis'): True,
#    ('kristis', 'comin'): True,
#    ('comin', 'moe'): True,
#    ('moe', 'said'): True,
#    ('said', 'mmmaybe'): True,
#    ('mmmaybe', 'take'): True,
#    ('take', 'us'): True},
#   'pos'),
#  ({'poemsunder': True, 'started': True, ('poemsunder', 'started'): True},
#   'pos'),
#  ({'believe': True, 'enough': True, ('believe', 'enough'): True}, 'pos'),
#  ({'goooood': True, 'timessss': True, ('goooood', 'timessss'): True}, 'pos'),
#  ({'know': True,
#    'hungry': True,
#    'lets': True,
#    'go': True,
#    'outside': True,
#    'balcony': True,
#    'eat': True,
#    ('know', 'hungry'): True,
#    ('hungry', 'so'): True,
#    ('so', 'lets'): True,
#    ('lets', 'go'): True,
#    ('go', 'outside'): True,
#    ('outside', 'balcony'): True,
#    ('balcony', 'so'): True,
#    ('so', 'eat'): True},
#   'pos'),
#  ({'men': True,
#    'uk': True,
#    'female': True,
#    'internet': True,
#    'entrepreneur': True,
#    'know': True,
#    'starting': True,
#    'growing': True,
#    'business': True,
#    'next': True,
#    'women': True,
#    ('men', 'uk'): True,
#    ('uk', 'female'): True,
#    ('female', 'internet'): True,
#    ('internet', 'entrepreneur'): True,
#    ('entrepreneur', 'know'): True,
#    ('know', 'starting'): True,
#    ('starting', 'growing'): True,
#    ('growing', 'business'): True,
#    ('business', 'next'): True,
#    ('next', 'women'): True},
#   'pos'),
#  ({'truth': True,
#    'hiding': True,
#    'eyes': True,
#    'paramore': True,
#    'decode': True,
#    ('truth', 'hiding'): True,
#    ('hiding', 'eyes'): True,
#    ('eyes', 'paramore'): True,
#    ('paramore', 'decode'): True},
#   'pos'),
#  ({'hummin': True,
#    'say': True,
#    'shut': True,
#    'put': True,
#    'money': True,
#    'mouth': True,
#    'headin': True,
#    'reality': True,
#    'cheers': True,
#    'twitter': True,
#    'world': True,
#    ('hummin', 'say'): True,
#    ('say', 'shut'): True,
#    ('shut', 'put'): True,
#    ('put', 'money'): True,
#    ('money', 'mouth'): True,
#    ('mouth', 'headin'): True,
#    ('headin', 'reality'): True,
#    ('reality', 'cheers'): True,
#    ('cheers', 'twitter'): True,
#    ('twitter', 'world'): True},
#   'pos'),
#  ({'sigh': True,
#    'cant': True,
#    'love': True,
#    'someone': True,
#    'back': True,
#    'like': True,
#    'stalker': True,
#    'status': True,
#    'get': True,
#    'divorce': True,
#    'move': True,
#    'trinity': True,
#    ('sigh', 'cant'): True,
#    ('cant', 'love'): True,
#    ('love', 'someone'): True,
#    ('someone', 'not'): True,
#    ('not', 'love'): True,
#    ('love', 'back'): True,
#    ('back', 'like'): True,
#    ('like', 'stalker'): True,
#    ('stalker', 'status'): True,
#    ('status', 'get'): True,
#    ('get', 'divorce'): True,
#    ('divorce', 'move'): True,
#    ('move', 'trinity'): True},
#   'pos'),
#  ({'aiqht': True,
#    'goodniqht': True,
#    'tri': True,
#    'neena': True,
#    'malcolm': True,
#    'chaise': True,
#    'jlew': True,
#    'atl': True,
#    'love': True,
#    'much': True,
#    ('aiqht', 'goodniqht'): True,
#    ('goodniqht', 'tri'): True,
#    ('tri', 'neena'): True,
#    ('neena', 'malcolm'): True,
#    ('malcolm', 'chaise'): True,
#    ('chaise', 'jlew'): True,
#    ('jlew', 'atl'): True,
#    ('atl', 'love'): True,
#    ('love', 'much'): True},
#   'pos'),
#  ({'triiiiiii': True,
#    'ily': True,
#    'even': True,
#    'chaise': True,
#    'dies': True,
#    'laughter': True,
#    ('triiiiiii', 'ily'): True,
#    ('ily', 'even'): True,
#    ('even', 'chaise'): True,
#    ('chaise', 'not'): True,
#    ('not', 'dies'): True,
#    ('dies', 'laughter'): True},
#   'pos'),
#  ({'hot': True,
#    'choco': True,
#    'best': True,
#    ('hot', 'choco'): True,
#    ('choco', 'best'): True},
#   'pos'),
#  ({'beach': True,
#    'day': True,
#    'scoobs': True,
#    'still': True,
#    'phone': True,
#    ('beach', 'day'): True,
#    ('day', 'scoobs'): True,
#    ('scoobs', 'still'): True,
#    ('still', 'no'): True,
#    ('no', 'phone'): True},
#   'pos'),
#  ({'amazing': True,
#    'night': True,
#    'day': True,
#    'hi': True,
#    'twits': True,
#    'miss': True,
#    'guys': True,
#    ('amazing', 'night'): True,
#    ('night', 'day'): True,
#    ('day', 'night'): True,
#    ('night', 'hi'): True,
#    ('hi', 'twits'): True,
#    ('twits', 'miss'): True,
#    ('miss', 'guys'): True},
#   'pos'),
#  ({'canaveral': True,
#    'national': True,
#    'seashore': True,
#    ('canaveral', 'national'): True,
#    ('national', 'seashore'): True},
#   'pos'),
#  ({'progressing': True,
#    'production': True,
#    'department': True,
#    'uprizing': True,
#    'thats': True,
#    'priority': True,
#    'getting': True,
#    'head': True,
#    'nodding': True,
#    'beats': True,
#    'reach': True,
#    ('progressing', 'production'): True,
#    ('production', 'department'): True,
#    ('department', 'uprizing'): True,
#    ('uprizing', 'thats'): True,
#    ('thats', 'priority'): True,
#    ('priority', 'getting'): True,
#    ('getting', 'head'): True,
#    ('head', 'nodding'): True,
#    ('nodding', 'beats'): True,
#    ('beats', 'reach'): True},
#   'pos'),
#  ({'taylorrhicks': True,
#    'enjoy': True,
#    'chicago': True,
#    'new': True,
#    'venue': True,
#    'always': True,
#    'cool': True,
#    'shine': True,
#    'everywhere': True,
#    'go': True,
#    'know': True,
#    'time': True,
#    'everyone': True,
#    ('taylorrhicks', 'enjoy'): True,
#    ('enjoy', 'chicago'): True,
#    ('chicago', 'new'): True,
#    ('new', 'venue'): True,
#    ('venue', 'always'): True,
#    ('always', 'cool'): True,
#    ('cool', 'shine'): True,
#    ('shine', 'everywhere'): True,
#    ('everywhere', 'go'): True,
#    ('go', 'know'): True,
#    ('know', 'time'): True,
#    ('time', 'so'): True,
#    ('so', 'everyone'): True},
#   'pos'),
#  ({'thestreetforce': True}, 'pos'),
#  ({'makes': True, 'smile': True, ('makes', 'smile'): True}, 'pos'),
#  ({'first': True,
#    'day': True,
#    'weeks': True,
#    'child': True,
#    'got': True,
#    'watch': True,
#    'nancy': True,
#    'grac': True,
#    ('first', 'day'): True,
#    ('day', 'off'): True,
#    ('off', 'weeks'): True,
#    ('weeks', 'child'): True,
#    ('child', 'got'): True,
#    ('got', 'so'): True,
#    ('so', 'watch'): True,
#    ('watch', 'nancy'): True,
#    ('nancy', 'grac'): True},
#   'pos'),
#  ({'video': True,
#    'woody': True,
#    'woodpecker': True,
#    'barber': True,
#    'seville': True,
#    'great': True,
#    'wishing': True,
#    'ch': True,
#    ('video', 'woody'): True,
#    ('woody', 'woodpecker'): True,
#    ('woodpecker', 'barber'): True,
#    ('barber', 'seville'): True,
#    ('seville', 'great'): True,
#    ('great', 'just'): True,
#    ('just', 'wishing'): True,
#    ('wishing', 'ch'): True},
#   'pos'),
#  ({'happy': True,
#    'staying': True,
#    'around': True,
#    'drexel': True,
#    'fabulous': True,
#    'university': True,
#    'proud': True,
#    'yeah': True,
#    ('happy', 'staying'): True,
#    ('staying', 'around'): True,
#    ('around', 'drexel'): True,
#    ('drexel', 'fabulous'): True,
#    ('fabulous', 'university'): True,
#    ('university', 'proud'): True,
#    ('proud', 'yeah'): True},
#   'pos'),
#  ({'call': True,
#    'dibs': True,
#    'voltron': True,
#    'arm': True,
#    'leg': True,
#    'wait': True,
#    'manners': True,
#    ('call', 'dibs'): True,
#    ('dibs', 'voltron'): True,
#    ('voltron', 'arm'): True,
#    ('arm', 'no'): True,
#    ('no', 'leg'): True,
#    ('leg', 'wait'): True,
#    ('wait', 'manners'): True},
#   'pos'),
#  ({'saw': True,
#    'ur': True,
#    'mum': True,
#    ('just', 'saw'): True,
#    ('saw', 'ur'): True,
#    ('ur', 'mum'): True},
#   'pos'),
#  ({'get': True,
#    'fat': True,
#    'asses': True,
#    'nai': True,
#    ('get', 'fat'): True,
#    ('fat', 'asses'): True,
#    ('asses', 'nai'): True},
#   'pos'),
#  ({'see': True,
#    'three': True,
#    'external': True,
#    'monitors': True,
#    'one': True,
#    'laptop': True,
#    'win': True,
#    'rc': True,
#    ('see', 'three'): True,
#    ('three', 'external'): True,
#    ('external', 'monitors'): True,
#    ('monitors', 'one'): True,
#    ('one', 'laptop'): True,
#    ('laptop', 'win'): True,
#    ('win', 'rc'): True},
#   'pos'),
#  ({'facebook': True,
#    'com': True,
#    'copic': True,
#    'marker': True,
#    'cool': True,
#    'maybe': True,
#    'send': True,
#    ('facebook', 'com'): True,
#    ('com', 'copic'): True,
#    ('copic', 'marker'): True,
#    ('marker', 'cool'): True,
#    ('cool', 'not'): True,
#    ('not', 'cool'): True,
#    ('cool', 'maybe'): True,
#    ('maybe', 'send'): True,
#    ('send', 'cool'): True},
#   'pos'),
#  ({'want': True,
#    'start': True,
#    'morning': True,
#    'later': True,
#    'new': True,
#    'york': True,
#    'californians': True,
#    'even': True,
#    'better': True,
#    ('want', 'start'): True,
#    ('start', 'morning'): True,
#    ('morning', 'later'): True,
#    ('later', 'new'): True,
#    ('new', 'york'): True,
#    ('york', 'californians'): True,
#    ('californians', 'even'): True,
#    ('even', 'better'): True},
#   'pos'),
#  ({'lol': True,
#    'luv': True,
#    'find': True,
#    ('lol', 'luv'): True,
#    ('luv', 'find'): True},
#   'pos'),
#  ({'making': True,
#    'fettucini': True,
#    'garlic': True,
#    'bread': True,
#    ('making', 'fettucini'): True,
#    ('fettucini', 'garlic'): True,
#    ('garlic', 'bread'): True},
#   'pos'),
#  ({'tell': True,
#    'said': True,
#    'happy': True,
#    'bday': True,
#    ('tell', 'said'): True,
#    ('said', 'happy'): True,
#    ('happy', 'bday'): True},
#   'pos'),
#  ({'told': True,
#    'would': True,
#    'sweep': True,
#    'haha': True,
#    ('told', 'would'): True,
#    ('would', 'sweep'): True,
#    ('sweep', 'haha'): True},
#   'pos'),
#  ({'servers': True,
#    'backup': True,
#    'experience': True,
#    'problems': True,
#    'please': True,
#    'let': True,
#    'know': True,
#    'sorry': True,
#    'delay': True,
#    ('servers', 'backup'): True,
#    ('backup', 'experience'): True,
#    ('experience', 'more'): True,
#    ('more', 'problems'): True,
#    ('problems', 'please'): True,
#    ('please', 'let'): True,
#    ('let', 'know'): True,
#    ('know', 'sorry'): True,
#    ('sorry', 'delay'): True},
#   'pos'),
#  ({'yes': True,
#    'lol': True,
#    'luv': True,
#    'like': True,
#    'gentle': True,
#    'breeze': True,
#    'blown': True,
#    'throug': True,
#    ('yes', 'lol'): True,
#    ('lol', 'luv'): True,
#    ('luv', 'like'): True,
#    ('like', 'gentle'): True,
#    ('gentle', 'breeze'): True,
#    ('breeze', 'blown'): True,
#    ('blown', 'throug'): True},
#   'pos'),
#  ({'future': True,
#    'rooooooooomies': True,
#    'nyc': True,
#    'holler': True,
#    ('future', 'rooooooooomies'): True,
#    ('rooooooooomies', 'nyc'): True,
#    ('nyc', 'holler'): True},
#   'pos'),
#  ({'hope': True,
#    'cheese': True,
#    'burgers': True,
#    'lmbo': True,
#    ('hope', 'cheese'): True,
#    ('cheese', 'burgers'): True,
#    ('burgers', 'lmbo'): True},
#   'pos'),
#  ({'awesome': True}, 'pos'),
#  ({'nothing': True,
#    'kind': True,
#    'everything': True,
#    'sort': True,
#    ('nothing', 'kind'): True,
#    ('kind', 'everything'): True,
#    ('everything', 'sort'): True},
#   'pos'),
#  ({'pick': True,
#    'flowers': True,
#    'teacher': True,
#    'jealous': True,
#    'want': True,
#    'without': True,
#    'hospital': True,
#    'get': True,
#    ('pick', 'flowers'): True,
#    ('flowers', 'teacher'): True,
#    ('teacher', 'jealous'): True,
#    ('jealous', 'want'): True,
#    ('want', 'flowers'): True,
#    ('flowers', 'without'): True,
#    ('without', 'hospital'): True,
#    ('hospital', 'get'): True},
#   'pos'),
#  ({'think': True,
#    'talvez': True,
#    'seja': True,
#    'nfase': True,
#    'na': True,
#    'cifra': True,
#    'mas': True,
#    'aten': True,
#    'security': True,
#    'chain': True,
#    'strong': True,
#    'weakest': True,
#    'link': True,
#    ('think', 'talvez'): True,
#    ('talvez', 'seja'): True,
#    ('seja', 'nfase'): True,
#    ('nfase', 'na'): True,
#    ('na', 'cifra'): True,
#    ('cifra', 'mas'): True,
#    ('mas', 'aten'): True,
#    ('aten', 'security'): True,
#    ('security', 'chain'): True,
#    ('chain', 'strong'): True,
#    ('strong', 'weakest'): True,
#    ('weakest', 'link'): True},
#   'pos'),
#  ({'watch': True}, 'pos'),
#  ({'thanks': True,
#    'hoping': True,
#    'pretty': True,
#    'nervous': True,
#    'though': True,
#    ('thanks', 'hoping'): True,
#    ('hoping', 'pretty'): True,
#    ('pretty', 'nervous'): True,
#    ('nervous', 'though'): True},
#   'pos'),
#  ({'followers': True}, 'pos'),
#  ({'tell': True,
#    'ya': True,
#    'grocery': True,
#    'store': True,
#    'better': True,
#    'blasted': True,
#    'oldies': True,
#    'sugar': True,
#    'ray': True,
#    'make': True,
#    ('tell', 'ya'): True,
#    ('ya', 'grocery'): True,
#    ('grocery', 'store'): True,
#    ('store', 'better'): True,
#    ('better', 'blasted'): True,
#    ('blasted', 'oldies'): True,
#    ('oldies', 'sugar'): True,
#    ('sugar', 'ray'): True,
#    ('ray', 'not'): True,
#    ('not', 'make'): True},
#   'pos'),
#  ({'yall': True,
#    'bitches': True,
#    'better': True,
#    'wake': True,
#    'early': True,
#    'go': True,
#    'la': True,
#    'opera': True,
#    'kay': True,
#    ('yall', 'bitches'): True,
#    ('bitches', 'better'): True,
#    ('better', 'wake'): True,
#    ('wake', 'early'): True,
#    ('early', 'go'): True,
#    ('go', 'la'): True,
#    ('la', 'opera'): True,
#    ('opera', 'kay'): True},
#   'pos'),
#  ({'congrats': True,
#    'bhai': True,
#    'like': True,
#    'oldies': True,
#    'used': True,
#    'say': True,
#    'arre': True,
#    'kuch': True,
#    'kam': True,
#    'ka': True,
#    ('congrats', 'bhai'): True,
#    ('bhai', 'but'): True,
#    ('but', 'like'): True,
#    ('like', 'oldies'): True,
#    ('oldies', 'used'): True,
#    ('used', 'say'): True,
#    ('say', 'arre'): True,
#    ('arre', 'bhai'): True,
#    ('bhai', 'kuch'): True,
#    ('kuch', 'kam'): True,
#    ('kam', 'ka'): True},
#   'pos'),
#  ({'chilling': True,
#    'twitter': True,
#    'via': True,
#    'spanking': True,
#    'new': True,
#    'blackberry': True,
#    'unlimited': True,
#    'internet': True,
#    ('chilling', 'twitter'): True,
#    ('twitter', 'via'): True,
#    ('via', 'spanking'): True,
#    ('spanking', 'new'): True,
#    ('new', 'blackberry'): True,
#    ('blackberry', 'unlimited'): True,
#    ('unlimited', 'internet'): True},
#   'pos'),
#  ({'give': True,
#    'every': True,
#    'inch': True,
#    'love': True,
#    'night': True,
#    ('so', 'give'): True,
#    ('give', 'every'): True,
#    ('every', 'inch'): True,
#    ('inch', 'love'): True,
#    ('love', 'every'): True,
#    ('every', 'night'): True},
#   'pos'),
#  ({'maybe': True,
#    'pop': True,
#    'tweet': True,
#    'quite': True,
#    'active': True,
#    'twitter': True,
#    ('maybe', 'pop'): True,
#    ('pop', 'tweet'): True,
#    ('tweet', 'quite'): True,
#    ('quite', 'active'): True,
#    ('active', 'twitter'): True},
#   'pos'),
#  ({'shame': True,
#    'women': True,
#    'mamma': True,
#    'mia': True,
#    'horny': True,
#    'since': True,
#    'men': True,
#    'island': True,
#    ('shame', 'women'): True,
#    ('women', 'mamma'): True,
#    ('mamma', 'mia'): True,
#    ('mia', 'so'): True,
#    ('so', 'horny'): True,
#    ('horny', 'since'): True,
#    ('since', 'men'): True,
#    ('men', 'island'): True,
#    ('island', 'so'): True},
#   'pos'),
#  ({'thanks': True,
#    'letting': True,
#    'know': True,
#    'going': True,
#    'check': True,
#    'eureka': True,
#    'later': True,
#    'knowledge': True,
#    ('thanks', 'letting'): True,
#    ('letting', 'know'): True,
#    ('know', 'going'): True,
#    ('going', 'check'): True,
#    ('check', 'eureka'): True,
#    ('eureka', 'later'): True,
#    ('later', 'knowledge'): True},
#   'pos'),
#  ({'hey': True,
#    'ok': True,
#    'thx': True,
#    'ttyl': True,
#    'oh': True,
#    'sowwy': True,
#    'lol': True,
#    ('hey', 'ok'): True,
#    ('ok', 'thx'): True,
#    ('thx', 'too'): True,
#    ('too', 'ttyl'): True,
#    ('ttyl', 'oh'): True,
#    ('oh', 'sowwy'): True,
#    ('sowwy', 'lol'): True},
#   'pos'),
#  ({'happy': True,
#    'mothers': True,
#    'day': True,
#    ('happy', 'mothers'): True,
#    ('mothers', 'day'): True},
#   'pos'),
#  ({'knew': True,
#    'sharepoint': True,
#    'written': True,
#    'interns': True,
#    ('knew', 'sharepoint'): True,
#    ('sharepoint', 'written'): True,
#    ('written', 'interns'): True,
#    ('interns', 'just'): True,
#    ('just', 'knew'): True},
#   'pos'),
#  ({'happy': True}, 'pos'),
#  ({'faltam': True,
#    'dias': True,
#    'para': True,
#    'world': True,
#    'drawing': True,
#    'day': True,
#    ('faltam', 'dias'): True,
#    ('dias', 'para'): True,
#    ('para', 'world'): True,
#    ('world', 'drawing'): True,
#    ('drawing', 'day'): True},
#   'pos'),
#  ({'haha': True,
#    'omg': True,
#    'stayin': True,
#    'steezy': True,
#    'mowin': True,
#    'lawn': True,
#    'loviie': True,
#    'still': True,
#    'goiing': True,
#    'tanning': True,
#    'soon': True,
#    ('haha', 'omg'): True,
#    ('omg', 'stayin'): True,
#    ('stayin', 'steezy'): True,
#    ('steezy', 'mowin'): True,
#    ('mowin', 'lawn'): True,
#    ('lawn', 'loviie'): True,
#    ('loviie', 'still'): True,
#    ('still', 'goiing'): True,
#    ('goiing', 'tanning'): True,
#    ('tanning', 'soon'): True},
#   'pos'),
#  ({'wanna': True,
#    'play': True,
#    'camera': True,
#    'settle': True,
#    'playing': True,
#    'iv': True,
#    'heart': True,
#    'monitors': True,
#    ('wanna', 'play'): True,
#    ('play', 'camera'): True,
#    ('camera', 'but'): True,
#    ('but', 'settle'): True,
#    ('settle', 'playing'): True,
#    ('playing', 'iv'): True,
#    ('iv', 'heart'): True,
#    ('heart', 'monitors'): True},
#   'pos'),
#  ({'lol': True,
#    'robotpickuplines': True,
#    'hilarious': True,
#    ('lol', 'robotpickuplines'): True,
#    ('robotpickuplines', 'hilarious'): True},
#   'pos'),
#  ({'man': True,
#    'oh': True,
#    'punch': True,
#    'head': True,
#    'im': True,
#    'ok': True,
#    ('man', 'oh'): True,
#    ('oh', 'man'): True,
#    ('man', 'punch'): True,
#    ('punch', 'head'): True,
#    ('head', 'but'): True,
#    ('but', 'im'): True,
#    ('im', 'ok'): True},
#   'pos'),
#  ({'friends': True,
#    'get': True,
#    'ur': True,
#    'shit': True,
#    'could': True,
#    'every': True,
#    'weeknd': True,
#    'aiigght': True,
#    'coop': True,
#    'crew': True,
#    ('friends', 'get'): True,
#    ('get', 'ur'): True,
#    ('ur', 'friends'): True,
#    ('friends', 'friends'): True,
#    ('friends', 'shit'): True,
#    ('shit', 'could'): True,
#    ('could', 'every'): True,
#    ('every', 'weeknd'): True,
#    ('weeknd', 'aiigght'): True,
#    ('aiigght', 'coop'): True,
#    ('coop', 'crew'): True},
#   'pos'),
#  ({'beautiful': True,
#    'satisfying': True,
#    'day': True,
#    'bargain': True,
#    'shopping': True,
#    'loves': True,
#    ('such', 'beautiful'): True,
#    ('beautiful', 'satisfying'): True,
#    ('satisfying', 'day'): True,
#    ('day', 'bargain'): True,
#    ('bargain', 'shopping'): True,
#    ('shopping', 'loves'): True},
#   'pos'),
#  ({'thank': True,
#    'god': True,
#    'today': True,
#    'friday': True,
#    'love': True,
#    'ti': True,
#    ('thank', 'god'): True,
#    ('god', 'today'): True,
#    ('today', 'friday'): True,
#    ('friday', 'love'): True,
#    ('love', 'ti'): True,
#    ('ti', 'ti'): True},
#   'pos'),
#  ({'thrilled': True,
#    'work': True,
#    'morning': True,
#    ('thrilled', 'work'): True,
#    ('work', 'morning'): True},
#   'pos'),
#  ({'break': True,
#    'dance': True,
#    'hearts': True,
#    'short': True,
#    'stack': True,
#    'ringtone': True,
#    'love': True,
#    'song': True,
#    ('break', 'dance'): True,
#    ('dance', 'not'): True,
#    ('not', 'hearts'): True,
#    ('hearts', 'short'): True,
#    ('short', 'stack'): True,
#    ('stack', 'ringtone'): True,
#    ('ringtone', 'love'): True,
#    ('love', 'song'): True},
#   'pos'),
#  ({'life': True,
#    'lazzzzyyyy': True,
#    ('life', 'very'): True,
#    ('very', 'lazzzzyyyy'): True},
#   'pos'),
#  ({'ish': True,
#    'good': True,
#    'mood': True,
#    'tlk': True,
#    ('ish', 'good'): True,
#    ('good', 'mood'): True,
#    ('mood', 'tlk'): True},
#   'pos'),
#  ({'made': True,
#    'nice': True,
#    'twice': True,
#    ('made', 'nice'): True,
#    ('nice', 'twice'): True},
#   'pos'),
#  ({'loves': True,
#    'life': True,
#    'atm': True,
#    'brilliant': True,
#    'xd': True,
#    ('loves', 'life'): True,
#    ('life', 'atm'): True,
#    ('atm', 'brilliant'): True,
#    ('brilliant', 'xd'): True},
#   'pos'),
#  ({'else': True,
#    'happy': True,
#    'mood': True,
#    ('else', 'happy'): True,
#    ('happy', 'mood'): True},
#   'pos'),
#  ({'bye': True, 'everyone': True, ('bye', 'everyone'): True}, 'pos'),
#  ({'far': True,
#    'good': True,
#    ('so', 'far'): True,
#    ('far', 'so'): True,
#    ('so', 'good'): True},
#   'pos'),
#  ({'today': True,
#    'great': True,
#    'day': True,
#    ('today', 'great'): True,
#    ('great', 'day'): True},
#   'pos'),
#  ({'lot': True, ('lot', 'lot'): True}, 'pos'),
#  ({'tiger': True,
#    'woods': True,
#    'via': True,
#    ('tiger', 'woods'): True,
#    ('woods', 'via'): True},
#   'pos'),
#  ({'yippeeeee': True,
#    'yay': True,
#    'lets': True,
#    'gather': True,
#    'hay': True,
#    'love': True,
#    'found': True,
#    'way': True,
#    'boy': True,
#    'gonna': True,
#    'stay': True,
#    'added': True,
#    'master': True,
#    'holy': True,
#    ('yippeeeee', 'yay'): True,
#    ('yay', 'lets'): True,
#    ('lets', 'gather'): True,
#    ('gather', 'hay'): True,
#    ('hay', 'love'): True,
#    ('love', 'found'): True,
#    ('found', 'way'): True,
#    ('way', 'boy'): True,
#    ('boy', 'gonna'): True,
#    ('gonna', 'stay'): True,
#    ('stay', 'added'): True,
#    ('added', 'master'): True,
#    ('master', 'holy'): True,
#    ('holy', 'way'): True,
#    ('way', 'way'): True},
#   'pos'),
#  ({'hardest': True,
#    'working': True,
#    'chica': True,
#    'know': True,
#    'mii': True,
#    'boss': True,
#    'lady': True,
#    'look': True,
#    'seriously': True,
#    'lol': True,
#    ('hardest', 'working'): True,
#    ('working', 'chica'): True,
#    ('chica', 'know'): True,
#    ('know', 'mii'): True,
#    ('mii', 'boss'): True,
#    ('boss', 'lady'): True,
#    ('lady', 'look'): True,
#    ('look', 'seriously'): True,
#    ('seriously', 'lol'): True},
#   'pos'),
#  ({'thanks': True,
#    'bestttttttttttttttttttt': True,
#    'dawg': True,
#    ('thanks', 'bestttttttttttttttttttt'): True,
#    ('bestttttttttttttttttttt', 'dawg'): True},
#   'pos'),
#  ({'praise': True,
#    'god': True,
#    'beautiful': True,
#    'day': True,
#    ('praise', 'god'): True,
#    ('god', 'beautiful'): True,
#    ('beautiful', 'day'): True},
#   'pos'),
#  ({'love': True,
#    'guyssss': True,
#    'rings': True,
#    'mmmyeahh': True,
#    'bling': True,
#    'blingg': True,
#    ('love', 'guyssss'): True,
#    ('guyssss', 'rings'): True,
#    ('rings', 'mmmyeahh'): True,
#    ('mmmyeahh', 'bling'): True,
#    ('bling', 'blingg'): True},
#   'pos'),
#  ({'chance': True, 'boo': True, ('chance', 'boo'): True}, 'pos'),
#  ({'thank': True,
#    'much': True,
#    'dvd': True,
#    'suggestion': True,
#    'nice': True,
#    'looks': True,
#    'good': True,
#    ('thank', 'very'): True,
#    ('very', 'much'): True,
#    ('much', 'dvd'): True,
#    ('dvd', 'suggestion'): True,
#    ('suggestion', 'very'): True,
#    ('very', 'nice'): True,
#    ('nice', 'looks'): True,
#    ('looks', 'good'): True},
#   'pos'),
#  ({'wonderful': True,
#    'day': True,
#    'grrrrrrrrreat': True,
#    ('wonderful', 'day'): True,
#    ('day', 'grrrrrrrrreat'): True},
#   'pos'),
#  ({'passed': True,
#    'exam': True,
#    'today': True,
#    ('passed', 'exam'): True,
#    ('exam', 'today'): True},
#   'pos'),
#  ({'want': True,
#    'write': True,
#    'song': True,
#    'think': True,
#    ('want', 'write'): True,
#    ('write', 'song'): True,
#    ('song', 'think'): True},
#   'pos'),
#  ({'always': True,
#    'thought': True,
#    'time': True,
#    'estimates': True,
#    'use': True,
#    'value': True,
#    'pi': True,
#    'rule': True,
#    'exception': True,
#    'squared': True,
#    ('always', 'thought'): True,
#    ('thought', 'time'): True,
#    ('time', 'estimates'): True,
#    ('estimates', 'use'): True,
#    ('use', 'value'): True,
#    ('value', 'pi'): True,
#    ('pi', 'rule'): True,
#    ('rule', 'only'): True,
#    ('only', 'exception'): True,
#    ('exception', 'pi'): True,
#    ('pi', 'squared'): True,
#    ('squared', 'rule'): True},
#   'pos'),
#  ({'creativity': True,
#    'via': True,
#    'twitter': True,
#    ('creativity', 'via'): True,
#    ('via', 'twitter'): True},
#   'pos'),
#  ({'tease': True,
#    'wanna': True,
#    'hear': True,
#    'tracks': True,
#    ('tease', 'wanna'): True,
#    ('wanna', 'hear'): True,
#    ('hear', 'tracks'): True},
#   'pos'),
#  ({'traveltips': True,
#    'student': True,
#    'safety': True,
#    'roughplaces': True,
#    ('traveltips', 'student'): True,
#    ('student', 'safety'): True,
#    ('safety', 'roughplaces'): True},
#   'pos'),
#  ({'fml': True}, 'pos'),
#  ({'gotta': True,
#    'love': True,
#    'blip': True,
#    'fm': True,
#    'john': True,
#    'mayer': True,
#    'trio': True,
#    'california': True,
#    'dreamin': True,
#    'heard': True,
#    'conan': True,
#    ('gotta', 'love'): True,
#    ('love', 'blip'): True,
#    ('blip', 'fm'): True,
#    ('fm', 'john'): True,
#    ('john', 'mayer'): True,
#    ('mayer', 'trio'): True,
#    ('trio', 'california'): True,
#    ('california', 'dreamin'): True,
#    ('dreamin', 'heard'): True,
#    ('heard', 'conan'): True},
#   'pos'),
#  ({'case': True,
#    'need': True,
#    'help': True,
#    ('just', 'case'): True,
#    ('case', 'need'): True,
#    ('need', 'help'): True},
#   'pos'),
#  ({'im': True,
#    'sure': True,
#    'love': True,
#    'lol': True,
#    ('im', 'sure'): True,
#    ('sure', 'love'): True,
#    ('love', 'lol'): True},
#   'pos'),
#  ({'karl': True,
#    'lagerfeld': True,
#    'twitter': True,
#    'profile': True,
#    'lol': True,
#    'heart': True,
#    'first': True,
#    'pic': True,
#    ('karl', 'lagerfeld'): True,
#    ('lagerfeld', 'twitter'): True,
#    ('twitter', 'profile'): True,
#    ('profile', 'lol'): True,
#    ('lol', 'heart'): True,
#    ('heart', 'first'): True,
#    ('first', 'pic'): True},
#   'pos'),
#  ({'avatar': True,
#    'figure': True,
#    'people': True,
#    'either': True,
#    ('avatar', 'not'): True,
#    ('not', 'figure'): True,
#    ('figure', 'people'): True,
#    ('people', 'either'): True},
#   'pos'),
#  ({'happened': True,
#    'movies': True,
#    'anyway': True,
#    'like': True,
#    'hollywood': True,
#    'forgot': True,
#    'rough': True,
#    'times': True,
#    'public': True,
#    'wants': True,
#    'see': True,
#    ('happened', 'movies'): True,
#    ('movies', 'anyway'): True,
#    ('anyway', 'like'): True,
#    ('like', 'hollywood'): True,
#    ('hollywood', 'forgot'): True,
#    ('forgot', 'rough'): True,
#    ('rough', 'times'): True,
#    ('times', 'public'): True,
#    ('public', 'wants'): True,
#    ('wants', 'see'): True},
#   'pos'),
#  ({'whoops': True,
#    'credit': True,
#    'due': True,
#    'rb': True,
#    ('whoops', 'credit'): True,
#    ('credit', 'due'): True,
#    ('due', 'rb'): True},
#   'pos'),
#  ({'exit': True,
#    'cessna': True,
#    'skydiving': True,
#    ('not', 'exit'): True,
#    ('exit', 'cessna'): True,
#    ('cessna', 'skydiving'): True},
#   'pos'),
#  ({'chicken': True,
#    'mcnuggets': True,
#    'double': True,
#    'cheeseburgers': True,
#    'large': True,
#    'fries': True,
#    'lemonade': True,
#    'dinner': True,
#    'may': True,
#    'ask': True,
#    'hate': True,
#    'body': True,
#    ('chicken', 'mcnuggets'): True,
#    ('mcnuggets', 'double'): True,
#    ('double', 'cheeseburgers'): True,
#    ('cheeseburgers', 'large'): True,
#    ('large', 'fries'): True,
#    ('fries', 'lemonade'): True,
#    ('lemonade', 'dinner'): True,
#    ('dinner', 'may'): True,
#    ('may', 'ask'): True,
#    ('ask', 'hate'): True,
#    ('hate', 'body'): True},
#   'pos'),
#  ({'th': True,
#    'tweet': True,
#    'breakfast': True,
#    'everything': True,
#    'bagel': True,
#    'toasted': True,
#    'cream': True,
#    'cheese': True,
#    'iced': True,
#    'cap': True,
#    'delish': True,
#    ('th', 'tweet'): True,
#    ('tweet', 'breakfast'): True,
#    ('breakfast', 'everything'): True,
#    ('everything', 'bagel'): True,
#    ('bagel', 'toasted'): True,
#    ('toasted', 'cream'): True,
#    ('cream', 'cheese'): True,
#    ('cheese', 'iced'): True,
#    ('iced', 'cap'): True,
#    ('cap', 'delish'): True},
#   'pos'),
#  ({'blessed': True,
#    'sunday': True,
#    'everyone': True,
#    ('blessed', 'sunday'): True,
#    ('sunday', 'everyone'): True},
#   'pos'),
#  ({'dog': True,
#    'riding': True,
#    'bicycle': True,
#    ('dog', 'riding'): True,
#    ('riding', 'bicycle'): True},
#   'pos'),
#  ({'problem': True,
#    'shared': True,
#    'buck': True,
#    'passed': True,
#    ('problem', 'shared'): True,
#    ('shared', 'buck'): True,
#    ('buck', 'passed'): True},
#   'pos'),
#  ({'hitech': True}, 'pos'),
#  ({'quite': True,
#    'tired': True,
#    'wait': True,
#    'till': True,
#    'wwe': True,
#    'burswood': True,
#    ('quite', 'tired'): True,
#    ('tired', 'not'): True,
#    ('not', 'wait'): True,
#    ('wait', 'till'): True,
#    ('till', 'wwe'): True,
#    ('wwe', 'burswood'): True},
#   'pos'),
#  ({'awake': True,
#    'ready': True,
#    'day': True,
#    ('awake', 'ready'): True,
#    ('ready', 'day'): True},
#   'pos'),
#  ({'nasty': True,
#    'studio': True,
#    'woman': True,
#    'go': True,
#    'sleepies': True,
#    ('nasty', 'studio'): True,
#    ('studio', 'woman'): True,
#    ('woman', 'go'): True,
#    ('go', 'sleepies'): True},
#   'pos'),
#  ({'feeling': True,
#    'ok': True,
#    'first': True,
#    'time': True,
#    'days': True,
#    'thank': True,
#    ('feeling', 'ok'): True,
#    ('ok', 'first'): True,
#    ('first', 'time'): True,
#    ('time', 'days'): True,
#    ('days', 'thank'): True},
#   'pos'),
#  ({'found': True,
#    'new': True,
#    'way': True,
#    'text': True,
#    'yey': True,
#    ('found', 'new'): True,
#    ('new', 'way'): True,
#    ('way', 'text'): True,
#    ('text', 'yey'): True},
#   'pos'),
#  ({'going': True,
#    'paddle': True,
#    'moz': True,
#    ('going', 'paddle'): True,
#    ('paddle', 'moz'): True},
#   'pos'),
#  ({'good': True,
#    'nite': True,
#    'hope': True,
#    'grandma': True,
#    'visits': True,
#    'dreams': True,
#    'tonight': True,
#    'last': True,
#    'night': True,
#    'uplifting': True,
#    'miss': True,
#    ('good', 'nite'): True,
#    ('nite', 'hope'): True,
#    ('hope', 'grandma'): True,
#    ('grandma', 'visits'): True,
#    ('visits', 'dreams'): True,
#    ('dreams', 'tonight'): True,
#    ('tonight', 'last'): True,
#    ('last', 'night'): True,
#    ('night', 'uplifting'): True,
#    ('uplifting', 'miss'): True},
#   'pos'),
#  ({'goodbassplayer': True,
#    'funny': True,
#    'oilipo': True,
#    'hope': True,
#    'people': True,
#    'bring': True,
#    'us': True,
#    'good': True,
#    'things': True,
#    'started': True,
#    'early': True,
#    'week': True,
#    ('goodbassplayer', 'funny'): True,
#    ('funny', 'oilipo'): True,
#    ('oilipo', 'hope'): True,
#    ('hope', 'people'): True,
#    ('people', 'bring'): True,
#    ('bring', 'us'): True,
#    ('us', 'good'): True,
#    ('good', 'things'): True,
#    ('things', 'started'): True,
#    ('started', 'early'): True,
#    ('early', 'week'): True},
#   'pos'),
#  ({'tell': True,
#    'ya': True,
#    'yummy': True,
#    'decided': True,
#    'go': True,
#    'hunt': True,
#    'blender': True,
#    'drinks': True,
#    'know': True,
#    'good': True,
#    'ones': True,
#    ('tell', 'ya'): True,
#    ('ya', 'very'): True,
#    ('very', 'yummy'): True,
#    ('yummy', 'decided'): True,
#    ('decided', 'go'): True,
#    ('go', 'hunt'): True,
#    ('hunt', 'blender'): True,
#    ('blender', 'drinks'): True,
#    ('drinks', 'know'): True,
#    ('know', 'good'): True,
#    ('good', 'ones'): True},
#   'pos'),
#  ({'listenin': True,
#    'new': True,
#    'fav': True,
#    'band': True,
#    'amor': True,
#    ('listenin', 'new'): True,
#    ('new', 'fav'): True,
#    ('fav', 'band'): True,
#    ('band', 'more'): True,
#    ('more', 'amor'): True},
#   'pos'),
#  ({'another': True,
#    'day': True,
#    'paradise': True,
#    ('just', 'another'): True,
#    ('another', 'day'): True,
#    ('day', 'paradise'): True},
#   'pos'),
#  ({'love': True}, 'pos'),
#  ({'pop': True,
#    'movie': True,
#    'chill': True,
#    'bit': True,
#    'get': True,
#    'innnnn': True,
#    'call': True,
#    'text': True,
#    ('pop', 'movie'): True,
#    ('movie', 'chill'): True,
#    ('chill', 'bit'): True,
#    ('bit', 'get'): True,
#    ('get', 'innnnn'): True,
#    ('innnnn', 'call'): True,
#    ('call', 'text'): True},
#   'pos'),
#  ({'swim': True}, 'pos'),
#  ({'ahh': True,
#    'school': True,
#    'monday': True,
#    'ready': True,
#    ('ahh', 'school'): True,
#    ('school', 'monday'): True,
#    ('monday', 'not'): True,
#    ('not', 'ready'): True},
#   'pos'),
#  ({'ahhh': True,
#    'drizzy': True,
#    'mr': True,
#    'rogers': True,
#    'indeed': True,
#    'best': True,
#    ('ahhh', 'drizzy'): True,
#    ('drizzy', 'mr'): True,
#    ('mr', 'rogers'): True,
#    ('rogers', 'indeed'): True,
#    ('indeed', 'best'): True},
#   'pos'),
#  ({'small': True, 'things': True, ('small', 'things'): True}, 'pos'),
#  ({'always': True,
#    'nice': True,
#    'thing': True,
#    'wake': True,
#    'yay': True,
#    'gosh': True,
#    'typical': True,
#    'lame': True,
#    'overanalyzing': True,
#    'teenager': True,
#    'lmao': True,
#    'nap': True,
#    ('always', 'nice'): True,
#    ('nice', 'thing'): True,
#    ('thing', 'wake'): True,
#    ('wake', 'yay'): True,
#    ('yay', 'gosh'): True,
#    ('gosh', 'such'): True,
#    ('such', 'typical'): True,
#    ('typical', 'lame'): True,
#    ('lame', 'overanalyzing'): True,
#    ('overanalyzing', 'teenager'): True,
#    ('teenager', 'lmao'): True,
#    ('lmao', 'nice'): True,
#    ('nice', 'nap'): True},
#   'pos'),
#  ({'excited': True}, 'pos'),
#  ({'feelin': True,
#    'happy': True,
#    ('feelin', 'very'): True,
#    ('very', 'happy'): True},
#   'pos'),
#  ({'feeding': True, 'pig': True, ('feeding', 'pig'): True}, 'pos'),
#  ({'alarm': True,
#    'clock': True,
#    'device': True,
#    'waking': True,
#    'people': True,
#    'small': True,
#    'children': True,
#    ('alarm', 'clock'): True,
#    ('clock', 'device'): True,
#    ('device', 'waking'): True,
#    ('waking', 'people'): True,
#    ('people', 'not'): True,
#    ('not', 'small'): True,
#    ('small', 'children'): True},
#   'pos'),
#  ({'anoron': True,
#    'reedcourty': True,
#    'operaunite': True,
#    'com': True,
#    'webserver': True,
#    'content': True,
#    'home': True,
#    'sch': True,
#    'alternat': True,
#    'va': True,
#    ('anoron', 'reedcourty'): True,
#    ('reedcourty', 'operaunite'): True,
#    ('operaunite', 'com'): True,
#    ('com', 'webserver'): True,
#    ('webserver', 'content'): True,
#    ('content', 'home'): True,
#    ('home', 'sch'): True,
#    ('sch', 'alternat'): True,
#    ('alternat', 'va'): True},
#   'pos'),
#  ({'another': True,
#    'friday': True,
#    'night': True,
#    'rock': True,
#    'band': True,
#    ('another', 'friday'): True,
#    ('friday', 'night'): True,
#    ('night', 'rock'): True,
#    ('rock', 'band'): True},
#   'pos'),
#  ({'million': True,
#    'making': True,
#    'difference': True,
#    'help': True,
#    'believe': True,
#    'came': True,
#    'believing': True,
#    'leave': True,
#    'god': True,
#    ('million', 'making'): True,
#    ('making', 'difference'): True,
#    ('difference', 'not'): True,
#    ('not', 'help'): True,
#    ('help', 'but'): True,
#    ('but', 'believe'): True,
#    ('believe', 'came'): True,
#    ('came', 'believing'): True,
#    ('believing', 'leave'): True,
#    ('leave', 'believing'): True,
#    ('believing', 'god'): True},
#   'pos'),
#  ({'good': True,
#    'morning': True,
#    'great': True,
#    'day': True,
#    ('good', 'morning'): True,
#    ('morning', 'great'): True,
#    ('great', 'day'): True},
#   'pos'),
#  ({'luvly': True, 'day': True, ('luvly', 'day'): True}, 'pos'),
#  ({'hot': True, ('so', 'hot'): True}, 'pos'),
#  ({'hmm': True}, 'pos'),
#  ({'iowa': True,
#    'happy': True,
#    'yea': True,
#    ('iowa', 'no'): True,
#    ('no', 'happy'): True,
#    ('happy', 'yea'): True},
#   'pos'),
#  ({'got': True, 'home': True, ('just', 'got'): True, ('got', 'home'): True},
#   'pos'),
#  ({'saw': True,
#    'sink': True,
#    'whole': True,
#    'video': True,
#    'kerrang': True,
#    'ive': True,
#    'seen': True,
#    'loads': True,
#    'much': True,
#    'better': True,
#    'tv': True,
#    ('just', 'saw'): True,
#    ('saw', 'sink'): True,
#    ('sink', 'whole'): True,
#    ('whole', 'video'): True,
#    ('video', 'kerrang'): True,
#    ('kerrang', 'ive'): True,
#    ('ive', 'seen'): True,
#    ('seen', 'loads'): True,
#    ('loads', 'but'): True,
#    ('but', 'so'): True,
#    ('so', 'much'): True,
#    ('much', 'better'): True,
#    ('better', 'tv'): True},
#   'pos'),
#  ({'mom': True,
#    'funniest': True,
#    'person': True,
#    'ever': True,
#    ('mom', 'funniest'): True,
#    ('funniest', 'person'): True,
#    ('person', 'ever'): True},
#   'pos'),
#  ({'pie': True,
#    'seems': True,
#    'quite': True,
#    'good': True,
#    'appetite': True,
#    ('pie', 'seems'): True,
#    ('seems', 'quite'): True,
#    ('quite', 'good'): True,
#    ('good', 'appetite'): True},
#   'pos'),
#  ({'nhl': True,
#    'penguins': True,
#    'red': True,
#    'wings': True,
#    'final': True,
#    'lead': True,
#    'series': True,
#    'stats': True,
#    'stars': True,
#    'visit': True,
#    ('nhl', 'penguins'): True,
#    ('penguins', 'red'): True,
#    ('red', 'wings'): True,
#    ('wings', 'final'): True,
#    ('final', 'red'): True,
#    ('wings', 'lead'): True,
#    ('lead', 'series'): True,
#    ('series', 'stats'): True,
#    ('stats', 'stars'): True,
#    ('stars', 'more'): True,
#    ('more', 'visit'): True},
#   'pos'),
#  ({'young': True,
#    'teke': True,
#    'miss': True,
#    'cuzin': True,
#    'year': True,
#    'sence': True,
#    'died': True,
#    'dont': True,
#    'ashamed': True,
#    'faith': True,
#    ('young', 'teke'): True,
#    ('teke', 'miss'): True,
#    ('miss', 'cuzin'): True,
#    ('cuzin', 'year'): True,
#    ('year', 'sence'): True,
#    ('sence', 'died'): True,
#    ('died', 'dont'): True,
#    ('dont', 'ashamed'): True,
#    ('ashamed', 'faith'): True},
#   'pos'),
#  ({'amazing': True,
#    'bjork': True,
#    'bachelorette': True,
#    ('amazing', 'bjork'): True,
#    ('bjork', 'bachelorette'): True},
#   'pos'),
#  ({'thank': True}, 'pos'),
#  ({'andyhurleyday': True}, 'pos'),
#  ({'asot': True}, 'pos'),
#  ({'followfriday': True}, 'pos'),
#  ({'mcflyforgermany': True, ('mcflyforgermany', 'mcflyforgermany'): True},
#   'pos'),
#  ({}, 'pos'),
#  ({'pic': True,
#    'want': True,
#    'tell': True,
#    'cause': True,
#    'got': True,
#    ('pic', 'want'): True,
#    ('want', 'more'): True,
#    ('more', 'tell'): True,
#    ('tell', 'cause'): True,
#    ('cause', 'got'): True,
#    ('got', 'more'): True},
#   'pos'),
#  ({'expression': True, 'watching': True, ('expression', 'watching'): True},
#   'pos'),
#  ({'freelance': True,
#    'writer': True,
#    'braille': True,
#    'porn': True,
#    'stunt': True,
#    'double': True,
#    'hand': True,
#    'model': True,
#    'palmolive': True,
#    'dishwashing': True,
#    'liquid': True,
#    ('freelance', 'writer'): True,
#    ('writer', 'braille'): True,
#    ('braille', 'porn'): True,
#    ('porn', 'stunt'): True,
#    ('stunt', 'double'): True,
#    ('double', 'hand'): True,
#    ('hand', 'model'): True,
#    ('model', 'palmolive'): True,
#    ('palmolive', 'dishwashing'): True,
#    ('dishwashing', 'liquid'): True},
#   'pos'),
#  ({'im': True,
#    'love': True,
#    'care': True,
#    'knows': True,
#    'elf': True,
#    ('im', 'love'): True,
#    ('love', 'not'): True,
#    ('not', 'care'): True,
#    ('care', 'knows'): True,
#    ('knows', 'elf'): True},
#   'pos'),
#  ({'must': True,
#    'people': True,
#    'insist': True,
#    'talking': True,
#    'stupid': True,
#    'politics': True,
#    'comments': True,
#    'bubblegum': True,
#    'pop': True,
#    'song': True,
#    'sorry': True,
#    'get': True,
#    ('must', 'people'): True,
#    ('people', 'insist'): True,
#    ('insist', 'talking'): True,
#    ('talking', 'stupid'): True,
#    ('stupid', 'politics'): True,
#    ('politics', 'comments'): True,
#    ('comments', 'bubblegum'): True,
#    ('bubblegum', 'pop'): True,
#    ('pop', 'song'): True,
#    ('song', 'sorry'): True,
#    ('sorry', 'get'): True},
#   'pos'),
#  ({'simple': True, 'gets': True, ('simple', 'gets'): True}, 'pos'),
#  ({'tweets': True,
#    'lady': True,
#    'saying': True,
#    'goodnite': True,
#    'later': True,
#    'good': True,
#    'morning': True,
#    'crazy': True,
#    'would': True,
#    'never': True,
#    'imagined': True,
#    'yrs': True,
#    'ago': True,
#    ('tweets', 'lady'): True,
#    ('lady', 'saying'): True,
#    ('saying', 'goodnite'): True,
#    ('goodnite', 'tweets'): True,
#    ('tweets', 'later'): True,
#    ('later', 'lady'): True,
#    ('saying', 'good'): True,
#    ('good', 'morning'): True,
#    ('morning', 'crazy'): True,
#    ('crazy', 'would'): True,
#    ('would', 'never'): True,
#    ('never', 'imagined'): True,
#    ('imagined', 'yrs'): True,
#    ('yrs', 'ago'): True},
#   'pos'),
#  ({'nursery': True,
#    'wailing': True,
#    'ended': True,
#    'sleeping': True,
#    'soundly': True,
#    'working': True,
#    'morning': True,
#    'shift': True,
#    'tmrw': True,
#    'grr': True,
#    ('nursery', 'wailing'): True,
#    ('wailing', 'just'): True,
#    ('just', 'ended'): True,
#    ('ended', 'sleeping'): True,
#    ('sleeping', 'soundly'): True,
#    ('soundly', 'working'): True,
#    ('working', 'morning'): True,
#    ('morning', 'shift'): True,
#    ('shift', 'tmrw'): True,
#    ('tmrw', 'grr'): True},
#   'pos'),
#  ({'random': True,
#    'mention': True,
# ...
#    ('tummy', 'hurt'): True,
#    ('hurt', 'laughing'): True,
#    ('laughing', 'too'): True,
#    ('too', 'much'): True,
#    ('much', 'simple'): True,
#    ('simple', 'mind'): True,
#    ('mind', 'simple'): True,
#    ('simple', 'pleasures'): True,
#    ('pleasures', 'lol'): True},
#   'pos'),
#  ({'really': True, 'lol': True, ('really', 'lol'): True}, 'pos'),
#  ({'relay': True, 'lifee': True, ('relay', 'lifee'): True}, 'pos'),
#  ({'revised': True,
#    'biochemistry': True,
#    'bit': True,
#    'taking': True,
#    'break': True,
#    'deserved': True,
#    'letting': True,
#    'go': True,
#    'xd': True,
#    ('revised', 'biochemistry'): True,
#    ('biochemistry', 'bit'): True,
#    ('bit', 'taking'): True,
#    ('taking', 'break'): True,
#    ('break', 'deserved'): True,
#    ('deserved', 'letting'): True,
#    ('letting', 'go'): True,
#    ('go', 'bit'): True,
#    ('bit', 'xd'): True},
#   'pos'),
#  ({'ts': True,
#    'studio': True,
#    'jess': True,
#    'killah': True,
#    'back': True,
#    'fuck': True,
#    ('ts', 'studio'): True,
#    ('studio', 'jess'): True,
#    ('jess', 'killah'): True,
#    ('killah', 'back'): True,
#    ('back', 'fuck'): True},
#   'pos'),
#  ({'makes': True,
#    'bullish': True,
#    'worth': True,
#    ('makes', 'bullish'): True,
#    ('bullish', 'worth'): True},
#   'pos'),
#  ({'happy': True,
#    'lalalalala': True,
#    'taylor': True,
#    'lautner': True,
#    'world': True,
#    'haha': True,
#    ('very', 'very'): True,
#    ('very', 'happy'): True,
#    ('happy', 'lalalalala'): True,
#    ('lalalalala', 'taylor'): True,
#    ('taylor', 'lautner'): True,
#    ('lautner', 'world'): True,
#    ('world', 'haha'): True},
#   'pos'),
#  ({'good': True, 'mood': True, ('good', 'mood'): True}, 'pos'),
#  ({'good': True, 'mood': True, ('good', 'mood'): True}, 'pos'),
#  ({'case': True,
#    'missed': True,
#    'check': True,
#    'new': True,
#    'love': True,
#    'bloggety': True,
#    'leave': True,
#    'comments': True,
#    'let': True,
#    'know': True,
#    'ya': True,
#    'think': True,
#    ('case', 'missed'): True,
#    ('missed', 'check'): True,
#    ('check', 'new'): True,
#    ('new', 'love'): True,
#    ('love', 'bloggety'): True,
#    ('bloggety', 'leave'): True,
#    ('leave', 'comments'): True,
#    ('comments', 'let'): True,
#    ('let', 'know'): True,
#    ('know', 'ya'): True,
#    ('ya', 'think'): True},
#   'pos'),
#  ({'anyone': True, 'turned': True, ('anyone', 'turned'): True}, 'pos'),
#  ({'alright': True,
#    'morning': True,
#    'lovees': True,
#    'calculating': True,
#    'collapse': True,
#    ('alright', 'morning'): True,
#    ('morning', 'lovees'): True,
#    ('lovees', 'calculating'): True,
#    ('calculating', 'collapse'): True},
#   'pos'),
#  ({'jeremih': True,
#    'lil': True,
#    'cutie': True,
#    ('jeremih', 'lil'): True,
#    ('lil', 'cutie'): True},
#   'pos'),
#  ({'juss': True,
#    'chillin': True,
#    'outz': True,
#    'listenin': True,
#    'dem': True,
#    'mad': True,
#    'tunes': True,
#    'beautiful': True,
#    'night': True,
#    'feelin': True,
#    'goooood': True,
#    'waitin': True,
#    'cuz': True,
#    'come': True,
#    ('juss', 'chillin'): True,
#    ('chillin', 'outz'): True,
#    ('outz', 'listenin'): True,
#    ('listenin', 'dem'): True,
#    ('dem', 'mad'): True,
#    ('mad', 'tunes'): True,
#    ('tunes', 'beautiful'): True,
#    ('beautiful', 'night'): True,
#    ('night', 'feelin'): True,
#    ('feelin', 'goooood'): True,
#    ('goooood', 'waitin'): True,
#    ('waitin', 'cuz'): True,
#    ('cuz', 'come'): True,
#    ('come', 'over'): True},
#   'pos'),
#  ({'today': True,
#    'wonderful': True,
#    'day': True,
#    ('not', 'today'): True,
#    ('today', 'wonderful'): True,
#    ('wonderful', 'day'): True},
#   'pos'),
#  ({'makes': True,
#    'format': True,
#    'tighter': True,
#    'prefer': True,
#    'new': True,
#    'lol': True,
#    'started': True,
#    'getting': True,
#    'serious': True,
#    'writing': True,
#    ('makes', 'format'): True,
#    ('format', 'tighter'): True,
#    ('tighter', 'prefer'): True,
#    ('prefer', 'new'): True,
#    ('new', 'lol'): True,
#    ('lol', 'only'): True,
#    ('only', 'started'): True,
#    ('started', 'getting'): True,
#    ('getting', 'serious'): True,
#    ('serious', 'writing'): True},
#   'pos'),
#  ({'sims': True,
#    'pure': True,
#    'awesome': True,
#    'ness': True,
#    'created': True,
#    'simon': True,
#    'cowell': True,
#    'terri': True,
#    'seymour': True,
#    'living': True,
#    'house': True,
#    'haha': True,
#    ('sims', 'pure'): True,
#    ('pure', 'awesome'): True,
#    ('awesome', 'ness'): True,
#    ('ness', 'created'): True,
#    ('created', 'simon'): True,
#    ('simon', 'cowell'): True,
#    ('cowell', 'terri'): True,
#    ('terri', 'seymour'): True,
#    ('seymour', 'living'): True,
#    ('living', 'house'): True,
#    ('house', 'haha'): True},
#   'pos'),
#  ({'sitting': True,
#    'ion': True,
#    'garden': True,
#    'hayley': True,
#    'drinking': True,
#    'cider': True,
#    'lovely': True,
#    'relax': True,
#    'yesterday': True,
#    'first': True,
#    'day': True,
#    'tomorrow': True,
#    'ohhhhhh': True,
#    ('sitting', 'ion'): True,
#    ('ion', 'garden'): True,
#    ('garden', 'hayley'): True,
#    ('hayley', 'drinking'): True,
#    ('drinking', 'cider'): True,
#    ('cider', 'lovely'): True,
#    ('lovely', 'relax'): True,
#    ('relax', 'yesterday'): True,
#    ('yesterday', 'first'): True,
#    ('first', 'day'): True,
#    ('day', 'tomorrow'): True,
#    ('tomorrow', 'ohhhhhh'): True},
#   'pos'),
#  ({'sitting': True,
#    'making': True,
#    'cookies': True,
#    'cuzzy': True,
#    ('sitting', 'making'): True,
#    ('making', 'cookies'): True,
#    ('cookies', 'cuzzy'): True},
#   'pos'),
#  ({'sleeping': True,
#    'losers': True,
#    'people': True,
#    'arent': True,
#    'vampires': True,
#    ('sleeping', 'losers'): True,
#    ('losers', 'people'): True,
#    ('people', 'arent'): True,
#    ('arent', 'vampires'): True},
#   'pos'),
#  ({'smile': True,
#    'happy': True,
#    'looks': True,
#    'good': True,
#    ('smile', 'happy'): True,
#    ('happy', 'looks'): True,
#    ('looks', 'good'): True},
#   'pos'),
#  ({'smile': True,
#    'shining': True,
#    'blooming': True,
#    'happy': True,
#    'wanna': True,
#    'dream': True,
#    'thoughts': True,
#    'forever': True,
#    'hahaha': True,
#    ('smile', 'shining'): True,
#    ('shining', 'blooming'): True,
#    ('blooming', 'so'): True,
#    ('so', 'happy'): True,
#    ('happy', 'just'): True,
#    ('just', 'wanna'): True,
#    ('wanna', 'dream'): True,
#    ('dream', 'happy'): True,
#    ('happy', 'thoughts'): True,
#    ('thoughts', 'forever'): True,
#    ('forever', 'hahaha'): True},
#   'pos'),
#  ({'smiley': True, 'faces': True, ('smiley', 'faces'): True}, 'pos'),
#  ({'excited': True, ('so', 'excited'): True}, 'pos'),
#  ({'good': True, ('so', 'good'): True, ('good', 'so'): True}, 'pos'),
#  ({'happy': True,
#    'less': True,
#    'week': True,
#    ('so', 'happy'): True,
#    ('happy', 'less'): True,
#    ('less', 'than'): True,
#    ('than', 'week'): True},
#   'pos'),
#  ({'many': True,
#    'old': True,
#    'good': True,
#    'movies': True,
#    'tv': True,
#    'tonight': True,
#    'national': True,
#    'lampoons': True,
#    'vacation': True,
#    'princess': True,
#    'bride': True,
#    'wonder': True,
#    'ever': True,
#    'get': True,
#    'bed': True,
#    ('so', 'many'): True,
#    ('many', 'old'): True,
#    ('old', 'but'): True,
#    ('but', 'good'): True,
#    ('good', 'movies'): True,
#    ('movies', 'tv'): True,
#    ('tv', 'tonight'): True,
#    ('tonight', 'national'): True,
#    ('national', 'lampoons'): True,
#    ('lampoons', 'vacation'): True,
#    ('vacation', 'princess'): True,
#    ('princess', 'bride'): True,
#    ('bride', 'wonder'): True,
#    ('wonder', 'ever'): True,
#    ('ever', 'get'): True,
#    ('get', 'bed'): True},
#   'pos'),
#  ({'still': True,
#    'curious': True,
#    'whole': True,
#    'david': True,
#    'thing': True,
#    ('so', 'still'): True,
#    ('still', 'curious'): True,
#    ('curious', 'whole'): True,
#    ('whole', 'david'): True,
#    ('david', 'thing'): True},
#   'pos'),
#  ({'sold': True,
#    'another': True,
#    'shirt': True,
#    'cafepress': True,
#    ('sold', 'another'): True,
#    ('another', 'shirt'): True,
#    ('shirt', 'cafepress'): True},
#   'pos'),
#  ({'wov': True}, 'pos'),
#  ({'happy': True,
#    'although': True,
#    'things': True,
#    'mind': True,
#    'damn': True,
#    'tricky': True,
#    'mine': True,
#    ('just', 'happy'): True,
#    ('happy', 'although'): True,
#    ('although', 'things'): True,
#    ('things', 'mind'): True,
#    ('mind', 'damn'): True,
#    ('damn', 'tricky'): True,
#    ('tricky', 'mind'): True,
#    ('mind', 'mine'): True},
#   'pos'),
#  ({'iam': True, 'bored': True, ('iam', 'bored'): True}, 'pos'),
#  ({'rather': True,
#    'girlfriend': True,
#    'crib': True,
#    'runnin': True,
#    'round': True,
#    'naked': True,
#    'girl': True,
#    'gotta': True,
#    'bed': True,
#    'nice': True,
#    'work': True,
#    ('rather', 'girlfriend'): True,
#    ('girlfriend', 'crib'): True,
#    ('crib', 'runnin'): True,
#    ('runnin', 'round'): True,
#    ('round', 'naked'): True,
#    ('naked', 'girl'): True,
#    ('girl', 'gotta'): True,
#    ('gotta', 'girlfriend'): True,
#    ('girlfriend', 'bed'): True,
#    ('bed', 'nice'): True,
#    ('nice', 'work'): True},
#   'pos'),
#  ({'end': True,
#    'eat': True,
#    'words': True,
#    'worry': True,
#    'taste': True,
#    'like': True,
#    'chicken': True,
#    ('end', 'eat'): True,
#    ('eat', 'words'): True,
#    ('words', 'not'): True,
#    ('not', 'worry'): True,
#    ('worry', 'taste'): True,
#    ('taste', 'like'): True,
#    ('like', 'chicken'): True},
#   'pos'),
#  ({'ihop': True,
#    'sounds': True,
#    'good': True,
#    ('ihop', 'sounds'): True,
#    ('sounds', 'good'): True},
#   'pos'),
#  ({'feeling': True, 'greate': True, ('feeling', 'greate'): True}, 'pos'),
#  ({'shalah': True,
#    'nails': True,
#    'wootness': True,
#    ('shalah', 'nails'): True,
#    ('nails', 'wootness'): True},
#   'pos'),
#  ({'im': True,
#    'good': True,
#    'mood': True,
#    'right': True,
#    'guys': True,
#    ('im', 'such'): True,
#    ('such', 'good'): True,
#    ('good', 'mood'): True,
#    ('mood', 'right'): True,
#    ('right', 'guys'): True},
#   'pos'),
#  ({'like': True,
#    'radio': True,
#    'right': True,
#    'fm': True,
#    'canterbury': True,
#    'wanna': True,
#    'hear': True,
#    'music': True,
#    ('like', 'so'): True,
#    ('so', 'radio'): True,
#    ('radio', 'right'): True,
#    ('right', 'fm'): True,
#    ('fm', 'canterbury'): True,
#    ('canterbury', 'wanna'): True,
#    ('wanna', 'hear'): True,
#    ('hear', 'music'): True},
#   'pos'),
#  ({'spoke': True,
#    'urban': True,
#    'youth': True,
#    'conference': True,
#    'reload': True,
#    'morning': True,
#    'riley': True,
#    'softball': True,
#    'games': True,
#    'nightlight': True,
#    'whew': True,
#    ('spoke', 'urban'): True,
#    ('urban', 'youth'): True,
#    ('youth', 'conference'): True,
#    ('conference', 'reload'): True,
#    ('reload', 'morning'): True,
#    ('morning', 'riley'): True,
#    ('riley', 'softball'): True,
#    ('softball', 'games'): True,
#    ('games', 'nightlight'): True,
#    ('nightlight', 'whew'): True},
#   'pos'),
#  ({'starbucks': True,
#    'tonight': True,
#    'love': True,
#    'dysfunctional': True,
#    'family': True,
#    ('starbucks', 'tonight'): True,
#    ('tonight', 'love'): True,
#    ('love', 'dysfunctional'): True,
#    ('dysfunctional', 'family'): True},
#   'pos'),
#  ({'steak': True,
#    'shrimp': True,
#    'excited': True,
#    ('steak', 'shrimp'): True,
#    ('shrimp', 'excited'): True},
#   'pos'),
#  ({'stray': True,
#    'cats': True,
#    'cat': True,
#    'strut': True,
#    ('stray', 'cats'): True,
#    ('cats', 'stray'): True,
#    ('stray', 'cat'): True,
#    ('cat', 'strut'): True},
#   'pos'),
#  ({'study': True,
#    'leave': True,
#    'finally': True,
#    ('study', 'leave'): True,
#    ('leave', 'finally'): True},
#   'pos'),
#  ({'subscribing': True,
#    'swoozie': True,
#    'youtube': True,
#    'following': True,
#    'twitter': True,
#    'adds': True,
#    'street': True,
#    'cred': True,
#    ('subscribing', 'swoozie'): True,
#    ('swoozie', 'youtube'): True,
#    ('youtube', 'following'): True,
#    ('following', 'twitter'): True,
#    ('twitter', 'adds'): True,
#    ('adds', 'street'): True,
#    ('street', 'cred'): True},
#   'pos'),
#  ({'sunrise': True,
#    'worth': True,
#    'waiting': True,
#    ('sunrise', 'worth'): True,
#    ('worth', 'waiting'): True},
#   'pos'),
#  ({'im': True,
#    'putting': True,
#    'weave': True,
#    'inmy': True,
#    'head': True,
#    'though': True,
#    'gonna': True,
#    'deal': True,
#    'short': True,
#    'cut': True,
#    ('im', 'not'): True,
#    ('not', 'putting'): True,
#    ('putting', 'no'): True,
#    ('no', 'weave'): True,
#    ('weave', 'inmy'): True,
#    ('inmy', 'head'): True,
#    ('head', 'though'): True,
#    ('though', 'gonna'): True,
#    ('gonna', 'deal'): True,
#    ('deal', 'short'): True,
#    ('short', 'cut'): True},
#   'pos'),
#  ({'tired': True,
#    'gonna': True,
#    'go': True,
#    'bed': True,
#    'probably': True,
#    'hah': True,
#    'watch': True,
#    'tv': True,
#    'hit': True,
#    'hay': True,
#    ('tired', 'gonna'): True,
#    ('gonna', 'go'): True,
#    ('go', 'bed'): True,
#    ('bed', 'most'): True,
#    ('most', 'probably'): True,
#    ('probably', 'hah'): True,
#    ('hah', 'gonna'): True,
#    ('gonna', 'watch'): True,
#    ('watch', 'tv'): True,
#    ('tv', 'hit'): True,
#    ('hit', 'hay'): True},
#   'pos'),
#  ({'im': True,
#    'iiiiiiiiiiiiimmmmmmmmm': True,
#    'ready': True,
#    'lol': True,
#    ('im', 'iiiiiiiiiiiiimmmmmmmmm'): True,
#    ('iiiiiiiiiiiiimmmmmmmmm', 'ready'): True,
#    ('ready', 'ready'): True,
#    ('ready', 'lol'): True},
#   'pos'),
#  ({'im': True,
#    'watchin': True,
#    'taken': True,
#    'yay': True,
#    'haha': True,
#    ('im', 'watchin'): True,
#    ('watchin', 'taken'): True,
#    ('taken', 'yay'): True,
#    ('yay', 'haha'): True},
#   'pos'),
#  ({'good': True,
#    'mood': True,
#    'anyway': True,
#    'love': True,
#    'music': True,
#    ('good', 'mood'): True,
#    ('mood', 'anyway'): True,
#    ('anyway', 'love'): True,
#    ('love', 'music'): True},
#   'pos'),
#  ({'love': True,
#    'guy': True,
#    'lives': True,
#    'miami': True,
#    'fail': True,
#    ('love', 'guy'): True,
#    ('guy', 'lives'): True,
#    ('lives', 'miami'): True,
#    ('miami', 'fail'): True},
#   'pos'),
#  ({'lab': True,
#    'right': True,
#    'cooking': True,
#    'sum': True,
#    'farout': True,
#    'ent': True,
#    'hotness': True,
#    'admire': True,
#    'greatness': True,
#    'works': True,
#    ('lab', 'right'): True,
#    ('right', 'cooking'): True,
#    ('cooking', 'sum'): True,
#    ('sum', 'farout'): True,
#    ('farout', 'ent'): True,
#    ('ent', 'hotness'): True,
#    ('hotness', 'admire'): True,
#    ('admire', 'greatness'): True,
#    ('greatness', 'works'): True},
#   'pos'),
#  ({'init': True,
#    'woo': True,
#    'lol': True,
#    'wait': True,
#    'see': True,
#    'videos': True,
#    'side': True,
#    ('init', 'woo'): True,
#    ('woo', 'lol'): True,
#    ('lol', 'wait'): True,
#    ('wait', 'see'): True,
#    ('see', 'videos'): True,
#    ('videos', 'side'): True},
#   'pos'),
#  ({'inky': True,
#    'eating': True,
#    'crackers': True,
#    ('inky', 'eating'): True,
#    ('eating', 'crackers'): True},
#   'pos'),
#  ({'insomniac': True,
#    'enjoying': True,
#    'life': True,
#    ('insomniac', 'enjoying'): True,
#    ('enjoying', 'life'): True},
#   'pos'),
#  ({'finishing': True,
#    'semester': True,
#    'less': True,
#    'week': True,
#    'remaining': True,
#    ('finishing', 'off'): True,
#    ('off', 'semester'): True,
#    ('semester', 'less'): True,
#    ('less', 'than'): True,
#    ('than', 'week'): True,
#    ('week', 'remaining'): True},
#   'pos'),
#  ({'going': True,
#    'watford': True,
#    'text': True,
#    'need': True,
#    ('going', 'watford'): True,
#    ('watford', 'text'): True,
#    ('text', 'need'): True},
#   'pos'),
#  ({'went': True,
#    'like': True,
#    'asked': True,
#    'smiled': True,
#    'said': True,
#    'yes': True,
#    ('went', 'like'): True,
#    ('like', 'asked'): True,
#    ('asked', 'smiled'): True,
#    ('smiled', 'said'): True,
#    ('said', 'yes'): True},
#   'pos'),
#  ({'go': True,
#    'home': True,
#    'good': True,
#    'bye': True,
#    'work': True,
#    'see': True,
#    'tomorrow': True,
#    ('go', 'home'): True,
#    ('home', 'good'): True,
#    ('good', 'bye'): True,
#    ('bye', 'work'): True,
#    ('work', 'see'): True,
#    ('see', 'tomorrow'): True},
#   'pos'),
#  ({'wiccan': True,
#    'wedding': True,
#    'love': True,
#    'show': True,
#    ('wiccan', 'wedding'): True,
#    ('wedding', 'too'): True,
#    ('too', 'love'): True,
#    ('love', 'show'): True},
#   'pos'),
#  ...]

# %%
neg_reviews_set = []
for words in neg_reviews:
#     print(words)
    neg_reviews_set.append((bag_of_all_words(words), 'neg'))
neg_reviews_set
# Out:
# [({'sad': True,
#    'apl': True,
#    'friend': True,
#    ('so', 'sad'): True,
#    ('sad', 'apl'): True,
#    ('apl', 'friend'): True},
#   'neg'),
#  ({'missed': True,
#    'new': True,
#    'moon': True,
#    'trailer': True,
#    ('missed', 'new'): True,
#    ('new', 'moon'): True,
#    ('moon', 'trailer'): True},
#   'neg'),
#  ({'omgaga': True,
#    'im': True,
#    'sooo': True,
#    'gunna': True,
#    'cry': True,
#    'dentist': True,
#    'since': True,
#    'suposed': True,
#    'get': True,
#    'crown': True,
#    'put': True,
#    'mins': True,
#    ('omgaga', 'im'): True,
#    ('im', 'sooo'): True,
#    ('sooo', 'im'): True,
#    ('im', 'gunna'): True,
#    ('gunna', 'cry'): True,
#    ('cry', 'dentist'): True,
#    ('dentist', 'since'): True,
#    ('since', 'suposed'): True,
#    ('suposed', 'just'): True,
#    ('just', 'get'): True,
#    ('get', 'crown'): True,
#    ('crown', 'put'): True,
#    ('put', 'mins'): True},
#   'neg'),
#  ({'think': True,
#    'mi': True,
#    'bf': True,
#    'cheating': True,
#    ('think', 'mi'): True,
#    ('mi', 'bf'): True,
#    ('bf', 'cheating'): True},
#   'neg'),
#  ({'worry': True,
#    'much': True,
#    ('just', 'worry'): True,
#    ('worry', 'too'): True,
#    ('too', 'much'): True},
#   'neg'),
#  ({'sunny': True,
#    'work': True,
#    'tomorrow': True,
#    'tv': True,
#    'tonight': True,
#    ('sunny', 'work'): True,
#    ('work', 'tomorrow'): True,
#    ('tomorrow', 'tv'): True,
#    ('tv', 'tonight'): True},
#   'neg'),
#  ({'must': True,
#    'think': True,
#    'positive': True,
#    ('must', 'think'): True,
#    ('think', 'positive'): True},
#   'neg'),
#  ({'weekend': True,
#    'sucked': True,
#    'far': True,
#    ('weekend', 'sucked'): True,
#    ('sucked', 'so'): True,
#    ('so', 'far'): True},
#   'neg'),
#  ({'jb': True,
#    'isnt': True,
#    'showing': True,
#    'australia': True,
#    ('jb', 'isnt'): True,
#    ('isnt', 'showing'): True,
#    ('showing', 'australia'): True,
#    ('australia', 'more'): True},
#   'neg'),
#  ({'ok': True,
#    'thats': True,
#    'win': True,
#    ('ok', 'thats'): True,
#    ('thats', 'win'): True},
#   'neg'),
#  ({'way': True,
#    'feel': True,
#    'right': True,
#    ('way', 'feel'): True,
#    ('feel', 'right'): True},
#   'neg'),
#  ({'awhhe': True,
#    'man': True,
#    'completely': True,
#    'useless': True,
#    'rt': True,
#    'funny': True,
#    'twitter': True,
#    ('awhhe', 'man'): True,
#    ('man', 'completely'): True,
#    ('completely', 'useless'): True,
#    ('useless', 'rt'): True,
#    ('rt', 'funny'): True,
#    ('funny', 'twitter'): True},
#   'neg'),
#  ({'huge': True,
#    'roll': True,
#    'thunder': True,
#    'scary': True,
#    ('huge', 'roll'): True,
#    ('roll', 'thunder'): True,
#    ('thunder', 'just'): True,
#    ('just', 'so'): True,
#    ('so', 'scary'): True},
#   'neg'),
#  ({'cut': True,
#    'beard': True,
#    'growing': True,
#    'well': True,
#    'year': True,
#    'gonna': True,
#    'start': True,
#    'happy': True,
#    'meantime': True,
#    ('just', 'cut'): True,
#    ('cut', 'beard'): True,
#    ('beard', 'off'): True,
#    ('off', 'only'): True,
#    ('only', 'growing'): True,
#    ('growing', 'well'): True,
#    ('well', 'over'): True,
#    ('over', 'year'): True,
#    ('year', 'gonna'): True,
#    ('gonna', 'start'): True,
#    ('start', 'over'): True,
#    ('over', 'happy'): True,
#    ('happy', 'meantime'): True},
#   'neg'),
#  ({'sad': True, 'iran': True, ('very', 'sad'): True, ('sad', 'iran'): True},
#   'neg'),
#  ({'wompppp': True, 'wompp': True, ('wompppp', 'wompp'): True}, 'neg'),
#  ({'sad': True,
#    'level': True,
#    'writing': True,
#    'massive': True,
#    'blog': True,
#    'tweet': True,
#    'myspace': True,
#    'comp': True,
#    'shut': True,
#    'lost': True,
#    'lays': True,
#    'fetal': True,
#    'position': True,
#    ('sad', 'level'): True,
#    ('level', 'writing'): True,
#    ('writing', 'massive'): True,
#    ('massive', 'blog'): True,
#    ('blog', 'tweet'): True,
#    ('tweet', 'myspace'): True,
#    ('myspace', 'comp'): True,
#    ('comp', 'shut'): True,
#    ('shut', 'lost'): True,
#    ('lost', 'lays'): True,
#    ('lays', 'fetal'): True,
#    ('fetal', 'position'): True},
#   'neg'),
#  ({'headed': True,
#    'hospitol': True,
#    'pull': True,
#    'golf': True,
#    'tourny': True,
#    'rd': True,
#    'place': True,
#    'think': True,
#    'ripped': True,
#    'something': True,
#    'yeah': True,
#    ('headed', 'hospitol'): True,
#    ('hospitol', 'pull'): True,
#    ('pull', 'golf'): True,
#    ('golf', 'tourny'): True,
#    ('tourny', 'rd'): True,
#    ('rd', 'place'): True,
#    ('place', 'think'): True,
#    ('think', 'ripped'): True,
#    ('ripped', 'something'): True,
#    ('something', 'yeah'): True},
#   'neg'),
#  ({'boring': True,
#    'whats': True,
#    'wrong': True,
#    'please': True,
#    'tell': True,
#    ('boring', 'whats'): True,
#    ('whats', 'wrong'): True,
#    ('wrong', 'please'): True,
#    ('please', 'tell'): True},
#   'neg'),
#  ({'bothered': True,
#    'wish': True,
#    'could': True,
#    'spend': True,
#    'rest': True,
#    'life': True,
#    'sat': True,
#    'going': True,
#    'gigs': True,
#    'seriously': True,
#    ('not', 'bothered'): True,
#    ('bothered', 'wish'): True,
#    ('wish', 'could'): True,
#    ('could', 'spend'): True,
#    ('spend', 'rest'): True,
#    ('rest', 'life'): True,
#    ('life', 'just'): True,
#    ('just', 'sat'): True,
#    ('sat', 'going'): True,
#    ('going', 'gigs'): True,
#    ('gigs', 'seriously'): True},
#   'neg'),
#  ({'feeeling': True,
#    'like': True,
#    'shit': True,
#    'right': True,
#    'really': True,
#    'want': True,
#    'sleep': True,
#    'nooo': True,
#    'hours': True,
#    'dancing': True,
#    'art': True,
#    'assignment': True,
#    'finish': True,
#    ('feeeling', 'like'): True,
#    ('like', 'shit'): True,
#    ('shit', 'right'): True,
#    ('right', 'really'): True,
#    ('really', 'want'): True,
#    ('want', 'sleep'): True,
#    ('sleep', 'but'): True,
#    ('but', 'nooo'): True,
#    ('nooo', 'hours'): True,
#    ('hours', 'dancing'): True,
#    ('dancing', 'art'): True,
#    ('art', 'assignment'): True,
#    ('assignment', 'finish'): True},
#   'neg'),
#  ({'realize': True,
#    'deep': True,
#    'geez': True,
#    'give': True,
#    'girl': True,
#    'warning': True,
#    'atleast': True,
#    ('not', 'realize'): True,
#    ('realize', 'deep'): True,
#    ('deep', 'geez'): True,
#    ('geez', 'give'): True,
#    ('give', 'girl'): True,
#    ('girl', 'warning'): True,
#    ('warning', 'atleast'): True},
#   'neg'),
#  ({'hate': True,
#    'athlete': True,
#    'appears': True,
#    'tear': True,
#    'acl': True,
#    'live': True,
#    'television': True,
#    ('hate', 'athlete'): True,
#    ('athlete', 'appears'): True,
#    ('appears', 'tear'): True,
#    ('tear', 'acl'): True,
#    ('acl', 'live'): True,
#    ('live', 'television'): True},
#   'neg'),
#  ({'miss': True,
#    'guys': True,
#    'think': True,
#    'wearing': True,
#    'skinny': True,
#    'jeans': True,
#    'cute': True,
#    'sweater': True,
#    'heels': True,
#    'really': True,
#    'sure': True,
#    'today': True,
#    ('miss', 'guys'): True,
#    ('guys', 'too'): True,
#    ('too', 'think'): True,
#    ('think', 'wearing'): True,
#    ('wearing', 'skinny'): True,
#    ('skinny', 'jeans'): True,
#    ('jeans', 'cute'): True,
#    ('cute', 'sweater'): True,
#    ('sweater', 'heels'): True,
#    ('heels', 'not'): True,
#    ('not', 'really'): True,
#    ('really', 'sure'): True,
#    ('sure', 'today'): True},
#   'neg'),
#  ({'meet': True, 'meat': True, ('meet', 'meat'): True}, 'neg'),
#  ({'horsie': True,
#    'moving': True,
#    'saturday': True,
#    'morning': True,
#    ('horsie', 'moving'): True,
#    ('moving', 'saturday'): True,
#    ('saturday', 'morning'): True},
#   'neg'),
#  ({'sat': True,
#    'need': True,
#    'work': True,
#    'days': True,
#    'week': True,
#    ('no', 'sat'): True,
#    ('sat', 'off'): True,
#    ('off', 'need'): True,
#    ('need', 'work'): True,
#    ('work', 'days'): True,
#    ('days', 'week'): True},
#   'neg'),
#  ({'really': True,
#    'dont': True,
#    'like': True,
#    'room': True,
#    'boring': True,
#    'sick': True,
#    'wardrobe': True,
#    'cant': True,
#    'waiit': True,
#    'till': True,
#    'walk': True,
#    'one': True,
#    'yay': True,
#    ('really', 'dont'): True,
#    ('dont', 'like'): True,
#    ('like', 'room'): True,
#    ('room', 'so'): True,
#    ('so', 'boring'): True,
#    ('boring', 'sick'): True,
#    ('sick', 'wardrobe'): True,
#    ('wardrobe', 'cant'): True,
#    ('cant', 'waiit'): True,
#    ('waiit', 'till'): True,
#    ('till', 'walk'): True,
#    ('walk', 'one'): True,
#    ('one', 'yay'): True},
#   'neg'),
#  ({'sox': True,
#    'floyd': True,
#    'great': True,
#    'relievers': True,
#    'need': True,
#    'scolding': True,
#    ('sox', 'floyd'): True,
#    ('floyd', 'great'): True,
#    ('great', 'but'): True,
#    ('but', 'relievers'): True,
#    ('relievers', 'need'): True,
#    ('need', 'scolding'): True},
#   'neg'),
#  ({'times': True,
#    'like': True,
#    'million': True,
#    ('times', 'like'): True,
#    ('like', 'million'): True},
#   'neg'),
#  ({'type': True,
#    'spaz': True,
#    'downloads': True,
#    'virus': True,
#    'brother': True,
#    'msn': True,
#    'fucked': True,
#    'forever': True,
#    ('type', 'spaz'): True,
#    ('spaz', 'downloads'): True,
#    ('downloads', 'virus'): True,
#    ('virus', 'brother'): True,
#    ('brother', 'msn'): True,
#    ('msn', 'fucked'): True,
#    ('fucked', 'forever'): True},
#   'neg'),
#  ({'fightiin': True,
#    'wiit': True,
#    'babes': True,
#    ('fightiin', 'wiit'): True,
#    ('wiit', 'babes'): True},
#   'neg'),
#  ({'enough': True, 'said': True, ('enough', 'said'): True}, 'neg'),
#  ({'really': True,
#    'makes': True,
#    'sad': True,
#    'look': True,
#    'muslims': True,
#    'reality': True,
#    ('really', 'makes'): True,
#    ('makes', 'sad'): True,
#    ('sad', 'look'): True,
#    ('look', 'muslims'): True,
#    ('muslims', 'reality'): True},
#   'neg'),
#  ({'time': True,
#    'low': True,
#    'shall': True,
#    'motivation': True,
#    'rest': True,
#    'week': True,
#    ('time', 'low'): True,
#    ('low', 'shall'): True,
#    ('shall', 'motivation'): True,
#    ('motivation', 'rest'): True,
#    ('rest', 'week'): True},
#   'neg'),
#  ({'entertainment': True,
#    'someone': True,
#    'complained': True,
#    'properly': True,
#    'experimental': True,
#    'say': True,
#    'experiment': True,
#    'melody': True,
#    ('entertainment', 'over'): True,
#    ('over', 'someone'): True,
#    ('someone', 'complained'): True,
#    ('complained', 'properly'): True,
#    ('properly', 'experimental'): True,
#    ('experimental', 'say'): True,
#    ('say', 'experiment'): True,
#    ('experiment', 'melody'): True},
#   'neg'),
#  ({'another': True,
#    'year': True,
#    'lakers': True,
#    'neither': True,
#    'magic': True,
#    'fun': True,
#    ('another', 'year'): True,
#    ('year', 'lakers'): True,
#    ('lakers', 'neither'): True,
#    ('neither', 'magic'): True,
#    ('magic', 'nor'): True,
#    ('nor', 'fun'): True},
#   'neg'),
#  ({'baddest': True,
#    'day': True,
#    'eveer': True,
#    ('baddest', 'day'): True,
#    ('day', 'eveer'): True},
#   'neg'),
#  ({'proud': True, ('but', 'proud'): True}, 'neg'),
#  ({'congrats': True,
#    'helio': True,
#    'though': True,
#    ('congrats', 'helio'): True,
#    ('helio', 'though'): True},
#   'neg'),
#  ({'david': True,
#    'must': True,
#    'hospitalized': True,
#    'five': True,
#    'days': True,
#    'end': True,
#    'july': True,
#    'palatine': True,
#    'tonsils': True,
#    'probably': True,
#    'never': True,
#    'see': True,
#    'katie': True,
#    'concert': True,
#    ('david', 'must'): True,
#    ('must', 'hospitalized'): True,
#    ('hospitalized', 'five'): True,
#    ('five', 'days'): True,
#    ('days', 'end'): True,
#    ('end', 'july'): True,
#    ('july', 'palatine'): True,
#    ('palatine', 'tonsils'): True,
#    ('tonsils', 'probably'): True,
#    ('probably', 'never'): True,
#    ('never', 'see'): True,
#    ('see', 'katie'): True,
#    ('katie', 'concert'): True},
#   'neg'),
#  ({'friends': True,
#    'leaving': True,
#    'cause': True,
#    'stupid': True,
#    'love': True,
#    ('friends', 'leaving'): True,
#    ('leaving', 'cause'): True,
#    ('cause', 'stupid'): True,
#    ('stupid', 'love'): True},
#   'neg'),
#  ({'hand': True, 'quilting': True, ('hand', 'quilting'): True}, 'neg'),
#  ({'hate': True,
#    'leysh': True,
#    'ar': True,
#    ('hate', 'leysh'): True,
#    ('leysh', 'ar'): True},
#   'neg'),
#  ({'love': True,
#    'guys': True,
#    'much': True,
#    'hurts': True,
#    ('love', 'guys'): True,
#    ('guys', 'so'): True,
#    ('so', 'much'): True,
#    ('much', 'hurts'): True},
#   'neg'),
#  ({'miss': True, 'earl': True, ('miss', 'earl'): True}, 'neg'),
#  ({'miss': True,
#    'new': True,
#    'jersey': True,
#    ('miss', 'new'): True,
#    ('new', 'jersey'): True},
#   'neg'),
#  ({'missed': True,
#    'first': True,
#    'hour': True,
#    'sytycd': True,
#    'last': True,
#    'night': True,
#    'find': True,
#    'online': True,
#    ('missed', 'first'): True,
#    ('first', 'hour'): True,
#    ('hour', 'sytycd'): True,
#    ('sytycd', 'last'): True,
#    ('last', 'night'): True,
#    ('night', 'not'): True,
#    ('not', 'find'): True,
#    ('find', 'online'): True},
#   'neg'),
#  ({'need': True, 'fix': True, ('need', 'fix'): True}, 'neg'),
#  ({'never': True,
#    'thought': True,
#    'become': True,
#    'second': True,
#    'choice': True,
#    ('never', 'thought'): True,
#    ('thought', 'become'): True,
#    ('become', 'second'): True,
#    ('second', 'choice'): True},
#   'neg'),
#  ({'think': True,
#    'may': True,
#    'friendly': True,
#    'lol': True,
#    'well': True,
#    ('think', 'may'): True,
#    ('may', 'too'): True,
#    ('too', 'friendly'): True,
#    ('friendly', 'lol'): True,
#    ('lol', 'well'): True},
#   'neg'),
#  ({'think': True,
#    'manuel': True,
#    'basil': True,
#    'plant': True,
#    'days': True,
#    'live': True,
#    ('think', 'manuel'): True,
#    ('manuel', 'basil'): True,
#    ('basil', 'plant'): True,
#    ('plant', 'only'): True,
#    ('only', 'days'): True,
#    ('days', 'live'): True},
#   'neg'),
#  ({'wanna': True,
#    'home': True,
#    'church': True,
#    'wonder': True,
#    'wht': True,
#    ('wanna', 'home'): True,
#    ('home', 'church'): True,
#    ('church', 'wonder'): True,
#    ('wonder', 'wht'): True},
#   'neg'),
#  ({'wanna': True,
#    'make': True,
#    'pizza': True,
#    ('wanna', 'make'): True,
#    ('make', 'pizza'): True},
#   'neg'),
#  ({'want': True,
#    'gb': True,
#    'harddrive': True,
#    'inch': True,
#    'tv': True,
#    'new': True,
#    'guitar': True,
#    'anyonefeeling': True,
#    'generous': True,
#    ('want', 'gb'): True,
#    ('gb', 'harddrive'): True,
#    ('harddrive', 'inch'): True,
#    ('inch', 'tv'): True,
#    ('tv', 'new'): True,
#    ('new', 'guitar'): True,
#    ('guitar', 'anyonefeeling'): True,
#    ('anyonefeeling', 'generous'): True},
#   'neg'),
#  ({'want': True, 'hug': True, ('want', 'hug'): True}, 'neg'),
#  ({'want': True,
#    'miley': True,
#    'tour': True,
#    'australia': True,
#    ('want', 'miley'): True,
#    ('miley', 'tour'): True,
#    ('tour', 'australia'): True},
#   'neg'),
#  ({'wanted': True,
#    'sleep': True,
#    'morning': True,
#    'mean': True,
#    'kid': True,
#    'popsicle': True,
#    'stick': True,
#    'head': True,
#    'wish': True,
#    'could': True,
#    'fly': True,
#    'away': True,
#    'like': True,
#    'squirrels': True,
#    ('wanted', 'sleep'): True,
#    ('sleep', 'morning'): True,
#    ('morning', 'but'): True,
#    ('but', 'mean'): True,
#    ('mean', 'kid'): True,
#    ('kid', 'popsicle'): True,
#    ('popsicle', 'stick'): True,
#    ('stick', 'head'): True,
#    ('head', 'wish'): True,
#    ('wish', 'could'): True,
#    ('could', 'fly'): True,
#    ('fly', 'away'): True,
#    ('away', 'like'): True,
#    ('like', 'squirrels'): True},
#   'neg'),
#  ({'slow': True,
#    'get': True,
#    'tix': True,
#    ('too', 'slow'): True,
#    ('slow', 'get'): True,
#    ('get', 'tix'): True},
#   'neg'),
#  ({'send': True,
#    'sunshine': True,
#    'northern': True,
#    'ireland': True,
#    'going': True,
#    'swimming': True,
#    'today': True,
#    ('send', 'sunshine'): True,
#    ('sunshine', 'northern'): True,
#    ('northern', 'ireland'): True,
#    ('ireland', 'going'): True,
#    ('going', 'swimming'): True,
#    ('swimming', 'today'): True},
#   'neg'),
#  ({'wish': True,
#    'could': True,
#    'go': True,
#    'beach': True,
#    'would': True,
#    'great': True,
#    'see': True,
#    ('wish', 'could'): True,
#    ('could', 'go'): True,
#    ('go', 'beach'): True,
#    ('beach', 'would'): True,
#    ('would', 'great'): True,
#    ('great', 'see'): True},
#   'neg'),
#  ({'would': True,
#    'much': True,
#    'happier': True,
#    'walls': True,
#    'bedroom': True,
#    'painted': True,
#    'white': True,
#    ('would', 'so'): True,
#    ('so', 'much'): True,
#    ('much', 'happier'): True,
#    ('happier', 'walls'): True,
#    ('walls', 'bedroom'): True,
#    ('bedroom', 'painted'): True,
#    ('painted', 'white'): True},
#   'neg'),
#  ({'idk': True,
#    'wat': True,
#    'trust': True,
#    'im': True,
#    'sorry': True,
#    'da': True,
#    'pain': True,
#    'caused': True,
#    'nebody': True,
#    'ima': True,
#    'take': True,
#    'dis': True,
#    'time': True,
#    'straighten': True,
#    'luv': True,
#    'yall': True,
#    ('idk', 'wat'): True,
#    ('wat', 'trust'): True,
#    ('trust', 'im'): True,
#    ('im', 'sorry'): True,
#    ('sorry', 'da'): True,
#    ('da', 'pain'): True,
#    ('pain', 'caused'): True,
#    ('caused', 'nebody'): True,
#    ('nebody', 'ima'): True,
#    ('ima', 'take'): True,
#    ('take', 'dis'): True,
#    ('dis', 'time'): True,
#    ('time', 'straighten'): True,
#    ('straighten', 'luv'): True,
#    ('luv', 'yall'): True},
#   'neg'),
#  ({'finding': True,
#    'intercept': True,
#    'slope': True,
#    'banging': True,
#    'head': True,
#    'wall': True,
#    'math': True,
#    'brain': True,
#    'heads': True,
#    'come': True,
#    'save': True,
#    ('finding', 'intercept'): True,
#    ('intercept', 'slope'): True,
#    ('slope', 'banging'): True,
#    ('banging', 'head'): True,
#    ('head', 'wall'): True,
#    ('wall', 'math'): True,
#    ('math', 'brain'): True,
#    ('brain', 'heads'): True,
#    ('heads', 'come'): True,
#    ('come', 'save'): True},
#   'neg'),
#  ({'im': True,
#    'sick': True,
#    'cough': True,
#    ('im', 'sick'): True,
#    ('sick', 'cough'): True,
#    ('cough', 'cough'): True},
#   'neg'),
#  ({'cab': True,
#    'headed': True,
#    'airport': True,
#    'going': True,
#    'home': True,
#    'christy': True,
#    ('cab', 'headed'): True,
#    ('headed', 'airport'): True,
#    ('airport', 'going'): True,
#    ('going', 'home'): True,
#    ('home', 'christy'): True},
#   'neg'),
#  ({'case': True,
#    'feel': True,
#    'emo': True,
#    'camp': True,
#    'feeling': True,
#    'wee': True,
#    'bit': True,
#    'alr': True,
#    'bringing': True,
#    'human': True,
#    'rights': True,
#    'watch': True,
#    'world': True,
#    'report': True,
#    'hope': True,
#    'work': True,
#    ('case', 'feel'): True,
#    ('feel', 'emo'): True,
#    ('emo', 'camp'): True,
#    ('camp', 'feeling'): True,
#    ('feeling', 'wee'): True,
#    ('wee', 'bit'): True,
#    ('bit', 'alr'): True,
#    ('alr', 'bringing'): True,
#    ('bringing', 'human'): True,
#    ('human', 'rights'): True,
#    ('rights', 'watch'): True,
#    ('watch', 'world'): True,
#    ('world', 'report'): True,
#    ('report', 'hope'): True,
#    ('hope', 'work'): True},
#   'neg'),
#  ({'jonas': True,
#    'day': True,
#    'almost': True,
#    ('jonas', 'day'): True,
#    ('day', 'almost'): True,
#    ('almost', 'over'): True},
#   'neg'),
#  ({'jus': True,
#    'got': True,
#    'hom': True,
#    'fr': True,
#    'tda': True,
#    'funeral': True,
#    'sad': True,
#    'cried': True,
#    'much': True,
#    'times': True,
#    'love': True,
#    'grandpa': True,
#    'never': True,
#    'say': True,
#    'last': True,
#    'goodbye': True,
#    ('jus', 'got'): True,
#    ('got', 'hom'): True,
#    ('hom', 'fr'): True,
#    ('fr', 'tda'): True,
#    ('tda', 'funeral'): True,
#    ('funeral', 'so'): True,
#    ('so', 'sad'): True,
#    ('sad', 'cried'): True,
#    ('cried', 'so'): True,
#    ('so', 'much'): True,
#    ('much', 'times'): True,
#    ('times', 'much'): True,
#    ('much', 'love'): True,
#    ('love', 'grandpa'): True,
#    ('grandpa', 'never'): True,
#    ('never', 'got'): True,
#    ('got', 'say'): True,
#    ('say', 'last'): True,
#    ('last', 'goodbye'): True},
#   'neg'),
#  ({'longest': True,
#    'night': True,
#    'ever': True,
#    'ugh': True,
#    ('longest', 'night'): True,
#    ('night', 'ever'): True,
#    ('ever', 'ugh'): True},
#   'neg'),
#  ({'mi': True,
#    'momacita': True,
#    'let': True,
#    'go': True,
#    'bf': True,
#    'bball': True,
#    'game': True,
#    'grrr': True,
#    ('mi', 'momacita'): True,
#    ('momacita', 'not'): True,
#    ('not', 'let'): True,
#    ('let', 'go'): True,
#    ('go', 'bf'): True,
#    ('bf', 'bball'): True,
#    ('bball', 'game'): True,
#    ('game', 'grrr'): True},
#   'neg'),
#  ({'mom': True,
#    'says': True,
#    'get': True,
#    'new': True,
#    'phone': True,
#    'immediately': True,
#    'mobile': True,
#    'paying': True,
#    ('mom', 'says'): True,
#    ('says', 'get'): True,
#    ('get', 'new'): True,
#    ('new', 'phone'): True,
#    ('phone', 'immediately'): True,
#    ('immediately', 'off'): True,
#    ('off', 'mobile'): True,
#    ('mobile', 'paying'): True},
#   'neg'),
#  ({'new': True,
#    'car': True,
#    'stolen': True,
#    'mother': True,
#    'wanted': True,
#    'go': True,
#    'pose': True,
#    'church': True,
#    ('new', 'car'): True,
#    ('car', 'stolen'): True,
#    ('stolen', 'mother'): True,
#    ('mother', 'wanted'): True,
#    ('wanted', 'go'): True,
#    ('go', 'pose'): True,
#    ('pose', 'church'): True},
#   'neg'),
#  ({'hang': True,
#    'girls': True,
#    'day': True,
#    'moro': True,
#    'hope': True,
#    ('no', 'hang'): True,
#    ('hang', 'girls'): True,
#    ('girls', 'day'): True,
#    ('day', 'moro'): True,
#    ('moro', 'hope'): True,
#    ('hope', 'so'): True},
#   'neg'),
#  ({'movie': True,
#    'times': True,
#    'sunday': True,
#    'rats': True,
#    'plan': True,
#    'tomorrow': True,
#    'guess': True,
#    'means': True,
#    'work': True,
#    'two': True,
#    'presentations': True,
#    ('no', 'movie'): True,
#    ('movie', 'times'): True,
#    ('times', 'sunday'): True,
#    ('sunday', 'rats'): True,
#    ('rats', 'plan'): True,
#    ('plan', 'tomorrow'): True,
#    ('tomorrow', 'guess'): True,
#    ('guess', 'means'): True,
#    ('means', 'work'): True,
#    ('work', 'two'): True,
#    ('two', 'presentations'): True},
#   'neg'),
#  ({'pavel': True,
#    'tonight': True,
#    'tigersfan': True,
#    ('no', 'pavel'): True,
#    ('pavel', 'tonight'): True,
#    ('tonight', 'tigersfan'): True},
#   'neg'),
#  ({'cool': True,
#    'night': True,
#    ('not', 'cool'): True,
#    ('cool', 'night'): True},
#   'neg'),
#  ({'probably': True,
#    'guna': True,
#    'get': True,
#    'soon': True,
#    'since': True,
#    'one': True,
#    'talkin': True,
#    ('probably', 'guna'): True,
#    ('guna', 'get'): True,
#    ('get', 'off'): True,
#    ('off', 'soon'): True,
#    ('soon', 'since'): True,
#    ('since', 'no'): True,
#    ('no', 'one'): True,
#    ('one', 'talkin'): True,
#    ('talkin', 'no'): True,
#    ('no', 'more'): True},
#   'neg'),
#  ({'really': True,
#    'wanted': True,
#    'safina': True,
#    'pull': True,
#    'win': True,
#    'lose': True,
#    'like': True,
#    ('really', 'wanted'): True,
#    ('wanted', 'safina'): True,
#    ('safina', 'pull'): True,
#    ('pull', 'win'): True,
#    ('win', 'lose'): True,
#    ('lose', 'like'): True},
#   'neg'),
#  ({'rip': True,
#    'david': True,
#    'eddings': True,
#    ('rip', 'david'): True,
#    ('david', 'eddings'): True},
#   'neg'),
#  ({'sannesias': True,
#    'aww': True,
#    'neighbor': True,
#    'need': True,
#    'watch': True,
#    'mean': True,
#    'girls': True,
#    ('sannesias', 'aww'): True,
#    ('aww', 'no'): True,
#    ('no', 'neighbor'): True,
#    ('neighbor', 'need'): True,
#    ('need', 'watch'): True,
#    ('watch', 'mean'): True,
#    ('mean', 'girls'): True},
#   'neg'),
#  ({'whats': True,
#    'status': True,
#    'next': True,
#    'weekend': True,
#    ('so', 'whats'): True,
#    ('whats', 'status'): True,
#    ('status', 'next'): True,
#    ('next', 'weekend'): True},
#   'neg'),
#  ({'sorry': True,
#    'ex': True,
#    'husband': True,
#    'overdosed': True,
#    'daily': True,
#    'dose': True,
#    'haterade': True,
#    ('sorry', 'ex'): True,
#    ('ex', 'husband'): True,
#    ('husband', 'overdosed'): True,
#    ('overdosed', 'daily'): True,
#    ('daily', 'dose'): True,
#    ('dose', 'haterade'): True},
#   'neg'),
#  ({'thanks': True,
#    'definition': True,
#    'throwbie': True,
#    'editors': True,
#    'reviewed': True,
#    'entry': True,
#    'decided': True,
#    'publish': True,
#    ('thanks', 'definition'): True,
#    ('definition', 'throwbie'): True,
#    ('throwbie', 'editors'): True,
#    ('editors', 'reviewed'): True,
#    ('reviewed', 'entry'): True,
#    ('entry', 'decided'): True,
#    ('decided', 'not'): True,
#    ('not', 'publish'): True},
#   'neg'),
#  ({'told': True,
#    'drink': True,
#    'rx': True,
#    'gave': True,
#    'porter': True,
#    'obs': True,
#    'stout': True,
#    'brought': True,
#    'home': True,
#    'neighbors': True,
#    'sad': True,
#    ('told', 'not'): True,
#    ('not', 'drink'): True,
#    ('drink', 'rx'): True,
#    ('rx', 'so'): True,
#    ('so', 'just'): True,
#    ('just', 'gave'): True,
#    ('gave', 'porter'): True,
#    ('porter', 'obs'): True,
#    ('obs', 'stout'): True,
#    ('stout', 'brought'): True,
#    ('brought', 'home'): True,
#    ('home', 'neighbors'): True,
#    ('neighbors', 'sad'): True},
#   'neg'),
#  ({'guys': True,
#    'knw': True,
#    'whyy': True,
#    ('guys', 'knw'): True,
#    ('knw', 'whyy'): True},
#   'neg'),
#  ({'much': True, ('very', 'much'): True, ('much', 'so'): True}, 'neg'),
#  ({'waahhh': True,
#    'getting': True,
#    'sad': True,
#    'miss': True,
#    'hub': True,
#    ('waahhh', 'getting'): True,
#    ('getting', 'sad'): True,
#    ('sad', 'miss'): True,
#    ('miss', 'hub'): True},
#   'neg'),
#  ({'standing': True,
#    'pouring': True,
#    'rain': True,
#    'sitting': True,
#    'top': True,
#    'world': True,
#    'summer': True,
#    'sucks': True,
#    ('standing', 'pouring'): True,
#    ('pouring', 'rain'): True,
#    ('rain', 'sitting'): True,
#    ('sitting', 'top'): True,
#    ('top', 'world'): True,
#    ('world', 'summer'): True,
#    ('summer', 'sucks'): True},
#   'neg'),
#  ({'went': True,
#    'get': True,
#    'dog': True,
#    'vets': True,
#    'theyve': True,
#    'stitched': True,
#    'ear': True,
#    'charged': True,
#    'us': True,
#    'still': True,
#    'bleeds': True,
#    'like': True,
#    'waterfall': True,
#    'everytime': True,
#    'moves': True,
#    ('went', 'get'): True,
#    ('get', 'dog'): True,
#    ('dog', 'vets'): True,
#    ('vets', 'theyve'): True,
#    ('theyve', 'stitched'): True,
#    ('stitched', 'ear'): True,
#    ('ear', 'charged'): True,
#    ('charged', 'us'): True,
#    ('us', 'but'): True,
#    ('but', 'still'): True,
#    ('still', 'bleeds'): True,
#    ('bleeds', 'like'): True,
#    ('like', 'waterfall'): True,
#    ('waterfall', 'everytime'): True,
#    ('everytime', 'moves'): True},
#   'neg'),
#  ({'picture': True,
#    'feel': True,
#    'naked': True,
#    ('picture', 'feel'): True,
#    ('feel', 'naked'): True},
#   'neg'),
#  ({'trains': True,
#    'going': True,
#    'manchester': True,
#    'sunday': True,
#    'go': True,
#    'concert': True,
#    ('not', 'trains'): True,
#    ('trains', 'going'): True,
#    ('going', 'manchester'): True,
#    ('manchester', 'sunday'): True,
#    ('sunday', 'not'): True,
#    ('not', 'go'): True,
#    ('go', 'concert'): True},
#   'neg'),
#  ({'must': True,
#    'people': True,
#    'picky': True,
#    'mean': True,
#    'hours': True,
#    'work': True,
#    'dice': True,
#    ('must', 'people'): True,
#    ('people', 'so'): True,
#    ('so', 'picky'): True,
#    ('picky', 'mean'): True,
#    ('mean', 'hours'): True,
#    ('hours', 'work'): True,
#    ('work', 'no'): True,
#    ('no', 'dice'): True},
#   'neg'),
#  ({'twitter': True,
#    'soon': True,
#    'become': True,
#    'obsolete': True,
#    ('twitter', 'soon'): True,
#    ('soon', 'become'): True,
#    ('become', 'obsolete'): True},
#   'neg'),
#  ({'hi': True,
#    'stranger': True,
#    'hello': True,
#    'frank': True,
#    'lampard': True,
#    'fine': True,
#    'urself': True,
#    'gay': True,
#    ('hi', 'stranger'): True,
#    ('stranger', 'hello'): True,
#    ('hello', 'frank'): True,
#    ('frank', 'lampard'): True,
#    ('lampard', 'fine'): True,
#    ('fine', 'urself'): True,
#    ('urself', 'stranger'): True,
#    ('stranger', 'gay'): True},
#   'neg'),
#  ({'always': True,
#    'one': True,
#    ('always', 'one'): True,
#    ('one', 'only'): True},
#   'neg'),
#  ({'turnoffwords': True,
#    'shit': True,
#    'sucks': True,
#    ('turnoffwords', 'shit'): True,
#    ('shit', 'sucks'): True},
#   'neg'),
#  ({'asylm': True,
#    'panel': True,
#    'guess': True,
#    'back': True,
#    'normal': True,
#    'life': True,
#    ('asylm', 'panel'): True,
#    ('panel', 'over'): True,
#    ('over', 'guess'): True,
#    ('guess', 'back'): True,
#    ('back', 'normal'): True,
#    ('normal', 'life'): True},
#   'neg'),
#  ({'squarespace': True,
#    'brighten': True,
#    'bad': True,
#    'day': True,
#    'never': True,
#    'win': True,
#    'anything': True,
#    ('squarespace', 'brighten'): True,
#    ('brighten', 'bad'): True,
#    ('bad', 'day'): True,
#    ('day', 'never'): True,
#    ('never', 'win'): True,
#    ('win', 'anything'): True},
#   'neg'),
#  ({'susan': True,
#    'boyle': True,
#    'didnt': True,
#    'win': True,
#    'mh': True,
#    'well': True,
#    'diversity': True,
#    'good': True,
#    'though': True,
#    'congratz': True,
#    ('susan', 'boyle'): True,
#    ('boyle', 'didnt'): True,
#    ('didnt', 'win'): True,
#    ('win', 'mh'): True,
#    ('mh', 'well'): True,
#    ('well', 'diversity'): True,
#    ('diversity', 'very'): True,
#    ('very', 'good'): True,
#    ('good', 'though'): True,
#    ('though', 'congratz'): True},
#   'neg'),
#  ({'twenty': True}, 'neg'),
#  ({'graduate': True}, 'neg'),
#  ({'vandals': True,
#    'paint': True,
#    'swastikas': True,
#    'home': True,
#    'author': True,
#    'gay': True,
#    'lesbian': True,
#    'church': True,
#    'story': True,
#    'naples': True,
#    'daily': True,
#    'news': True,
#    ('vandals', 'paint'): True,
#    ('paint', 'swastikas'): True,
#    ('swastikas', 'home'): True,
#    ('home', 'author'): True,
#    ('author', 'gay'): True,
#    ('gay', 'lesbian'): True,
#    ('lesbian', 'church'): True,
#    ('church', 'story'): True,
#    ('story', 'naples'): True,
#    ('naples', 'daily'): True,
#    ('daily', 'news'): True},
#   'neg'),
#  ({'unknown': True,
#    'error': True,
#    'occured': True,
#    'uh': True,
#    'oh': True,
#    'iphone': True,
#    'os': True,
#    'fail': True,
#    'far': True,
#    ('unknown', 'error'): True,
#    ('error', 'occured'): True,
#    ('occured', 'uh'): True,
#    ('uh', 'oh'): True,
#    ('oh', 'iphone'): True,
#    ('iphone', 'os'): True,
#    ('os', 'fail'): True,
#    ('fail', 'so'): True,
#    ('so', 'far'): True},
#   'neg'),
#  ({'experts': True,
#    'homers': True,
#    'predict': True,
#    'eagles': True,
#    'go': True,
#    'giants': True,
#    'bs': True,
#    ('experts', 'homers'): True,
#    ('homers', 'predict'): True,
#    ('predict', 'eagles'): True,
#    ('eagles', 'go'): True,
#    ('go', 'giants'): True,
#    ('giants', 'go'): True,
#    ('go', 'bs'): True},
#   'neg'),
#  ({'want': True,
#    'bad': True,
#    'driving': True,
#    'mad': True,
#    ('want', 'so'): True,
#    ('so', 'bad'): True,
#    ('bad', 'driving'): True,
#    ('driving', 'mad'): True},
#   'neg'),
#  ({'try': True,
#    'turn': True,
#    'tv': True,
#    'get': True,
#    'head': True,
#    'got': True,
#    'feeling': True,
#    'inside': True,
#    'admit': True,
#    'literally': True,
#    'feel': True,
#    ('try', 'turn'): True,
#    ('turn', 'tv'): True,
#    ('tv', 'get'): True,
#    ('get', 'head'): True,
#    ('head', 'got'): True,
#    ('got', 'feeling'): True,
#    ('feeling', 'inside'): True,
#    ('inside', 'just'): True,
#    ('just', 'not'): True,
#    ('not', 'admit'): True,
#    ('admit', 'literally'): True,
#    ('literally', 'feel'): True},
#   'neg'),
#  ({'well': True,
#    'truth': True,
#    'miss': True,
#    'coldplay': True,
#    ('well', 'truth'): True,
#    ('truth', 'miss'): True,
#    ('miss', 'so'): True,
#    ('so', 'coldplay'): True},
#   'neg'),
#  ({'tears': True,
#    'today': True,
#    'last': True,
#    'day': True,
#    'kids': True,
#    'go': True,
#    'summer': True,
#    'break': True,
#    'dads': True,
#    'tomorrow': True,
#    'sighs': True,
#    ('tears', 'today'): True,
#    ('today', 'last'): True,
#    ('last', 'day'): True,
#    ('day', 'kids'): True,
#    ('kids', 'go'): True,
#    ('go', 'summer'): True,
#    ('summer', 'break'): True,
#    ('break', 'dads'): True,
#    ('dads', 'tomorrow'): True,
#    ('tomorrow', 'sighs'): True},
#   'neg'),
#  ({'unsure': True, 'annoyed': True, ('unsure', 'annoyed'): True}, 'neg'),
#  ({'via': True,
#    'designed': True,
#    'gallery': True,
#    'exhibition': True,
#    'postcards': True,
#    'mailers': True,
#    'going': True,
#    'extinct': True,
#    'nyt': True,
#    ('via', 'designed'): True,
#    ('designed', 'gallery'): True,
#    ('gallery', 'exhibition'): True,
#    ('exhibition', 'postcards'): True,
#    ('postcards', 'mailers'): True,
#    ('mailers', 'going'): True,
#    ('going', 'extinct'): True,
#    ('extinct', 'via'): True,
#    ('via', 'nyt'): True},
#   'neg'),
#  ({'beautifulylost': True}, 'neg'),
#  ({'cries': True,
#    'going': True,
#    'miss': True,
#    'harry': True,
#    'potter': True,
#    'comes': True,
#    'leaving': True,
#    'vietnam': True,
#    'july': True,
#    'th': True,
#    'cry': True,
#    ('cries', 'going'): True,
#    ('going', 'miss'): True,
#    ('miss', 'harry'): True,
#    ('harry', 'potter'): True,
#    ('potter', 'comes'): True,
#    ('comes', 'leaving'): True,
#    ('leaving', 'vietnam'): True,
#    ('vietnam', 'july'): True,
#    ('july', 'th'): True,
#    ('th', 'going'): True,
#    ('going', 'cry'): True},
#   'neg'),
#  ({'going': True,
#    'back': True,
#    'bed': True,
#    'lookin': True,
#    'around': True,
#    'see': True,
#    'reason': True,
#    'awake': True,
#    'atm': True,
#    'little': True,
#    ('going', 'back'): True,
#    ('back', 'bed'): True,
#    ('bed', 'lookin'): True,
#    ('lookin', 'around'): True,
#    ('around', 'not'): True,
#    ('not', 'see'): True,
#    ('see', 'reason'): True,
#    ('reason', 'awake'): True,
#    ('awake', 'atm'): True,
#    ('atm', 'little'): True},
#   'neg'),
#  ({'wantt': True,
#    'hiim': True,
#    'soo': True,
#    'badd': True,
#    ('wantt', 'hiim'): True,
#    ('hiim', 'soo'): True,
#    ('soo', 'badd'): True},
#   'neg'),
#  ({'watching': True,
#    'tv': True,
#    'bed': True,
#    'shopping': True,
#    'mom': True,
#    'trent': True,
#    'hopefully': True,
#    'need': True,
#    'best': True,
#    'friend': True,
#    ('watching', 'tv'): True,
#    ('tv', 'bed'): True,
#    ('bed', 'shopping'): True,
#    ('shopping', 'mom'): True,
#    ('mom', 'trent'): True,
#    ('trent', 'hopefully'): True,
#    ('hopefully', 'need'): True,
#    ('need', 'best'): True,
#    ('best', 'friend'): True},
#   'neg'),
#  ({'weird': True,
#    'encounters': True,
#    'many': True,
#    'homeless': True,
#    'creeps': True,
#    'walk': True,
#    'home': True,
#    'tonight': True,
#    'awesome': True,
#    'really': True,
#    ('weird', 'encounters'): True,
#    ('encounters', 'so'): True,
#    ('so', 'many'): True,
#    ('many', 'homeless'): True,
#    ('homeless', 'creeps'): True,
#    ('creeps', 'walk'): True,
#    ('walk', 'home'): True,
#    ('home', 'tonight'): True,
#    ('tonight', 'awesome'): True,
#    ('awesome', 'really'): True},
#   'neg'),
#  ({'rained': True,
#    'truck': True,
#    'race': True,
#    ('rained', 'truck'): True,
#    ('truck', 'race'): True},
#   'neg'),
#  ({'feeling': True, 'worse': True, ('feeling', 'worse'): True}, 'neg'),
#  ({'feeling': True,
#    'pain': True,
#    'happiness': True,
#    'time': True,
#    'confusing': True,
#    ('feeling', 'pain'): True,
#    ('pain', 'happiness'): True,
#    ('happiness', 'time'): True,
#    ('time', 'confusing'): True},
#   'neg'),
#  ({'shirt': True,
#    'panties': True,
#    'celulite': True,
#    ('shirt', 'panties'): True,
#    ('panties', 'celulite'): True},
#   'neg'),
#  ({'turn': True,
#    'back': True,
#    'north': True,
#    'due': True,
#    'body': True,
#    'line': True,
#    'missing': True,
#    'design': True,
#    'council': True,
#    'tech': True,
#    'transfer': True,
#    'event': True,
#    ('turn', 'back'): True,
#    ('back', 'north'): True,
#    ('north', 'due'): True,
#    ('due', 'body'): True,
#    ('body', 'line'): True,
#    ('line', 'so'): True,
#    ('so', 'missing'): True,
#    ('missing', 'design'): True,
#    ('design', 'council'): True,
#    ('council', 'design'): True,
#    ('design', 'tech'): True,
#    ('tech', 'transfer'): True,
#    ('transfer', 'event'): True},
#   'neg'),
#  ({'everything': True,
#    'hard': True,
#    ('everything', 'so'): True,
#    ('so', 'hard'): True},
#   'neg'),
#  ({'bueno': True,
#    'good': True,
#    'bye': True,
#    'night': True,
#    ('bueno', 'good'): True,
#    ('good', 'bye'): True,
#    ('bye', 'good'): True,
#    ('good', 'night'): True},
#   'neg'),
#  ({'let': True,
#    'fun': True,
#    'give': True,
#    'ya': True,
#    ('let', 'fun'): True,
#    ('fun', 'give'): True,
#    ('give', 'ya'): True,
#    ('ya', 'give'): True},
#   'neg'),
#  ({'want': True, 'move': True, ('not', 'want'): True, ('want', 'move'): True},
#   'neg'),
#  ({'train': True,
#    'crash': True,
#    'dc': True,
#    ('train', 'crash'): True,
#    ('crash', 'dc'): True},
#   'neg'),
#  ({'happened': True,
#    'angels': True,
#    'demons': True,
#    'lions': True,
#    'tigers': True,
#    'bears': True,
#    ('happened', 'angels'): True,
#    ('angels', 'demons'): True,
#    ('demons', 'lions'): True,
#    ('lions', 'tigers'): True,
#    ('tigers', 'bears'): True},
#   'neg'),
#  ({'well': True,
#    'sure': True,
#    'minimizes': True,
#    'impact': True,
#    'lol': True,
#    ('well', 'sure'): True,
#    ('sure', 'minimizes'): True,
#    ('minimizes', 'impact'): True,
#    ('impact', 'lol'): True},
#   'neg'),
#  ({'went': True,
#    'work': True,
#    'last': True,
#    'year': True,
#    'pants': True,
#    'ironically': True,
#    'day': True,
#    'job': True,
#    'fml': True,
#    ('went', 'work'): True,
#    ('work', 'last'): True,
#    ('last', 'year'): True,
#    ('year', 'no'): True,
#    ('no', 'pants'): True,
#    ('pants', 'ironically'): True,
#    ('ironically', 'last'): True,
#    ('last', 'day'): True,
#    ('day', 'work'): True,
#    ('work', 'job'): True,
#    ('job', 'fml'): True},
#   'neg'),
#  ({'many': True,
#    'gr': True,
#    'science': True,
#    'cartoons': True,
#    ('many', 'gr'): True,
#    ('gr', 'science'): True,
#    ('science', 'cartoons'): True},
#   'neg'),
#  ({'edinburgh': True,
#    'fringe': True,
#    'weeks': True,
#    'away': True,
#    'need': True,
#    'monies': True,
#    'btw': True,
#    'elliott': True,
#    'blame': True,
#    'twitter': True,
#    'intrusion': True,
#    ('edinburgh', 'fringe'): True,
#    ('fringe', 'only'): True,
#    ('only', 'weeks'): True,
#    ('weeks', 'away'): True,
#    ('away', 'need'): True,
#    ('need', 'monies'): True,
#    ('monies', 'btw'): True,
#    ('btw', 'elliott'): True,
#    ('elliott', 'blame'): True,
#    ('blame', 'twitter'): True,
#    ('twitter', 'intrusion'): True},
#   'neg'),
#  ({'didnt': True,
#    'come': True,
#    'school': True,
#    'done': True,
#    'short': True,
#    'stack': True,
#    'thing': True,
#    'still': True,
#    'need': True,
#    ('didnt', 'come'): True,
#    ('come', 'school'): True,
#    ('school', 'done'): True,
#    ('done', 'short'): True,
#    ('short', 'stack'): True,
#    ('stack', 'thing'): True,
#    ('thing', 'still'): True,
#    ('still', 'need'): True},
#   'neg'),
#  ({'one': True,
#    'latter': True,
#    'us': True,
#    'store': True,
#    'iphone': True,
#    'comics': True,
#    ('one', 'latter'): True,
#    ('latter', 'us'): True,
#    ('us', 'store'): True,
#    ('store', 'only'): True,
#    ('only', 'iphone'): True,
#    ('iphone', 'comics'): True},
#   'neg'),
#  ({'magic': True,
#    'thinking': True,
#    'less': True,
#    'chance': True,
#    'hedo': True,
#    'stays': True,
#    'orlando': True,
#    'gonna': True,
#    'go': True,
#    'blame': True,
#    'though': True,
#    ('magic', 'thinking'): True,
#    ('thinking', 'less'): True,
#    ('less', 'than'): True,
#    ('than', 'chance'): True,
#    ('chance', 'hedo'): True,
#    ('hedo', 'stays'): True,
#    ('stays', 'orlando'): True,
#    ('orlando', 'gonna'): True,
#    ('gonna', 'go'): True,
#    ('go', 'not'): True,
#    ('not', 'blame'): True,
#    ('blame', 'though'): True},
#   'neg'),
#  ({'wud': True,
#    'make': True,
#    'beautiful': True,
#    'plc': True,
#    'cry': True,
#    ('wud', 'make'): True,
#    ('make', 'beautiful'): True,
#    ('beautiful', 'plc'): True,
#    ('plc', 'cry'): True},
#   'neg'),
#  ({'outer': True,
#    'fat': True,
#    'kid': True,
#    ('outer', 'fat'): True,
#    ('fat', 'kid'): True},
#   'neg'),
#  ({'se': True,
#    'morrea': True,
#    'mi': True,
#    'joseph': True,
#    'vale': True,
#    ('se', 'morrea'): True,
#    ('morrea', 'mi'): True,
#    ('mi', 'joseph'): True,
#    ('joseph', 'no'): True,
#    ('no', 'no'): True,
#    ('no', 'se'): True,
#    ('se', 'vale'): True},
#   'neg'),
#  ({'youtube': True,
#    'account': True,
#    'suspended': True,
#    'lol': True,
#    'single': True,
#    'ladies': True,
#    'dance': True,
#    'need': True,
#    'watch': True,
#    ('youtube', 'account'): True,
#    ('account', 'suspended'): True,
#    ('suspended', 'lol'): True,
#    ('lol', 'single'): True,
#    ('single', 'ladies'): True,
#    ('ladies', 'dance'): True,
#    ('dance', 'need'): True,
#    ('need', 'watch'): True},
#   'neg'),
#  ({'know': True,
#    'sold': True,
#    'though': True,
#    ('know', 'sold'): True,
#    ('sold', 'though'): True},
#   'neg'),
#  ({'get': True,
#    'aim': True,
#    'talk': True,
#    'miss': True,
#    ('get', 'aim'): True,
#    ('aim', 'talk'): True,
#    ('talk', 'miss'): True},
#   'neg'),
#  ({'kashrut': True,
#    'convo': True,
#    'makes': True,
#    'want': True,
#    'keep': True,
#    'kosher': True,
#    'roomies': True,
#    'catholic': True,
#    'pork': True,
#    'loin': True,
#    'fridge': True,
#    'kosherfail': True,
#    ('kashrut', 'convo'): True,
#    ('convo', 'makes'): True,
#    ('makes', 'want'): True,
#    ('want', 'keep'): True,
#    ('keep', 'more'): True,
#    ('more', 'kosher'): True,
#    ('kosher', 'but'): True,
#    ('but', 'roomies'): True,
#    ('roomies', 'catholic'): True,
#    ('catholic', 'pork'): True,
#    ('pork', 'loin'): True,
#    ('loin', 'fridge'): True,
#    ('fridge', 'kosherfail'): True},
#   'neg'),
#  ({'home': True,
#    'neither': True,
#    'better': True,
#    ('not', 'home'): True,
#    ('home', 'neither'): True,
#    ('neither', 'better'): True},
#   'neg'),
#  ({'immune': True,
#    'dentists': True,
#    'drills': True,
#    'etc': True,
#    'bother': True,
#    'gum': True,
#    'lift': True,
#    'surgery': True,
#    'next': True,
#    'week': True,
#    'tho': True,
#    'eek': True,
#    ('immune', 'dentists'): True,
#    ('dentists', 'drills'): True,
#    ('drills', 'etc'): True,
#    ('etc', 'just'): True,
#    ('just', 'not'): True,
#    ('not', 'bother'): True,
#    ('bother', 'gum'): True,
#    ('gum', 'lift'): True,
#    ('lift', 'surgery'): True,
#    ('surgery', 'next'): True,
#    ('next', 'week'): True,
#    ('week', 'tho'): True,
#    ('tho', 'eek'): True},
#   'neg'),
#  ({'tonite': True,
#    'im': True,
#    'still': True,
#    'awake': True,
#    ('tonite', 'im'): True,
#    ('im', 'still'): True,
#    ('still', 'awake'): True},
#   'neg'),
#  ({'hates': True,
#    'bebot': True,
#    'app': True,
#    ('hates', 'bebot'): True,
#    ('bebot', 'app'): True},
#   'neg'),
#  ({'referring': True}, 'neg'),
#  ({'miss': True,
#    'much': True,
#    'already': True,
#    ('miss', 'so'): True,
#    ('so', 'much'): True,
#    ('much', 'already'): True},
#   'neg'),
#  ({'practising': True,
#    'feel': True,
#    ('just', 'practising'): True,
#    ('practising', 'feel'): True},
#   'neg'),
#  ({'miss': True,
#    'love': True,
#    'jamie': True,
#    ('miss', 'love'): True,
#    ('love', 'jamie'): True},
#   'neg'),
#  ({'fuck': True}, 'neg'),
#  ({'head': True,
#    'feels': True,
#    'like': True,
#    'bowling': True,
#    'ball': True,
#    ('head', 'feels'): True,
#    ('feels', 'like'): True,
#    ('like', 'bowling'): True,
#    ('bowling', 'ball'): True},
#   'neg'),
#  ({'heart': True,
#    'hurts': True,
#    'badly': True,
#    ('heart', 'hurts'): True,
#    ('hurts', 'badly'): True},
#   'neg'),
#  ({'fs': True,
#    'keeps': True,
#    'crashing': True,
#    'try': True,
#    'load': True,
#    'bungie': True,
#    'plane': True,
#    ('fs', 'keeps'): True,
#    ('keeps', 'crashing'): True,
#    ('crashing', 'try'): True,
#    ('try', 'load'): True,
#    ('load', 'bungie'): True,
#    ('bungie', 'plane'): True},
#   'neg'),
#  ({'current': True,
#    'headset': True,
#    'deathbed': True,
#    'dad': True,
#    'gave': True,
#    'weeks': True,
#    'back': True,
#    ('current', 'headset'): True,
#    ('headset', 'deathbed'): True,
#    ('deathbed', 'dad'): True,
#    ('dad', 'gave'): True,
#    ('gave', 'just'): True,
#    ('just', 'weeks'): True,
#    ('weeks', 'back'): True},
#   'neg'),
#  ({'mood': True,
#    'currently': True,
#    'blah': True,
#    'sitting': True,
#    'parking': True,
#    'lot': True,
#    ('mood', 'currently'): True,
#    ('currently', 'blah'): True,
#    ('blah', 'sitting'): True,
#    ('sitting', 'parking'): True,
#    ('parking', 'lot'): True},
#   'neg'),
#  ({}, 'neg'),
#  ({'everyone': True,
#    'went': True,
#    'home': True,
#    'even': True,
#    'cmf': True,
#    ('everyone', 'went'): True,
#    ('went', 'home'): True,
#    ('home', 'not'): True,
#    ('not', 'everyone'): True,
#    ('everyone', 'even'): True,
#    ('even', 'cmf'): True},
#   'neg'),
#  ({'fed': True}, 'neg'),
#  ({'fuck': True,
#    'fuuuuck': True,
#    ('fuck', 'fuck'): True,
#    ('fuck', 'fuuuuck'): True},
#   'neg'),
#  ({'feeling': True,
#    'today': True,
#    'make': True,
#    'matters': True,
#    'worst': True,
#    'super': True,
#    'nasty': True,
#    'rainy': True,
#    'outside': True,
#    'yuck': True,
#    ('not', 'feeling'): True,
#    ('feeling', 'today'): True,
#    ('today', 'make'): True,
#    ('make', 'matters'): True,
#    ('matters', 'worst'): True,
#    ('worst', 'super'): True,
#    ('super', 'nasty'): True,
#    ('nasty', 'rainy'): True,
#    ('rainy', 'outside'): True,
#    ('outside', 'yuck'): True},
#   'neg'),
#  ({'wanted': True,
#    'aiden': True,
#    'davis': True,
#    'win': True,
#    'bummed': True,
#    'didnt': True,
#    ('wanted', 'aiden'): True,
#    ('aiden', 'davis'): True,
#    ('davis', 'win'): True,
#    ('win', 'so'): True,
#    ('so', 'bummed'): True,
#    ('bummed', 'didnt'): True},
#   'neg'),
#  ({'bed': True, 'time': True, ('bed', 'time'): True}, 'neg'),
#  ({'friends': True,
#    'like': True,
#    'thanks': True,
#    'fake': True,
#    ('friends', 'like'): True,
#    ('like', 'no'): True,
#    ('no', 'thanks'): True,
#    ('thanks', 'not'): True,
#    ('not', 'fake'): True},
#   'neg'),
#  ({'think': True,
#    'bf': True,
#    'cheating': True,
#    ('think', 'bf'): True,
#    ('bf', 'cheating'): True},
#   'neg'),
#  ({'want': True,
#    'octo': True,
#    'drive': True,
#    ('want', 'octo'): True,
#    ('octo', 'drive'): True},
#   'neg'),
#  ({'want': True,
#    'display': True,
#    'pretty': True,
#    'voltron': True,
#    'upside': True,
#    'get': True,
#    'two': True,
#    'voltrons': True,
#    ('want', 'display'): True,
#    ('display', 'pretty'): True,
#    ('pretty', 'voltron'): True,
#    ('voltron', 'upside'): True,
#    ('upside', 'get'): True,
#    ('get', 'two'): True,
#    ('two', 'pretty'): True,
#    ('pretty', 'voltrons'): True},
#   'neg'),
#  ({'want': True,
#    'find': True,
#    'way': True,
#    'put': True,
#    'photos': True,
#    'phone': True,
#    'bluetooth': True,
#    'computer': True,
#    'work': True,
#    ('want', 'find'): True,
#    ('find', 'way'): True,
#    ('way', 'put'): True,
#    ('put', 'photos'): True,
#    ('photos', 'phone'): True,
#    ('phone', 'bluetooth'): True,
#    ('bluetooth', 'phone'): True,
#    ('phone', 'computer'): True,
#    ('computer', 'but'): True,
#    ('but', 'not'): True,
#    ('not', 'work'): True},
#   'neg'),
#  ({'effort': True,
#    'bring': True,
#    'best': True,
#    'content': True,
#    'added': True,
#    'lease': True,
#    'hours': True,
#    'release': True,
#    'digital': True,
#    'rapture': True,
#    'soon': True,
#    'hang': True,
#    'tight': True,
#    ('effort', 'bring'): True,
#    ('bring', 'best'): True,
#    ('best', 'content'): True,
#    ('content', 'just'): True,
#    ('just', 'added'): True,
#    ('added', 'lease'): True,
#    ('lease', 'hours'): True,
#    ('hours', 'release'): True,
#    ('release', 'digital'): True,
#    ('digital', 'rapture'): True,
#    ('rapture', 'soon'): True,
#    ('soon', 'hang'): True,
#    ('hang', 'tight'): True},
#   'neg'),
#  ({'response': True,
#    'happened': True,
#    'today': True,
#    ('response', 'happened'): True,
#    ('happened', 'today'): True},
#   'neg'),
#  ({'right': True, 'hurts': True, ('right', 'hurts'): True}, 'neg'),
#  ({'kinda': True,
#    'really': True,
#    ('kinda', 'but'): True,
#    ('but', 'not'): True,
#    ('not', 'really'): True,
#    ('really', 'but'): True,
#    ('but', 'kinda'): True},
#   'neg'),
#  ({'let': True,
#    'moment': True,
#    'silence': True,
#    'childhood': True,
#    'homes': True,
#    'sadly': True,
#    'replaced': True,
#    'never': True,
#    'go': True,
#    'back': True,
#    ('let', 'moment'): True,
#    ('moment', 'silence'): True,
#    ('silence', 'childhood'): True,
#    ('childhood', 'homes'): True,
#    ('homes', 'sadly'): True,
#    ('sadly', 'not'): True,
#    ('not', 'replaced'): True,
#    ('replaced', 'never'): True,
#    ('never', 'go'): True,
#    ('go', 'back'): True},
#   'neg'),
#  ({'man': True,
#    'worth': True,
#    'tears': True,
#    'one': True,
#    'make': True,
#    'cry': True,
#    ('no', 'man'): True,
#    ('man', 'worth'): True,
#    ('worth', 'tears'): True,
#    ('tears', 'one'): True,
#    ('one', 'not'): True,
#    ('not', 'make'): True,
#    ('make', 'cry'): True},
#   'neg'),
#  ({'rain': True,
# ...
#    'miss': True,
#    'papi': True,
#    ('not', 'wanna'): True,
#    ('wanna', 'go'): True,
#    ('go', 'work'): True,
#    ('work', 'tired'): True,
#    ('tired', 'miss'): True,
#    ('miss', 'papi'): True},
#   'neg'),
#  ({'want': True,
#    'school': True,
#    'anymoreee': True,
#    ('not', 'want'): True,
#    ('want', 'school'): True,
#    ('school', 'anymoreee'): True},
#   'neg'),
#  ({'dunno': True}, 'neg'),
#  ({'failed': True,
#    'math': True,
#    'final': True,
#    'part': True,
#    'hate': True,
#    'calculus': True,
#    ('failed', 'math'): True,
#    ('math', 'final'): True,
#    ('final', 'part'): True,
#    ('part', 'hate'): True,
#    ('hate', 'calculus'): True},
#   'neg'),
#  ({'feel': True,
#    'bad': True,
#    'mewithoutyou': True,
#    ('feel', 'bad'): True,
#    ('bad', 'mewithoutyou'): True},
#   'neg'),
#  ({'feel': True,
#    'like': True,
#    'car': True,
#    'inside': True,
#    'banged': True,
#    'sad': True,
#    'maybe': True,
#    'meant': True,
#    'get': True,
#    'new': True,
#    'borrow': True,
#    'cash': True,
#    'anyone': True,
#    ('feel', 'just'): True,
#    ('just', 'like'): True,
#    ('like', 'car'): True,
#    ('car', 'inside'): True,
#    ('inside', 'banged'): True,
#    ('banged', 'sad'): True,
#    ('sad', 'maybe'): True,
#    ('maybe', 'meant'): True,
#    ('meant', 'get'): True,
#    ('get', 'new'): True,
#    ('new', 'borrow'): True,
#    ('borrow', 'cash'): True,
#    ('cash', 'anyone'): True,
#    ('anyone', 'anyone'): True},
#   'neg'),
#  ({'feel': True,
#    'like': True,
#    'horrible': True,
#    'human': True,
#    'take': True,
#    'dog': True,
#    'supposed': True,
#    ('feel', 'like'): True,
#    ('like', 'horrible'): True,
#    ('horrible', 'human'): True,
#    ('human', 'not'): True,
#    ('not', 'take'): True,
#    ('take', 'dog'): True,
#    ('dog', 'supposed'): True,
#    ('supposed', 'too'): True},
#   'neg'),
#  ({'feel': True,
#    'like': True,
#    'crap': True,
#    ('feel', 'like'): True,
#    ('like', 'crap'): True},
#   'neg'),
#  ({'feel': True,
#    'like': True,
#    'crawling': True,
#    'bed': True,
#    'covers': True,
#    'listening': True,
#    'ipod': True,
#    'cry': True,
#    'session': True,
#    ('feel', 'like'): True,
#    ('like', 'crawling'): True,
#    ('crawling', 'bed'): True,
#    ('bed', 'under'): True,
#    ('under', 'covers'): True,
#    ('covers', 'listening'): True,
#    ('listening', 'ipod'): True,
#    ('ipod', 'cry'): True,
#    ('cry', 'session'): True},
#   'neg'),
#  ({'feel': True,
#    'like': True,
#    'ipod': True,
#    'gonna': True,
#    'die': True,
#    'today': True,
#    'apple': True,
#    'eye': True,
#    'double': True,
#    'pun': True,
#    ('feel', 'like'): True,
#    ('like', 'ipod'): True,
#    ('ipod', 'gonna'): True,
#    ('gonna', 'die'): True,
#    ('die', 'today'): True,
#    ('today', 'apple'): True,
#    ('apple', 'eye'): True,
#    ('eye', 'double'): True,
#    ('double', 'pun'): True},
#   'neg'),
#  ({'feel': True,
#    'really': True,
#    'alone': True,
#    ('feel', 'really'): True,
#    ('really', 'alone'): True},
#   'neg'),
#  ({'fell': True,
#    'stairs': True,
#    'officially': True,
#    'hate': True,
#    'curvy': True,
#    'staircases': True,
#    'nothing': True,
#    'bad': True,
#    'news': True,
#    ('fell', 'stairs'): True,
#    ('stairs', 'officially'): True,
#    ('officially', 'hate'): True,
#    ('hate', 'curvy'): True,
#    ('curvy', 'staircases'): True,
#    ('staircases', 'nothing'): True,
#    ('nothing', 'but'): True,
#    ('but', 'bad'): True,
#    ('bad', 'news'): True},
#   'neg'),
#  ({'felt': True,
#    'sick': True,
#    'today': True,
#    'sore': True,
#    'throat': True,
#    'go': True,
#    'doctors': True,
#    'appointment': True,
#    'wanna': True,
#    'rest': True,
#    ('felt', 'so'): True,
#    ('so', 'sick'): True,
#    ('sick', 'today'): True,
#    ('today', 'sore'): True,
#    ('sore', 'throat'): True,
#    ('throat', 'go'): True,
#    ('go', 'doctors'): True,
#    ('doctors', 'appointment'): True,
#    ('appointment', 'just'): True,
#    ('just', 'wanna'): True,
#    ('wanna', 'rest'): True},
#   'neg'),
#  ({'forgot': True,
#    'bring': True,
#    'new': True,
#    'allegra': True,
#    'hour': True,
#    'work': True,
#    'today': True,
#    'singulair': True,
#    'flying': True,
#    'solo': True,
#    ('forgot', 'bring'): True,
#    ('bring', 'new'): True,
#    ('new', 'allegra'): True,
#    ('allegra', 'hour'): True,
#    ('hour', 'work'): True,
#    ('work', 'today'): True,
#    ('today', 'so'): True,
#    ('so', 'singulair'): True,
#    ('singulair', 'flying'): True,
#    ('flying', 'solo'): True,
#    ('solo', 'today'): True},
#   'neg'),
#  ({'forgot': True,
#    'tell': True,
#    'guys': True,
#    'didnt': True,
#    'make': True,
#    'cheer': True,
#    'team': True,
#    'gggrr': True,
#    ('forgot', 'tell'): True,
#    ('tell', 'guys'): True,
#    ('guys', 'didnt'): True,
#    ('didnt', 'make'): True,
#    ('make', 'cheer'): True,
#    ('cheer', 'team'): True,
#    ('team', 'gggrr'): True},
#   'neg'),
#  ({'got': True,
#    'banned': True,
#    'forever': True,
#    'cp': True,
#    'mimo': True,
#    'dosnt': True,
#    'suck': True,
#    ('got', 'banned'): True,
#    ('banned', 'forever'): True,
#    ('forever', 'cp'): True,
#    ('cp', 'mimo'): True,
#    ('mimo', 'dosnt'): True,
#    ('dosnt', 'suck'): True},
#   'neg'),
#  ({'got': True,
#    'ill': True,
#    'tomorrow': True,
#    'birthday': True,
#    ('got', 'ill'): True,
#    ('ill', 'tomorrow'): True,
#    ('tomorrow', 'got'): True,
#    ('got', 'birthday'): True},
#   'neg'),
#  ({'got': True,
#    'sunburnt': True,
#    'day': True,
#    'blackpool': True,
#    'lol': True,
#    'little': True,
#    'boy': True,
#    'fun': True,
#    'tho': True,
#    'chucking': True,
#    'water': True,
#    ('got', 'sunburnt'): True,
#    ('sunburnt', 'day'): True,
#    ('day', 'blackpool'): True,
#    ('blackpool', 'lol'): True,
#    ('lol', 'little'): True,
#    ('little', 'boy'): True,
#    ('boy', 'fun'): True,
#    ('fun', 'tho'): True,
#    ('tho', 'chucking'): True,
#    ('chucking', 'water'): True,
#    ('water', 'lol'): True},
#   'neg'),
#  ({'guess': True,
#    'dont': True,
#    'boyfriend': True,
#    ('guess', 'dont'): True,
#    ('dont', 'boyfriend'): True},
#   'neg'),
#  ({'guess': True,
#    'would': True,
#    'true': True,
#    'cleveland': True,
#    'sports': True,
#    'fan': True,
#    'without': True,
#    'years': True,
#    'collapse': True,
#    'disappointment': True,
#    ('guess', 'would'): True,
#    ('would', 'not'): True,
#    ('not', 'true'): True,
#    ('true', 'cleveland'): True,
#    ('cleveland', 'sports'): True,
#    ('sports', 'fan'): True,
#    ('fan', 'without'): True,
#    ('without', 'years'): True,
#    ('years', 'collapse'): True,
#    ('collapse', 'disappointment'): True},
#   'neg'),
#  ({'guess': True,
#    'home': True,
#    'everyone': True,
#    'bday': True,
#    'bash': True,
#    'time': True,
#    'lives': True,
#    'drake': True,
#    ('guess', 'home'): True,
#    ('home', 'everyone'): True,
#    ('everyone', 'bday'): True,
#    ('bday', 'bash'): True,
#    ('bash', 'time'): True,
#    ('time', 'lives'): True,
#    ('lives', 'drake'): True},
#   'neg'),
#  ({'guess': True,
#    'got': True,
#    'time': True,
#    'work': True,
#    'rofl': True,
#    ('guess', 'got'): True,
#    ('got', 'more'): True,
#    ('more', 'time'): True,
#    ('time', 'work'): True,
#    ('work', 'rofl'): True},
#   'neg'),
#  ({'hat': True,
#    'seeing': True,
#    'friends': True,
#    'breakup': True,
#    'im': True,
#    'sorry': True,
#    'frankus': True,
#    ('hat', 'seeing'): True,
#    ('seeing', 'friends'): True,
#    ('friends', 'breakup'): True,
#    ('breakup', 'im'): True,
#    ('im', 'sorry'): True,
#    ('sorry', 'frankus'): True},
#   'neg'),
#  ({'hate': True, 'goodbyes': True, ('hate', 'goodbyes'): True}, 'neg'),
#  ({'hate': True,
#    'change': True,
#    'driving': True,
#    'instructor': True,
#    'new': True,
#    'one': True,
#    'dented': True,
#    'confidence': True,
#    'slightly': True,
#    ('hate', 'change'): True,
#    ('change', 'driving'): True,
#    ('driving', 'instructor'): True,
#    ('instructor', 'new'): True,
#    ('new', 'one'): True,
#    ('one', 'dented'): True,
#    ('dented', 'confidence'): True,
#    ('confidence', 'slightly'): True},
#   'neg'),
#  ({'hate': True,
#    'work': True,
#    'weekend': True,
#    'duty': True,
#    ('hate', 'work'): True,
#    ('work', 'weekend'): True,
#    ('weekend', 'duty'): True},
#   'neg'),
#  ({'hate': True}, 'neg'),
#  ({'hate': True, 'mad': True, ('hate', 'mad'): True}, 'neg'),
#  ({'hate': True, 'lightening': True, ('hate', 'lightening'): True}, 'neg'),
#  ({'hate': True,
#    'anyone': True,
#    'talk': True,
#    ('hate', 'not'): True,
#    ('not', 'anyone'): True,
#    ('anyone', 'talk'): True},
#   'neg'),
#  ({'hate': True, 'pain': True, ('hate', 'pain'): True}, 'neg'),
#  ({'hate': True,
#    'summerschool': True,
#    'fun': True,
#    'work': True,
#    'even': True,
#    'though': True,
#    'getting': True,
#    'doooit': True,
#    'visitt': True,
#    'fobby': True,
#    'friend': True,
#    ('hate', 'summerschool'): True,
#    ('summerschool', 'fun'): True,
#    ('fun', 'work'): True,
#    ('work', 'even'): True,
#    ('even', 'though'): True,
#    ('though', 'getting'): True,
#    ('getting', 'off'): True,
#    ('off', 'doooit'): True,
#    ('doooit', 'visitt'): True,
#    ('visitt', 'fobby'): True,
#    ('fobby', 'friend'): True},
#   'neg'),
#  ({'hate': True,
#    'cold': True,
#    'weather': True,
#    ('hate', 'cold'): True,
#    ('cold', 'weather'): True},
#   'neg'),
#  ({'bbc': True,
#    'champion': True,
#    'nadal': True,
#    'wimbledon': True,
#    ('bbc', 'champion'): True,
#    ('champion', 'nadal'): True,
#    ('nadal', 'wimbledon'): True},
#   'neg'),
#  ({'boston': True,
#    'fine': True,
#    'ass': True,
#    'eddie': True,
#    'house': True,
#    'whocangetit': True,
#    'way': True,
#    'lost': True,
#    'last': True,
#    'nite': True,
#    'boo': True,
#    'orlando': True,
#    'la': True,
#    'cle': True,
#    'finals': True,
#    'baby': True,
#    ('boston', 'fine'): True,
#    ('fine', 'ass'): True,
#    ('ass', 'eddie'): True,
#    ('eddie', 'house'): True,
#    ('house', 'whocangetit'): True,
#    ('whocangetit', 'way'): True,
#    ('way', 'lost'): True,
#    ('lost', 'last'): True,
#    ('last', 'nite'): True,
#    ('nite', 'boo'): True,
#    ('boo', 'orlando'): True,
#    ('orlando', 'la'): True,
#    ('la', 'cle'): True,
#    ('cle', 'finals'): True,
#    ('finals', 'baby'): True},
#   'neg'),
#  ({'safe': True,
#    'person': True,
#    'ego': True,
#    'little': True,
#    'damaged': True,
#    'lil': True,
#    'reboot': True,
#    'back': True,
#    'usual': True,
#    'harlem': True,
#    'swagg': True,
#    ('safe', 'person'): True,
#    ('person', 'ego'): True,
#    ('ego', 'little'): True,
#    ('little', 'damaged'): True,
#    ('damaged', 'lil'): True,
#    ('lil', 'reboot'): True,
#    ('reboot', 'back'): True,
#    ('back', 'usual'): True,
#    ('usual', 'harlem'): True,
#    ('harlem', 'swagg'): True},
#   'neg'),
#  ({'becca': True,
#    'told': True,
#    'would': True,
#    'start': True,
#    'feel': True,
#    'better': True,
#    'food': True,
#    'still': True,
#    'stressing': True,
#    'exam': True,
#    'revision': True,
#    'bit': True,
#    ('becca', 'told'): True,
#    ('told', 'would'): True,
#    ('would', 'start'): True,
#    ('start', 'feel'): True,
#    ('feel', 'better'): True,
#    ('better', 'food'): True,
#    ('food', 'still'): True,
#    ('still', 'stressing'): True,
#    ('stressing', 'exam'): True,
#    ('exam', 'more'): True,
#    ('more', 'revision'): True,
#    ('revision', 'bit'): True},
#   'neg'),
#  ({'becomming': True,
#    'fan': True,
#    'bubble': True,
#    'shirts': True,
#    'haha': True,
#    'dont': True,
#    'make': True,
#    'look': True,
#    'chubby': True,
#    ('becomming', 'fan'): True,
#    ('fan', 'bubble'): True,
#    ('bubble', 'shirts'): True,
#    ('shirts', 'haha'): True,
#    ('haha', 'dont'): True,
#    ('dont', 'make'): True,
#    ('make', 'look'): True,
#    ('look', 'chubby'): True},
#   'neg'),
#  ({'crappy': True, 'day': True, ('crappy', 'day'): True}, 'neg'),
#  ({'girl': True,
#    'stinks': True,
#    'grrrrrrrrrr': True,
#    ('girl', 'stinks'): True,
#    ('stinks', 'grrrrrrrrrr'): True},
#   'neg'),
#  ({'forced': True,
#    'bed': True,
#    'guess': True,
#    'wait': True,
#    'moring': True,
#    'niley': True,
#    'news': True,
#    'uk': True,
#    ('forced', 'bed'): True,
#    ('bed', 'guess'): True,
#    ('guess', 'wait'): True,
#    ('wait', 'moring'): True,
#    ('moring', 'niley'): True,
#    ('niley', 'news'): True,
#    ('news', 'uk'): True,
#    ('uk', 'so'): True},
#   'neg'),
#  ({'big': True,
#    'day': True,
#    'putting': True,
#    'dock': True,
#    'tomorrow': True,
#    'degress': True,
#    'outside': True,
#    'water': True,
#    'much': True,
#    'colder': True,
#    ('big', 'day'): True,
#    ('day', 'putting'): True,
#    ('putting', 'dock'): True,
#    ('dock', 'tomorrow'): True,
#    ('tomorrow', 'degress'): True,
#    ('degress', 'outside'): True,
#    ('outside', 'but'): True,
#    ('but', 'water'): True,
#    ('water', 'much'): True,
#    ('much', 'colder'): True,
#    ('colder', 'than'): True},
#   'neg'),
#  ({'bio': True,
#    'physics': True,
#    'math': True,
#    'health': True,
#    'filipino': True,
#    'english': True,
#    'elections': True,
#    'help': True,
#    'drowning': True,
#    'school': True,
#    'work': True,
#    ('bio', 'physics'): True,
#    ('physics', 'math'): True,
#    ('math', 'health'): True,
#    ('health', 'filipino'): True,
#    ('filipino', 'english'): True,
#    ('english', 'elections'): True,
#    ('elections', 'help'): True,
#    ('help', 'drowning'): True,
#    ('drowning', 'school'): True,
#    ('school', 'work'): True},
#   'neg'),
#  ({'blah': True,
#    'perfect': True,
#    'know': True,
#    ('blah', 'blah'): True,
#    ('blah', 'perfect'): True,
#    ('perfect', 'know'): True},
#   'neg'),
#  ({'blesh': True,
#    'feedback': True,
#    'one': True,
#    'house': True,
#    'tell': True,
#    'sheesh': True,
#    ('blesh', 'no'): True,
#    ('no', 'feedback'): True,
#    ('feedback', 'no'): True,
#    ('no', 'one'): True,
#    ('one', 'house'): True,
#    ('house', 'tell'): True,
#    ('tell', 'sheesh'): True},
#   'neg'),
#  ({'bluetooth': True,
#    'still': True,
#    'work': True,
#    'iphone': True,
#    'pile': True,
#    'knob': True,
#    'sackage': True,
#    ('bluetooth', 'still'): True,
#    ('still', 'not'): True,
#    ('not', 'work'): True,
#    ('work', 'iphone'): True,
#    ('iphone', 'pile'): True,
#    ('pile', 'knob'): True,
#    ('knob', 'sackage'): True},
#   'neg'),
#  ({'boo': True, 'listen': True, ('boo', 'but'): True, ('but', 'listen'): True},
#   'neg'),
#  ({'boo': True,
#    'first': True,
#    'day': True,
#    'classes': True,
#    'summer': True,
#    'ughhhh': True,
#    'anyone': True,
#    'ever': True,
#    'boob': True,
#    'cramps': True,
#    'lol': True,
#    ('boo', 'first'): True,
#    ('first', 'day'): True,
#    ('day', 'classes'): True,
#    ('classes', 'summer'): True,
#    ('summer', 'classes'): True,
#    ('classes', 'ughhhh'): True,
#    ('ughhhh', 'anyone'): True,
#    ('anyone', 'ever'): True,
#    ('ever', 'boob'): True,
#    ('boob', 'cramps'): True,
#    ('cramps', 'lol'): True},
#   'neg'),
#  ({'boo': True,
#    'hoo': True,
#    'trying': True,
#    'open': True,
#    'email': True,
#    'working': True,
#    'grrrr': True,
#    ('boo', 'hoo'): True,
#    ('hoo', 'trying'): True,
#    ('trying', 'open'): True,
#    ('open', 'email'): True,
#    ('email', 'not'): True,
#    ('not', 'working'): True,
#    ('working', 'grrrr'): True},
#   'neg'),
#  ({'boo': True,
#    'suck': True,
#    'thanks': True,
#    'one': True,
#    'thing': True,
#    'today': True,
#    'wait': True,
#    'rest': True,
#    'week': True,
#    ('boo', 'suck'): True,
#    ('suck', 'but'): True,
#    ('but', 'thanks'): True,
#    ('thanks', 'one'): True,
#    ('one', 'thing'): True,
#    ('thing', 'today'): True,
#    ('today', 'not'): True,
#    ('not', 'wait'): True,
#    ('wait', 'rest'): True,
#    ('rest', 'week'): True},
#   'neg'),
#  ({'bored': True,
#    'one': True,
#    'talking': True,
#    'anymore': True,
#    ('bored', 'no'): True,
#    ('no', 'one'): True,
#    ('one', 'talking'): True,
#    ('talking', 'anymore'): True},
#   'neg'),
#  ({'bored': True,
#    'sad': True,
#    'one': True,
#    'tweeting': True,
#    ('bored', 'sad'): True,
#    ('sad', 'no'): True,
#    ('no', 'one'): True,
#    ('one', 'tweeting'): True},
#   'neg'),
#  ({'bored': True,
#    'wish': True,
#    'somewhere': True,
#    'go': True,
#    'ha': True,
#    ('bored', 'wish'): True,
#    ('wish', 'somewhere'): True,
#    ('somewhere', 'go'): True,
#    ('go', 'ha'): True},
#   'neg'),
#  ({'boredd': True,
#    'want': True,
#    'go': True,
#    'hommmmme': True,
#    ('boredd', 'want'): True,
#    ('want', 'go'): True,
#    ('go', 'hommmmme'): True},
#   'neg'),
#  ...]

# %%
print (len(pos_reviews_set), len(neg_reviews_set)) # Output: (1000, 1000)
 
# radomize pos_reviews_set and neg_reviews_set
# doing so will output different accuracy result everytime we run the program
from random import shuffle 
shuffle(pos_reviews_set)
shuffle(neg_reviews_set)

test_set = pos_reviews_set[:int((0.2*len(pos_reviews_set)))] + neg_reviews_set[:int((0.2*len(neg_reviews_set)))]
train_set = pos_reviews_set[int((0.2*len(pos_reviews_set))):] + neg_reviews_set[int((0.2*len(neg_reviews_set))):]
 
print(len(test_set),  len(train_set))
# Out:
# 56204 43319
# 19903 79620

# %%
from nltk import classify
from nltk import NaiveBayesClassifier
 
classifier = NaiveBayesClassifier.train(train_set)
 
accuracy = classify.accuracy(classifier, test_set)
print(accuracy)
 
print (classifier.show_most_informative_features(10))
# Out:
# 0.736723107069286
# Most Informative Features
#     ('followers', 'day') = True              pos : neg    =     72.7 : 1.0
#         ('makes', 'sad') = True              neg : pos    =     49.7 : 1.0
#            ('so', 'sad') = True              neg : pos    =     48.9 : 1.0
#        ('going', 'miss') = True              neg : pos    =     42.0 : 1.0
#                   gutted = True              neg : pos    =     40.2 : 1.0
#        ('really', 'sad') = True              neg : pos    =     34.2 : 1.0
#     ('get', 'followers') = True              pos : neg    =     32.9 : 1.0
#          ('very', 'sad') = True              neg : pos    =     32.4 : 1.0
#                    cries = True              neg : pos    =     29.8 : 1.0
#                cancelled = True              neg : pos    =     27.2 : 1.0
# None

# %%
from nltk.tokenize import word_tokenize
 
custom_review = "I hated the film. It was a disaster. Poor direction, bad acting."
custom_review_tokens = word_tokenize(custom_review)
custom_review_set = bag_of_all_words(custom_review_tokens)
print (classifier.classify(custom_review_set)) # Output: neg
# Negative review correctly classified as negative
 
# probability result
prob_result = classifier.prob_classify(custom_review_set)
print (prob_result) # Output: <ProbDist with 2 samples>
print (prob_result.max()) # Output: neg
print (prob_result.prob("neg")) # Output: 0.770612685688
print (prob_result.prob("pos")) # Output: 0.229387314312
 
 
custom_review = "It was a wonderful and amazing movie. I loved it. Best direction, good acting."
custom_review_tokens = word_tokenize(custom_review)
custom_review_set = bag_of_all_words(custom_review_tokens)
 
print (classifier.classify(custom_review_set)) # Output: pos
# Positive review correctly classified as positive
 
# probability result
prob_result = classifier.prob_classify(custom_review_set)
print (prob_result) # Output: <ProbDist with 2 samples>
print (prob_result.max()) # Output: pos
print (prob_result.prob("neg")) # Output: 0.00677736186354
print (prob_result.prob("pos")) # Output: 0.993222638136
# Out:
# neg
# <ProbDist with 2 samples>
# neg
# 0.9845074131222304
# 0.015492586877772035
# pos
# <ProbDist with 2 samples>
# pos
# 0.003092670237989356
# 0.9969073297620106

# %%
custom_review = 'handed in my uniform today miss you already'
custom_review_tokens = word_tokenize(custom_review)
custom_review_set = bag_of_all_words(custom_review_tokens)
 
print (classifier.classify(custom_review_set)) # Output: pos
# Positive review correctly classified as positive
 
# probability result
prob_result = classifier.prob_classify(custom_review_set)
print (prob_result) # Output: <ProbDist with 2 samples>
print (prob_result.max()) # Output: pos
print (prob_result.prob("neg")) # Output: 0.00677736186354
print (prob_result.prob("pos")) # Output: 0.993222638136
# Out:
# neg
# <ProbDist with 2 samples>
# neg
# 0.9997690966098208
# 0.00023090339018304177

# %%
# pos_reviews_list = tweet_data[tweet_data['sentiment']==1]

# %%
# pos_list = list(pos_reviews_list['text'])

# %%
# # pos_reviews = []
# pos_reviews_set = []
# # for words in pos_reviews:
# #     print(words)
# #     pos_reviews_set.append((bag_of_all_words(words), 'pos'))
# for i in pos_list:
#     if type(i) is not float:
#         pos_reviews_set.append((bag_of_all_words(i.split()), 'pos'))
# #         print(i.split())
# #         pos_reviews.append(i.split())
# # pos_reviews
# pos_reviews_set

# %%
# [i for i in pos_reviews_set]

# %%
# len(pos_reviews_set)

# %%
# neg_reviews_list = tweet_data[tweet_data['sentiment']==0]

# %%
# neg_list = list(neg_reviews_list['text'])

# %%
# # pos_reviews = []
# neg_reviews_set = []
# # for words in pos_reviews:
# #     print(words)
# #     pos_reviews_set.append((bag_of_all_words(words), 'pos'))
# for i in neg_list:
#     if type(i) is not float:
#         neg_reviews_set.append((bag_of_all_words(i.split()), 'neg'))
# #         print(i.split())
# #         pos_reviews.append(i.split())
# # pos_reviews
# neg_reviews_set

# %%
# len(neg_reviews_set)

# %%
# print (len(pos_reviews_set), len(neg_reviews_set)) # Output: (1000, 1000)
 
# # radomize pos_reviews_set and neg_reviews_set
# # doing so will output different accuracy result everytime we run the program
# from random import shuffle 
# shuffle(pos_reviews_set)
# shuffle(neg_reviews_set)

# test_set = pos_reviews_set[:int((0.2*len(pos_reviews_set)))] + neg_reviews_set[:int((0.2*len(neg_reviews_set)))]
# train_set = pos_reviews_set[int((0.2*len(pos_reviews_set))):] + neg_reviews_set[int((0.2*len(neg_reviews_set))):]
 
# print(len(test_set),  len(train_set))

# %%
# neg_reviews_set[:int((0.2*len(neg_reviews_set)))]

# %%
# for row in train_set:
#     if row[1] == 'neg':
#         print(row)

# %%
# from nltk import classify
# from nltk import NaiveBayesClassifier
 
# classifier = NaiveBayesClassifier.train(train_set)
 
# accuracy = classify.accuracy(classifier, test_set)
# print(accuracy)
 
# print (classifier.show_most_informative_features(10))

# %%
# from nltk.tokenize import word_tokenize
 
# custom_review = "I hated the film. It was a disaster. Poor direction, bad acting."
# custom_review_tokens = word_tokenize(custom_review)
# custom_review_set = bag_of_all_words(custom_review_tokens)
# print (classifier.classify(custom_review_set)) # Output: neg
# # Negative review correctly classified as negative
 
# # probability result
# prob_result = classifier.prob_classify(custom_review_set)
# print (prob_result) # Output: <ProbDist with 2 samples>
# print (prob_result.max()) # Output: neg
# print (prob_result.prob("neg")) # Output: 0.770612685688
# print (prob_result.prob("pos")) # Output: 0.229387314312
 
 
# custom_review = "It was a wonderful and amazing movie. I loved it. Best direction, good acting."
# custom_review_tokens = word_tokenize(custom_review)
# custom_review_set = bag_of_all_words(custom_review_tokens)
 
# print (classifier.classify(custom_review_set)) # Output: pos
# # Positive review correctly classified as positive
 
# # probability result
# prob_result = classifier.prob_classify(custom_review_set)
# print (prob_result) # Output: <ProbDist with 2 samples>
# print (prob_result.max()) # Output: pos
# print (prob_result.prob("neg")) # Output: 0.00677736186354
# print (prob_result.prob("pos")) # Output: 0.993222638136

# %%
# custom_review = 'handed in my uniform today miss you already'
# custom_review_tokens = word_tokenize(custom_review)
# custom_review_set = bag_of_all_words(custom_review_tokens)
 
# print (classifier.classify(custom_review_set)) # Output: pos
# # Positive review correctly classified as positive
 
# # probability result
# prob_result = classifier.prob_classify(custom_review_set)
# print (prob_result) # Output: <ProbDist with 2 samples>
# print (prob_result.max()) # Output: pos
# print (prob_result.prob("neg")) # Output: 0.00677736186354
# print (prob_result.prob("pos")) # Output: 0.993222638136
